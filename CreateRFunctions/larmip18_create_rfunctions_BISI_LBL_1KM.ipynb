# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv
#import pandas

# %%
# BISI_LBL
# BM02

fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.6-2.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM02_R0 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM02_R0.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.1-2.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM02_R1 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM02_R1.append(val)

fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.2-2.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM02_R2 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM02_R2.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.3-2.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM02_R3 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM02_R3.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.4-2.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM02_R4 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM02_R4.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.5-2.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM02_R5 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM02_R5.append(val)

# %%
BISI_LBL_1KM_BM02_R0=np.array(BISI_LBL_1KM_BM02_R0)
BISI_LBL_1KM_BM02_R1=np.array(BISI_LBL_1KM_BM02_R1)
BISI_LBL_1KM_BM02_R2=np.array(BISI_LBL_1KM_BM02_R2)
BISI_LBL_1KM_BM02_R3=np.array(BISI_LBL_1KM_BM02_R3)
BISI_LBL_1KM_BM02_R4=np.array(BISI_LBL_1KM_BM02_R4)
BISI_LBL_1KM_BM02_R5=np.array(BISI_LBL_1KM_BM02_R5)

BISI_LBL_1KM_BM02_SU=BISI_LBL_1KM_BM02_R1+BISI_LBL_1KM_BM02_R2+BISI_LBL_1KM_BM02_R3+BISI_LBL_1KM_BM02_R4+BISI_LBL_1KM_BM02_R5


# create and write response function
RF_BISI_LBL_1KM_BM02_R0=np.diff(BISI_LBL_1KM_BM02_R0)/2
RF_BISI_LBL_1KM_BM02_R1=np.diff(BISI_LBL_1KM_BM02_R1)/2
RF_BISI_LBL_1KM_BM02_R2=np.diff(BISI_LBL_1KM_BM02_R2)/2
RF_BISI_LBL_1KM_BM02_R3=np.diff(BISI_LBL_1KM_BM02_R3)/2
RF_BISI_LBL_1KM_BM02_R4=np.diff(BISI_LBL_1KM_BM02_R4)/2
RF_BISI_LBL_1KM_BM02_R5=np.diff(BISI_LBL_1KM_BM02_R5)/2
RF_BISI_LBL_1KM_BM02_SU=np.diff(BISI_LBL_1KM_BM02_SU)/2

RF_BISI_LBL_1KM_BM02_R0=np.append(RF_BISI_LBL_1KM_BM02_R0[0],RF_BISI_LBL_1KM_BM02_R0)
RF_BISI_LBL_1KM_BM02_R1=np.append(RF_BISI_LBL_1KM_BM02_R1[0],RF_BISI_LBL_1KM_BM02_R1)
RF_BISI_LBL_1KM_BM02_R2=np.append(RF_BISI_LBL_1KM_BM02_R2[0],RF_BISI_LBL_1KM_BM02_R2)
RF_BISI_LBL_1KM_BM02_R3=np.append(RF_BISI_LBL_1KM_BM02_R3[0],RF_BISI_LBL_1KM_BM02_R3)
RF_BISI_LBL_1KM_BM02_R4=np.append(RF_BISI_LBL_1KM_BM02_R4[0],RF_BISI_LBL_1KM_BM02_R4)
RF_BISI_LBL_1KM_BM02_R5=np.append(RF_BISI_LBL_1KM_BM02_R5[0],RF_BISI_LBL_1KM_BM02_R5)
RF_BISI_LBL_1KM_BM02_SU=np.append(RF_BISI_LBL_1KM_BM02_SU[0],RF_BISI_LBL_1KM_BM02_SU)


# plot
plt.plot(BISI_LBL_1KM_BM02_R0,label="BISI_LBL_1KM_BM02_R0")
plt.plot(BISI_LBL_1KM_BM02_R1,label="BISI_LBL_1KM_BM02_R1")
plt.plot(BISI_LBL_1KM_BM02_R2,label="BISI_LBL_1KM_BM02_R2")
plt.plot(BISI_LBL_1KM_BM02_R3,label="BISI_LBL_1KM_BM02_R3")
plt.plot(BISI_LBL_1KM_BM02_R4,label="BISI_LBL_1KM_BM02_R4")
plt.plot(BISI_LBL_1KM_BM02_R5,label="BISI_LBL_1KM_BM02_R5")
plt.plot(BISI_LBL_1KM_BM02_SU,label="BISI_LBL_1KM_BM02_SU")
plt.legend()

print(len(RF_BISI_LBL_1KM_BM02_R2))
# Out:
# 200

# %%
# BISI_LBL
# BM04

fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.6-4.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM04_R0 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM04_R0.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.1-4.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM04_R1 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM04_R1.append(val)

fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.2-4.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM04_R2 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM04_R2.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.3-4.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM04_R3 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM04_R3.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.4-4.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM04_R4 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM04_R4.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.5-4.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM04_R5 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM04_R5.append(val)

# %%
BISI_LBL_1KM_BM04_R0=np.array(BISI_LBL_1KM_BM04_R0)
BISI_LBL_1KM_BM04_R1=np.array(BISI_LBL_1KM_BM04_R1)
BISI_LBL_1KM_BM04_R2=np.array(BISI_LBL_1KM_BM04_R2)
BISI_LBL_1KM_BM04_R3=np.array(BISI_LBL_1KM_BM04_R3)
BISI_LBL_1KM_BM04_R4=np.array(BISI_LBL_1KM_BM04_R4)
BISI_LBL_1KM_BM04_R5=np.array(BISI_LBL_1KM_BM04_R5)

BISI_LBL_1KM_BM04_SU=BISI_LBL_1KM_BM04_R1+BISI_LBL_1KM_BM04_R2+BISI_LBL_1KM_BM04_R3+BISI_LBL_1KM_BM04_R4+BISI_LBL_1KM_BM04_R5


# create and write response function
RF_BISI_LBL_1KM_BM04_R0=np.diff(BISI_LBL_1KM_BM04_R0)/4
RF_BISI_LBL_1KM_BM04_R1=np.diff(BISI_LBL_1KM_BM04_R1)/4
RF_BISI_LBL_1KM_BM04_R2=np.diff(BISI_LBL_1KM_BM04_R2)/4
RF_BISI_LBL_1KM_BM04_R3=np.diff(BISI_LBL_1KM_BM04_R3)/4
RF_BISI_LBL_1KM_BM04_R4=np.diff(BISI_LBL_1KM_BM04_R4)/4
RF_BISI_LBL_1KM_BM04_R5=np.diff(BISI_LBL_1KM_BM04_R5)/4
RF_BISI_LBL_1KM_BM04_SU=np.diff(BISI_LBL_1KM_BM04_SU)/4

RF_BISI_LBL_1KM_BM04_R0=np.append(RF_BISI_LBL_1KM_BM04_R0[0],RF_BISI_LBL_1KM_BM04_R0)
RF_BISI_LBL_1KM_BM04_R1=np.append(RF_BISI_LBL_1KM_BM04_R1[0],RF_BISI_LBL_1KM_BM04_R1)
RF_BISI_LBL_1KM_BM04_R2=np.append(RF_BISI_LBL_1KM_BM04_R2[0],RF_BISI_LBL_1KM_BM04_R2)
RF_BISI_LBL_1KM_BM04_R3=np.append(RF_BISI_LBL_1KM_BM04_R3[0],RF_BISI_LBL_1KM_BM04_R3)
RF_BISI_LBL_1KM_BM04_R4=np.append(RF_BISI_LBL_1KM_BM04_R4[0],RF_BISI_LBL_1KM_BM04_R4)
RF_BISI_LBL_1KM_BM04_R5=np.append(RF_BISI_LBL_1KM_BM04_R5[0],RF_BISI_LBL_1KM_BM04_R5)
RF_BISI_LBL_1KM_BM04_SU=np.append(RF_BISI_LBL_1KM_BM04_SU[0],RF_BISI_LBL_1KM_BM04_SU)


# plot
plt.plot(BISI_LBL_1KM_BM04_R0,label="BISI_LBL_1KM_BM04_R0")
plt.plot(BISI_LBL_1KM_BM04_R1,label="BISI_LBL_1KM_BM04_R1")
plt.plot(BISI_LBL_1KM_BM04_R2,label="BISI_LBL_1KM_BM04_R2")
plt.plot(BISI_LBL_1KM_BM04_R3,label="BISI_LBL_1KM_BM04_R3")
plt.plot(BISI_LBL_1KM_BM04_R4,label="BISI_LBL_1KM_BM04_R4")
plt.plot(BISI_LBL_1KM_BM04_R5,label="BISI_LBL_1KM_BM04_R5")
plt.plot(BISI_LBL_1KM_BM04_SU,label="BISI_LBL_1KM_BM04_SU")
plt.legend()

print(len(RF_BISI_LBL_1KM_BM04_R2))
# Out:
# 200

# %%
# BISI_LBL
# BM08

fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.6-8.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM08_R0 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM08_R0.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.1-8.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM08_R1 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM08_R1.append(val)

fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.2-8.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM08_R2 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM08_R2.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.3-8.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM08_R3 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM08_R3.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.4-8.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM08_R4 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM08_R4.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.5-8.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM08_R5 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM08_R5.append(val)

# %%
BISI_LBL_1KM_BM08_R0=np.array(BISI_LBL_1KM_BM08_R0)
BISI_LBL_1KM_BM08_R1=np.array(BISI_LBL_1KM_BM08_R1)
BISI_LBL_1KM_BM08_R2=np.array(BISI_LBL_1KM_BM08_R2)
BISI_LBL_1KM_BM08_R3=np.array(BISI_LBL_1KM_BM08_R3)
BISI_LBL_1KM_BM08_R4=np.array(BISI_LBL_1KM_BM08_R4)
BISI_LBL_1KM_BM08_R5=np.array(BISI_LBL_1KM_BM08_R5)

BISI_LBL_1KM_BM08_SU=BISI_LBL_1KM_BM08_R1+BISI_LBL_1KM_BM08_R2+BISI_LBL_1KM_BM08_R3+BISI_LBL_1KM_BM08_R4+BISI_LBL_1KM_BM08_R5


# create and write response function
RF_BISI_LBL_1KM_BM08_R0=np.diff(BISI_LBL_1KM_BM08_R0)/8
RF_BISI_LBL_1KM_BM08_R1=np.diff(BISI_LBL_1KM_BM08_R1)/8
RF_BISI_LBL_1KM_BM08_R2=np.diff(BISI_LBL_1KM_BM08_R2)/8
RF_BISI_LBL_1KM_BM08_R3=np.diff(BISI_LBL_1KM_BM08_R3)/8
RF_BISI_LBL_1KM_BM08_R4=np.diff(BISI_LBL_1KM_BM08_R4)/8
RF_BISI_LBL_1KM_BM08_R5=np.diff(BISI_LBL_1KM_BM08_R5)/8
RF_BISI_LBL_1KM_BM08_SU=np.diff(BISI_LBL_1KM_BM08_SU)/8

RF_BISI_LBL_1KM_BM08_R0=np.append(RF_BISI_LBL_1KM_BM08_R0[0],RF_BISI_LBL_1KM_BM08_R0)
RF_BISI_LBL_1KM_BM08_R1=np.append(RF_BISI_LBL_1KM_BM08_R1[0],RF_BISI_LBL_1KM_BM08_R1)
RF_BISI_LBL_1KM_BM08_R2=np.append(RF_BISI_LBL_1KM_BM08_R2[0],RF_BISI_LBL_1KM_BM08_R2)
RF_BISI_LBL_1KM_BM08_R3=np.append(RF_BISI_LBL_1KM_BM08_R3[0],RF_BISI_LBL_1KM_BM08_R3)
RF_BISI_LBL_1KM_BM08_R4=np.append(RF_BISI_LBL_1KM_BM08_R4[0],RF_BISI_LBL_1KM_BM08_R4)
RF_BISI_LBL_1KM_BM08_R5=np.append(RF_BISI_LBL_1KM_BM08_R5[0],RF_BISI_LBL_1KM_BM08_R5)
RF_BISI_LBL_1KM_BM08_SU=np.append(RF_BISI_LBL_1KM_BM08_SU[0],RF_BISI_LBL_1KM_BM08_SU)


# plot
plt.plot(BISI_LBL_1KM_BM08_R0,label="BISI_LBL_1KM_BM08_R0")
plt.plot(BISI_LBL_1KM_BM08_R1,label="BISI_LBL_1KM_BM08_R1")
plt.plot(BISI_LBL_1KM_BM08_R2,label="BISI_LBL_1KM_BM08_R2")
plt.plot(BISI_LBL_1KM_BM08_R3,label="BISI_LBL_1KM_BM08_R3")
plt.plot(BISI_LBL_1KM_BM08_R4,label="BISI_LBL_1KM_BM08_R4")
plt.plot(BISI_LBL_1KM_BM08_R5,label="BISI_LBL_1KM_BM08_R5")
plt.plot(BISI_LBL_1KM_BM08_SU,label="BISI_LBL_1KM_BM08_SU")
plt.legend()

print(len(RF_BISI_LBL_1KM_BM08_R2))
# Out:
# 200

# %%
# BISI_LBL
# BM16

fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.6-16.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM16_R0 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM16_R0.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.1-16.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM16_R1 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM16_R1.append(val)

fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.2-16.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM16_R2 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM16_R2.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.3-16.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM16_R3 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM16_R3.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.4-16.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM16_R4 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM16_R4.append(val)
    
fname = "larmip_data/BISI_LBL/VaFDiffControl-SLE-larmip.5-16.1km" # File to read
with open(fname) as f:
    time = np.array([float(row[:17]) for row in f])
with open(fname) as f:
    sl = -np.array([float(row[18:])/1000 for row in f])
BISI_LBL_1KM_BM16_R5 = []
for t in range(200):
    ind = 0
    for i in range(len(time)):
        if time[i]<=t and time[i+1]:
            ind = i
    val = sl[ind]+(t-time[ind])/(time[ind+1]-time[ind])*(sl[ind+1]-sl[ind])
    BISI_LBL_1KM_BM16_R5.append(val)

# %%
BISI_LBL_1KM_BM16_R0=np.array(BISI_LBL_1KM_BM16_R0)
BISI_LBL_1KM_BM16_R1=np.array(BISI_LBL_1KM_BM16_R1)
BISI_LBL_1KM_BM16_R2=np.array(BISI_LBL_1KM_BM16_R2)
BISI_LBL_1KM_BM16_R3=np.array(BISI_LBL_1KM_BM16_R3)
BISI_LBL_1KM_BM16_R4=np.array(BISI_LBL_1KM_BM16_R4)
BISI_LBL_1KM_BM16_R5=np.array(BISI_LBL_1KM_BM16_R5)

BISI_LBL_1KM_BM16_SU=BISI_LBL_1KM_BM16_R1+BISI_LBL_1KM_BM16_R2+BISI_LBL_1KM_BM16_R3+BISI_LBL_1KM_BM16_R4+BISI_LBL_1KM_BM16_R5


# create and write response function
RF_BISI_LBL_1KM_BM16_R0=np.diff(BISI_LBL_1KM_BM16_R0)/16
RF_BISI_LBL_1KM_BM16_R1=np.diff(BISI_LBL_1KM_BM16_R1)/16
RF_BISI_LBL_1KM_BM16_R2=np.diff(BISI_LBL_1KM_BM16_R2)/16
RF_BISI_LBL_1KM_BM16_R3=np.diff(BISI_LBL_1KM_BM16_R3)/16
RF_BISI_LBL_1KM_BM16_R4=np.diff(BISI_LBL_1KM_BM16_R4)/16
RF_BISI_LBL_1KM_BM16_R5=np.diff(BISI_LBL_1KM_BM16_R5)/16
RF_BISI_LBL_1KM_BM16_SU=np.diff(BISI_LBL_1KM_BM16_SU)/16

RF_BISI_LBL_1KM_BM16_R0=np.append(RF_BISI_LBL_1KM_BM16_R0[0],RF_BISI_LBL_1KM_BM16_R0)
RF_BISI_LBL_1KM_BM16_R1=np.append(RF_BISI_LBL_1KM_BM16_R1[0],RF_BISI_LBL_1KM_BM16_R1)
RF_BISI_LBL_1KM_BM16_R2=np.append(RF_BISI_LBL_1KM_BM16_R2[0],RF_BISI_LBL_1KM_BM16_R2)
RF_BISI_LBL_1KM_BM16_R3=np.append(RF_BISI_LBL_1KM_BM16_R3[0],RF_BISI_LBL_1KM_BM16_R3)
RF_BISI_LBL_1KM_BM16_R4=np.append(RF_BISI_LBL_1KM_BM16_R4[0],RF_BISI_LBL_1KM_BM16_R4)
RF_BISI_LBL_1KM_BM16_R5=np.append(RF_BISI_LBL_1KM_BM16_R5[0],RF_BISI_LBL_1KM_BM16_R5)
RF_BISI_LBL_1KM_BM16_SU=np.append(RF_BISI_LBL_1KM_BM16_SU[0],RF_BISI_LBL_1KM_BM16_SU)


# plot
plt.plot(BISI_LBL_1KM_BM16_R0,label="BISI_LBL_1KM_BM16_R0")
plt.plot(BISI_LBL_1KM_BM16_R1,label="BISI_LBL_1KM_BM16_R1")
plt.plot(BISI_LBL_1KM_BM16_R2,label="BISI_LBL_1KM_BM16_R2")
plt.plot(BISI_LBL_1KM_BM16_R3,label="BISI_LBL_1KM_BM16_R3")
plt.plot(BISI_LBL_1KM_BM16_R4,label="BISI_LBL_1KM_BM16_R4")
plt.plot(BISI_LBL_1KM_BM16_R5,label="BISI_LBL_1KM_BM16_R5")
plt.plot(BISI_LBL_1KM_BM16_SU,label="BISI_LBL_1KM_BM16_SU")
plt.legend()

print(len(RF_BISI_LBL_1KM_BM16_R2))
# Out:
# 200

# %%
# Response functions
np.savetxt("RF_BISI_LBL_1KM_BM02_R0.dat", RF_BISI_LBL_1KM_BM02_R0, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM02_R1.dat", RF_BISI_LBL_1KM_BM02_R1, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM02_R2.dat", RF_BISI_LBL_1KM_BM02_R2, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM02_R3.dat", RF_BISI_LBL_1KM_BM02_R3, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM02_R4.dat", RF_BISI_LBL_1KM_BM02_R4, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM02_R5.dat", RF_BISI_LBL_1KM_BM02_R5, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM02_SU.dat", RF_BISI_LBL_1KM_BM02_SU, delimiter=",")

# %%
# Response functions
np.savetxt("RF_BISI_LBL_1KM_BM04_R0.dat", RF_BISI_LBL_1KM_BM04_R0, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM04_R1.dat", RF_BISI_LBL_1KM_BM04_R1, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM04_R2.dat", RF_BISI_LBL_1KM_BM04_R2, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM04_R3.dat", RF_BISI_LBL_1KM_BM04_R3, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM04_R4.dat", RF_BISI_LBL_1KM_BM04_R4, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM04_R5.dat", RF_BISI_LBL_1KM_BM04_R5, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM04_SU.dat", RF_BISI_LBL_1KM_BM04_SU, delimiter=",")

# %%
# Response functions
np.savetxt("RF_BISI_LBL_1KM_BM08_R0.dat", RF_BISI_LBL_1KM_BM08_R0, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM08_R1.dat", RF_BISI_LBL_1KM_BM08_R1, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM08_R2.dat", RF_BISI_LBL_1KM_BM08_R2, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM08_R3.dat", RF_BISI_LBL_1KM_BM08_R3, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM08_R4.dat", RF_BISI_LBL_1KM_BM08_R4, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM08_R5.dat", RF_BISI_LBL_1KM_BM08_R5, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM08_SU.dat", RF_BISI_LBL_1KM_BM08_SU, delimiter=",")

# %%
# Response functions
np.savetxt("RF_BISI_LBL_1KM_BM16_R0.dat", RF_BISI_LBL_1KM_BM16_R0, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM16_R1.dat", RF_BISI_LBL_1KM_BM16_R1, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM16_R2.dat", RF_BISI_LBL_1KM_BM16_R2, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM16_R3.dat", RF_BISI_LBL_1KM_BM16_R3, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM16_R4.dat", RF_BISI_LBL_1KM_BM16_R4, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM16_R5.dat", RF_BISI_LBL_1KM_BM16_R5, delimiter=",")
np.savetxt("RF_BISI_LBL_1KM_BM16_SU.dat", RF_BISI_LBL_1KM_BM16_SU, delimiter=",")

# %%
# Experiments
np.savetxt("BISI_LBL_1KM_BM02_R0.dat", BISI_LBL_1KM_BM02_R0, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM02_R1.dat", BISI_LBL_1KM_BM02_R1, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM02_R2.dat", BISI_LBL_1KM_BM02_R2, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM02_R3.dat", BISI_LBL_1KM_BM02_R3, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM02_R4.dat", BISI_LBL_1KM_BM02_R4, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM02_R5.dat", BISI_LBL_1KM_BM02_R5, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM02_SU.dat", BISI_LBL_1KM_BM02_SU, delimiter=",")

# %%
# Experiments
np.savetxt("BISI_LBL_1KM_BM04_R0.dat", BISI_LBL_1KM_BM04_R0, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM04_R1.dat", BISI_LBL_1KM_BM04_R1, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM04_R2.dat", BISI_LBL_1KM_BM04_R2, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM04_R3.dat", BISI_LBL_1KM_BM04_R3, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM04_R4.dat", BISI_LBL_1KM_BM04_R4, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM04_R5.dat", BISI_LBL_1KM_BM04_R5, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM04_SU.dat", BISI_LBL_1KM_BM04_SU, delimiter=",")

# %%
# Experiments
np.savetxt("BISI_LBL_1KM_BM08_R0.dat", BISI_LBL_1KM_BM08_R0, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM08_R1.dat", BISI_LBL_1KM_BM08_R1, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM08_R2.dat", BISI_LBL_1KM_BM08_R2, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM08_R3.dat", BISI_LBL_1KM_BM08_R3, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM08_R4.dat", BISI_LBL_1KM_BM08_R4, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM08_R5.dat", BISI_LBL_1KM_BM08_R5, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM08_SU.dat", BISI_LBL_1KM_BM08_SU, delimiter=",")

# %%
# Experiments
np.savetxt("BISI_LBL_1KM_BM16_R0.dat", BISI_LBL_1KM_BM16_R0, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM16_R1.dat", BISI_LBL_1KM_BM16_R1, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM16_R2.dat", BISI_LBL_1KM_BM16_R2, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM16_R3.dat", BISI_LBL_1KM_BM16_R3, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM16_R4.dat", BISI_LBL_1KM_BM16_R4, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM16_R5.dat", BISI_LBL_1KM_BM16_R5, delimiter=",")
np.savetxt("BISI_LBL_1KM_BM16_SU.dat", BISI_LBL_1KM_BM16_SU, delimiter=",")
