# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv

# %%
# CISM_NCA = CISM_NCAR
# Experiment BM01

fname="larmip_data/CISM/NCAR_CISM_4km_1my/NCAR_CISM_4km_AllRegions_1m.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
CISM_NCA_BM01_R0 = ncf.variables["slc"][:]/1000
CISM_NCA_BM01_R0_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_1my/NCAR_CISM_4km_EAIS_1m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM01_R1 = ncf.variables["slc"][:]/1000
CISM_NCA_BM01_R1_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_1my/NCAR_CISM_4km_Ross_1m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM01_R2 = ncf.variables["slc"][:]/1000
CISM_NCA_BM01_R2_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_1my/NCAR_CISM_4km_Amundsen_1m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM01_R3 = ncf.variables["slc"][:]/1000
CISM_NCA_BM01_R3_time = ncf.variables["Time"][:]


fname="larmip_data/CISM/NCAR_CISM_4km_1my/NCAR_CISM_4km_Weddell_1m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM01_R4 = ncf.variables["slc"][:]/1000
CISM_NCA_BM01_R4_time = ncf.variables["Time"][:]


fname="larmip_data/CISM/NCAR_CISM_4km_1my/NCAR_CISM_4km_Peninsula_1m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM01_R5 = ncf.variables["slc"][:]/1000
CISM_NCA_BM01_R5_time = ncf.variables["Time"][:]


CISM_NCA_BM01_SU = CISM_NCA_BM01_R1+CISM_NCA_BM01_R2+CISM_NCA_BM01_R3+CISM_NCA_BM01_R4+CISM_NCA_BM01_R5


# create and save response functions

RF_CISM_NCA_BM01_R0=np.diff(CISM_NCA_BM01_R0)/np.diff(CISM_NCA_BM01_R0_time)/1
RF_CISM_NCA_BM01_R1=np.diff(CISM_NCA_BM01_R1)/np.diff(CISM_NCA_BM01_R1_time)/1
RF_CISM_NCA_BM01_R2=np.diff(CISM_NCA_BM01_R2)/np.diff(CISM_NCA_BM01_R2_time)/1
RF_CISM_NCA_BM01_R3=np.diff(CISM_NCA_BM01_R3)/np.diff(CISM_NCA_BM01_R3_time)/1
RF_CISM_NCA_BM01_R4=np.diff(CISM_NCA_BM01_R4)/np.diff(CISM_NCA_BM01_R4_time)/1
RF_CISM_NCA_BM01_R5=np.diff(CISM_NCA_BM01_R5)/np.diff(CISM_NCA_BM01_R5_time)/1
RF_CISM_NCA_BM01_SU=np.diff(CISM_NCA_BM01_SU)/np.diff(CISM_NCA_BM01_R0_time)/1

# plot
plt.plot(CISM_NCA_BM01_R0,label="CISM_NCA_BM01_R0")
plt.plot(CISM_NCA_BM01_R1,label="CISM_NCA_BM01_R1")
plt.plot(CISM_NCA_BM01_R2,label="CISM_NCA_BM01_R2")
plt.plot(CISM_NCA_BM01_R3,label="CISM_NCA_BM01_R3")
plt.plot(CISM_NCA_BM01_R4,label="CISM_NCA_BM01_R4")
plt.plot(CISM_NCA_BM01_R5,label="CISM_NCA_BM01_R5")
plt.plot(CISM_NCA_BM01_SU,label="CISM_NCA_BM01_SU")
plt.legend()

# %%
# CISM_NCA = CISM_NCAR
# Experiment BM02

fname="larmip_data/CISM/NCAR_CISM_4km_2my/NCAR_CISM_4km_AllRegions_2m.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
CISM_NCA_BM02_R0 = ncf.variables["slc"][:]/1000
CISM_NCA_BM02_R0_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_2my/NCAR_CISM_4km_EAIS_2m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM02_R1 = ncf.variables["slc"][:]/1000
CISM_NCA_BM02_R1_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_2my/NCAR_CISM_4km_Ross_2m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM02_R2 = ncf.variables["slc"][:]/1000
CISM_NCA_BM02_R2_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_2my/NCAR_CISM_4km_Amundsen_2m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM02_R3 = ncf.variables["slc"][:]/1000
CISM_NCA_BM02_R3_time = ncf.variables["Time"][:]


fname="larmip_data/CISM/NCAR_CISM_4km_2my/NCAR_CISM_4km_Weddell_2m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM02_R4 = ncf.variables["slc"][:]/1000
CISM_NCA_BM02_R4_time = ncf.variables["Time"][:]


fname="larmip_data/CISM/NCAR_CISM_4km_2my/NCAR_CISM_4km_Peninsula_2m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM02_R5 = ncf.variables["slc"][:]/1000
CISM_NCA_BM02_R5_time = ncf.variables["Time"][:]


CISM_NCA_BM02_SU = CISM_NCA_BM02_R1+CISM_NCA_BM02_R2+CISM_NCA_BM02_R3+CISM_NCA_BM02_R4+CISM_NCA_BM02_R5


# create and save response functions

RF_CISM_NCA_BM02_R0=np.diff(CISM_NCA_BM02_R0)/np.diff(CISM_NCA_BM02_R0_time)/2
RF_CISM_NCA_BM02_R1=np.diff(CISM_NCA_BM02_R1)/np.diff(CISM_NCA_BM02_R1_time)/2
RF_CISM_NCA_BM02_R2=np.diff(CISM_NCA_BM02_R2)/np.diff(CISM_NCA_BM02_R2_time)/2
RF_CISM_NCA_BM02_R3=np.diff(CISM_NCA_BM02_R3)/np.diff(CISM_NCA_BM02_R3_time)/2
RF_CISM_NCA_BM02_R4=np.diff(CISM_NCA_BM02_R4)/np.diff(CISM_NCA_BM02_R4_time)/2
RF_CISM_NCA_BM02_R5=np.diff(CISM_NCA_BM02_R5)/np.diff(CISM_NCA_BM02_R5_time)/2
RF_CISM_NCA_BM02_SU=np.diff(CISM_NCA_BM02_SU)/np.diff(CISM_NCA_BM02_R0_time)/2


# plot
plt.plot(CISM_NCA_BM02_R0,label="CISM_NCA_BM02_R0")
plt.plot(CISM_NCA_BM02_R1,label="CISM_NCA_BM02_R1")
plt.plot(CISM_NCA_BM02_R2,label="CISM_NCA_BM02_R2")
plt.plot(CISM_NCA_BM02_R3,label="CISM_NCA_BM02_R3")
plt.plot(CISM_NCA_BM02_R4,label="CISM_NCA_BM02_R4")
plt.plot(CISM_NCA_BM02_R5,label="CISM_NCA_BM02_R5")
plt.plot(CISM_NCA_BM02_SU,label="CISM_NCA_BM02_SU")
plt.legend()

# %%
# CISM_NCA = CISM_NCAR
# Experiment BM04

fname="larmip_data/CISM/NCAR_CISM_4km_4my/NCAR_CISM_4km_AllRegions_4m.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
CISM_NCA_BM04_R0 = ncf.variables["slc"][:]/1000
CISM_NCA_BM04_R0_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_4my/NCAR_CISM_4km_EAIS_4m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM04_R1 = ncf.variables["slc"][:]/1000
CISM_NCA_BM04_R1_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_4my/NCAR_CISM_4km_Ross_4m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM04_R2 = ncf.variables["slc"][:]/1000
CISM_NCA_BM04_R2_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_4my/NCAR_CISM_4km_Amundsen_4m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM04_R3 = ncf.variables["slc"][:]/1000
CISM_NCA_BM04_R3_time = ncf.variables["Time"][:]


fname="larmip_data/CISM/NCAR_CISM_4km_4my/NCAR_CISM_4km_Weddell_4m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM04_R4 = ncf.variables["slc"][:]/1000
CISM_NCA_BM04_R4_time = ncf.variables["Time"][:]


fname="larmip_data/CISM/NCAR_CISM_4km_4my/NCAR_CISM_4km_Peninsula_4m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM04_R5 = ncf.variables["slc"][:]/1000
CISM_NCA_BM04_R5_time = ncf.variables["Time"][:]


CISM_NCA_BM04_SU = CISM_NCA_BM04_R1+CISM_NCA_BM04_R2+CISM_NCA_BM04_R3+CISM_NCA_BM04_R4+CISM_NCA_BM04_R5


# create and save response functions

RF_CISM_NCA_BM04_R0=np.diff(CISM_NCA_BM04_R0)/np.diff(CISM_NCA_BM04_R0_time)/4
RF_CISM_NCA_BM04_R1=np.diff(CISM_NCA_BM04_R1)/np.diff(CISM_NCA_BM04_R1_time)/4
RF_CISM_NCA_BM04_R2=np.diff(CISM_NCA_BM04_R2)/np.diff(CISM_NCA_BM04_R2_time)/4
RF_CISM_NCA_BM04_R3=np.diff(CISM_NCA_BM04_R3)/np.diff(CISM_NCA_BM04_R3_time)/4
RF_CISM_NCA_BM04_R4=np.diff(CISM_NCA_BM04_R4)/np.diff(CISM_NCA_BM04_R4_time)/4
RF_CISM_NCA_BM04_R5=np.diff(CISM_NCA_BM04_R5)/np.diff(CISM_NCA_BM04_R5_time)/4
RF_CISM_NCA_BM04_SU=np.diff(CISM_NCA_BM04_SU)/np.diff(CISM_NCA_BM04_R0_time)/4


# plot
plt.plot(CISM_NCA_BM04_R0,label="CISM_NCA_BM04_R0")
plt.plot(CISM_NCA_BM04_R1,label="CISM_NCA_BM04_R1")
plt.plot(CISM_NCA_BM04_R2,label="CISM_NCA_BM04_R2")
plt.plot(CISM_NCA_BM04_R3,label="CISM_NCA_BM04_R3")
plt.plot(CISM_NCA_BM04_R4,label="CISM_NCA_BM04_R4")
plt.plot(CISM_NCA_BM04_R5,label="CISM_NCA_BM04_R5")
plt.plot(CISM_NCA_BM04_SU,label="CISM_NCA_BM04_SU")
plt.legend()

# %%
# CISM_NCA = CISM_NCAR
# Experiment BM08

fname="larmip_data/CISM/NCAR_CISM_4km_8my/NCAR_CISM_4km_AllRegions_8m.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
CISM_NCA_BM08_R0 = ncf.variables["slc"][:]/1000
CISM_NCA_BM08_R0_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_8my/NCAR_CISM_4km_EAIS_8m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM08_R1 = ncf.variables["slc"][:]/1000
CISM_NCA_BM08_R1_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_8my/NCAR_CISM_4km_Ross_8m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM08_R2 = ncf.variables["slc"][:]/1000
CISM_NCA_BM08_R2_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_8my/NCAR_CISM_4km_Amundsen_8m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM08_R3 = ncf.variables["slc"][:]/1000
CISM_NCA_BM08_R3_time = ncf.variables["Time"][:]


fname="larmip_data/CISM/NCAR_CISM_4km_8my/NCAR_CISM_4km_Weddell_8m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM08_R4 = ncf.variables["slc"][:]/1000
CISM_NCA_BM08_R4_time = ncf.variables["Time"][:]


fname="larmip_data/CISM/NCAR_CISM_4km_8my/NCAR_CISM_4km_Peninsula_8m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM08_R5 = ncf.variables["slc"][:]/1000
CISM_NCA_BM08_R5_time = ncf.variables["Time"][:]


CISM_NCA_BM08_SU = CISM_NCA_BM08_R1+CISM_NCA_BM08_R2+CISM_NCA_BM08_R3+CISM_NCA_BM08_R4+CISM_NCA_BM08_R5


# create and save response functions

RF_CISM_NCA_BM08_R0=np.diff(CISM_NCA_BM08_R0)/np.diff(CISM_NCA_BM08_R0_time)/8
RF_CISM_NCA_BM08_R1=np.diff(CISM_NCA_BM08_R1)/np.diff(CISM_NCA_BM08_R1_time)/8
RF_CISM_NCA_BM08_R2=np.diff(CISM_NCA_BM08_R2)/np.diff(CISM_NCA_BM08_R2_time)/8
RF_CISM_NCA_BM08_R3=np.diff(CISM_NCA_BM08_R3)/np.diff(CISM_NCA_BM08_R3_time)/8
RF_CISM_NCA_BM08_R4=np.diff(CISM_NCA_BM08_R4)/np.diff(CISM_NCA_BM08_R4_time)/8
RF_CISM_NCA_BM08_R5=np.diff(CISM_NCA_BM08_R5)/np.diff(CISM_NCA_BM08_R5_time)/8
RF_CISM_NCA_BM08_SU=np.diff(CISM_NCA_BM08_SU)/np.diff(CISM_NCA_BM08_R0_time)/8


# plot
plt.plot(CISM_NCA_BM08_R0,label="CISM_NCA_BM08_R0")
plt.plot(CISM_NCA_BM08_R1,label="CISM_NCA_BM08_R1")
plt.plot(CISM_NCA_BM08_R2,label="CISM_NCA_BM08_R2")
plt.plot(CISM_NCA_BM08_R3,label="CISM_NCA_BM08_R3")
plt.plot(CISM_NCA_BM08_R4,label="CISM_NCA_BM08_R4")
plt.plot(CISM_NCA_BM08_R5,label="CISM_NCA_BM08_R5")
plt.plot(CISM_NCA_BM08_SU,label="CISM_NCA_BM08_SU")
plt.legend()

# %%
# CISM_NCA = CISM_NCAR
# Experiment BM16

fname="larmip_data/CISM/NCAR_CISM_4km_16my/NCAR_CISM_4km_AllRegions_16m.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
CISM_NCA_BM16_R0 = ncf.variables["slc"][:]/1000
CISM_NCA_BM16_R0_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_16my/NCAR_CISM_4km_EAIS_16m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM16_R1 = ncf.variables["slc"][:]/1000
CISM_NCA_BM16_R1_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_16my/NCAR_CISM_4km_Ross_16m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM16_R2 = ncf.variables["slc"][:]/1000
CISM_NCA_BM16_R2_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_16my/NCAR_CISM_4km_Amundsen_16m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM16_R3 = ncf.variables["slc"][:]/1000
CISM_NCA_BM16_R3_time = ncf.variables["Time"][:]


fname="larmip_data/CISM/NCAR_CISM_4km_16my/NCAR_CISM_4km_Weddell_16m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM16_R4 = ncf.variables["slc"][:]/1000
CISM_NCA_BM16_R4_time = ncf.variables["Time"][:]


fname="larmip_data/CISM/NCAR_CISM_4km_16my/NCAR_CISM_4km_Peninsula_16m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM16_R5 = ncf.variables["slc"][:]/1000
CISM_NCA_BM16_R5_time = ncf.variables["Time"][:]


CISM_NCA_BM16_SU = CISM_NCA_BM16_R1+CISM_NCA_BM16_R2+CISM_NCA_BM16_R3+CISM_NCA_BM16_R4+CISM_NCA_BM16_R5


# create and save response functions

RF_CISM_NCA_BM16_R0=np.diff(CISM_NCA_BM16_R0)/np.diff(CISM_NCA_BM16_R0_time)/16
RF_CISM_NCA_BM16_R1=np.diff(CISM_NCA_BM16_R1)/np.diff(CISM_NCA_BM16_R1_time)/16
RF_CISM_NCA_BM16_R2=np.diff(CISM_NCA_BM16_R2)/np.diff(CISM_NCA_BM16_R2_time)/16
RF_CISM_NCA_BM16_R3=np.diff(CISM_NCA_BM16_R3)/np.diff(CISM_NCA_BM16_R3_time)/16
RF_CISM_NCA_BM16_R4=np.diff(CISM_NCA_BM16_R4)/np.diff(CISM_NCA_BM16_R4_time)/16
RF_CISM_NCA_BM16_R5=np.diff(CISM_NCA_BM16_R5)/np.diff(CISM_NCA_BM16_R5_time)/16
RF_CISM_NCA_BM16_SU=np.diff(CISM_NCA_BM16_SU)/np.diff(CISM_NCA_BM16_R0_time)/16


# plot
plt.plot(CISM_NCA_BM16_R0,label="CISM_NCA_BM16_R0")
plt.plot(CISM_NCA_BM16_R1,label="CISM_NCA_BM16_R1")
plt.plot(CISM_NCA_BM16_R2,label="CISM_NCA_BM16_R2")
plt.plot(CISM_NCA_BM16_R3,label="CISM_NCA_BM16_R3")
plt.plot(CISM_NCA_BM16_R4,label="CISM_NCA_BM16_R4")
plt.plot(CISM_NCA_BM16_R5,label="CISM_NCA_BM16_R5")
plt.plot(CISM_NCA_BM16_SU,label="CISM_NCA_BM16_SU")
plt.legend()

# %%
# CISM_NCA = CISM_NCAR
# Experiment BM32

fname="larmip_data/CISM/NCAR_CISM_4km_32my/NCAR_CISM_4km_AllRegions_32m.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
CISM_NCA_BM32_R0 = ncf.variables["slc"][:]/1000
CISM_NCA_BM32_R0_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_32my/NCAR_CISM_4km_EAIS_32m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM32_R1 = ncf.variables["slc"][:]/1000
CISM_NCA_BM32_R1_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_32my/NCAR_CISM_4km_Ross_32m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM32_R2 = ncf.variables["slc"][:]/1000
CISM_NCA_BM32_R2_time = ncf.variables["Time"][:]

fname="larmip_data/CISM/NCAR_CISM_4km_32my/NCAR_CISM_4km_Amundsen_32m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM32_R3 = ncf.variables["slc"][:]/1000
CISM_NCA_BM32_R3_time = ncf.variables["Time"][:]


fname="larmip_data/CISM/NCAR_CISM_4km_32my/NCAR_CISM_4km_Weddell_32m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM32_R4 = ncf.variables["slc"][:]/1000
CISM_NCA_BM32_R4_time = ncf.variables["Time"][:]


fname="larmip_data/CISM/NCAR_CISM_4km_32my/NCAR_CISM_4km_Peninsula_32m.nc"
ncf = nc.Dataset(fname, "r")
#ncf.variables.keys()
CISM_NCA_BM32_R5 = ncf.variables["slc"][:]/1000
CISM_NCA_BM32_R5_time = ncf.variables["Time"][:]


CISM_NCA_BM32_SU = CISM_NCA_BM32_R1+CISM_NCA_BM32_R2+CISM_NCA_BM32_R3+CISM_NCA_BM32_R4+CISM_NCA_BM32_R5


# create and save response functions

RF_CISM_NCA_BM32_R0=np.diff(CISM_NCA_BM32_R0)/np.diff(CISM_NCA_BM32_R0_time)/32
RF_CISM_NCA_BM32_R1=np.diff(CISM_NCA_BM32_R1)/np.diff(CISM_NCA_BM32_R1_time)/32
RF_CISM_NCA_BM32_R2=np.diff(CISM_NCA_BM32_R2)/np.diff(CISM_NCA_BM32_R2_time)/32
RF_CISM_NCA_BM32_R3=np.diff(CISM_NCA_BM32_R3)/np.diff(CISM_NCA_BM32_R3_time)/32
RF_CISM_NCA_BM32_R4=np.diff(CISM_NCA_BM32_R4)/np.diff(CISM_NCA_BM32_R4_time)/32
RF_CISM_NCA_BM32_R5=np.diff(CISM_NCA_BM32_R5)/np.diff(CISM_NCA_BM32_R5_time)/32
RF_CISM_NCA_BM32_SU=np.diff(CISM_NCA_BM32_SU)/np.diff(CISM_NCA_BM32_R0_time)/32


# plot
plt.plot(CISM_NCA_BM32_R0,label="CISM_NCA_BM32_R0")
plt.plot(CISM_NCA_BM32_R1,label="CISM_NCA_BM32_R1")
plt.plot(CISM_NCA_BM32_R2,label="CISM_NCA_BM32_R2")
plt.plot(CISM_NCA_BM32_R3,label="CISM_NCA_BM32_R3")
plt.plot(CISM_NCA_BM32_R4,label="CISM_NCA_BM32_R4")
plt.plot(CISM_NCA_BM32_R5,label="CISM_NCA_BM32_R5")
plt.plot(CISM_NCA_BM32_SU,label="CISM_NCA_BM32_SU")
plt.legend()

# %%
# Compare response functions

plt.plot(RF_CISM_NCA_BM01_R0,label="RF_CISM_NCA_BM01_R0")
plt.plot(RF_CISM_NCA_BM02_R0,label="RF_CISM_NCA_BM02_R0")
plt.plot(RF_CISM_NCA_BM04_R0,label="RF_CISM_NCA_BM04_R0")
plt.plot(RF_CISM_NCA_BM08_R0,label="RF_CISM_NCA_BM08_R0")
plt.plot(RF_CISM_NCA_BM16_R0,label="RF_CISM_NCA_BM16_R0")
plt.plot(RF_CISM_NCA_BM32_R0,label="RF_CISM_NCA_BM32_R0")
plt.title("All regions")
# Out:
# Text(0.5,1,'All regions')

# %%
# Response functions
np.savetxt("RF_CISM_NCA_BM01_R0.dat", RF_CISM_NCA_BM01_R0, delimiter=",")
np.savetxt("RF_CISM_NCA_BM01_R1.dat", RF_CISM_NCA_BM01_R1, delimiter=",")
np.savetxt("RF_CISM_NCA_BM01_R2.dat", RF_CISM_NCA_BM01_R2, delimiter=",")
np.savetxt("RF_CISM_NCA_BM01_R3.dat", RF_CISM_NCA_BM01_R3, delimiter=",")
np.savetxt("RF_CISM_NCA_BM01_R4.dat", RF_CISM_NCA_BM01_R4, delimiter=",")
np.savetxt("RF_CISM_NCA_BM01_R5.dat", RF_CISM_NCA_BM01_R5, delimiter=",")
np.savetxt("RF_CISM_NCA_BM01_SU.dat", RF_CISM_NCA_BM01_SU, delimiter=",")

# %%
np.savetxt("RF_CISM_NCA_BM02_R0.dat", RF_CISM_NCA_BM02_R0, delimiter=",")
np.savetxt("RF_CISM_NCA_BM02_R1.dat", RF_CISM_NCA_BM02_R1, delimiter=",")
np.savetxt("RF_CISM_NCA_BM02_R2.dat", RF_CISM_NCA_BM02_R2, delimiter=",")
np.savetxt("RF_CISM_NCA_BM02_R3.dat", RF_CISM_NCA_BM02_R3, delimiter=",")
np.savetxt("RF_CISM_NCA_BM02_R4.dat", RF_CISM_NCA_BM02_R4, delimiter=",")
np.savetxt("RF_CISM_NCA_BM02_R5.dat", RF_CISM_NCA_BM02_R5, delimiter=",")
np.savetxt("RF_CISM_NCA_BM02_SU.dat", RF_CISM_NCA_BM02_SU, delimiter=",")

# %%
np.savetxt("RF_CISM_NCA_BM04_R0.dat", RF_CISM_NCA_BM04_R0, delimiter=",")
np.savetxt("RF_CISM_NCA_BM04_R1.dat", RF_CISM_NCA_BM04_R1, delimiter=",")
np.savetxt("RF_CISM_NCA_BM04_R2.dat", RF_CISM_NCA_BM04_R2, delimiter=",")
np.savetxt("RF_CISM_NCA_BM04_R3.dat", RF_CISM_NCA_BM04_R3, delimiter=",")
np.savetxt("RF_CISM_NCA_BM04_R4.dat", RF_CISM_NCA_BM04_R4, delimiter=",")
np.savetxt("RF_CISM_NCA_BM04_R5.dat", RF_CISM_NCA_BM04_R5, delimiter=",")
np.savetxt("RF_CISM_NCA_BM04_SU.dat", RF_CISM_NCA_BM04_SU, delimiter=",")

# %%
np.savetxt("RF_CISM_NCA_BM08_R0.dat", RF_CISM_NCA_BM08_R0, delimiter=",")
np.savetxt("RF_CISM_NCA_BM08_R1.dat", RF_CISM_NCA_BM08_R1, delimiter=",")
np.savetxt("RF_CISM_NCA_BM08_R2.dat", RF_CISM_NCA_BM08_R2, delimiter=",")
np.savetxt("RF_CISM_NCA_BM08_R3.dat", RF_CISM_NCA_BM08_R3, delimiter=",")
np.savetxt("RF_CISM_NCA_BM08_R4.dat", RF_CISM_NCA_BM08_R4, delimiter=",")
np.savetxt("RF_CISM_NCA_BM08_R5.dat", RF_CISM_NCA_BM08_R5, delimiter=",")
np.savetxt("RF_CISM_NCA_BM08_SU.dat", RF_CISM_NCA_BM08_SU, delimiter=",")

# %%
np.savetxt("RF_CISM_NCA_BM16_R0.dat", RF_CISM_NCA_BM16_R0, delimiter=",")
np.savetxt("RF_CISM_NCA_BM16_R1.dat", RF_CISM_NCA_BM16_R1, delimiter=",")
np.savetxt("RF_CISM_NCA_BM16_R2.dat", RF_CISM_NCA_BM16_R2, delimiter=",")
np.savetxt("RF_CISM_NCA_BM16_R3.dat", RF_CISM_NCA_BM16_R3, delimiter=",")
np.savetxt("RF_CISM_NCA_BM16_R4.dat", RF_CISM_NCA_BM16_R4, delimiter=",")
np.savetxt("RF_CISM_NCA_BM16_R5.dat", RF_CISM_NCA_BM16_R5, delimiter=",")
np.savetxt("RF_CISM_NCA_BM16_SU.dat", RF_CISM_NCA_BM16_SU, delimiter=",")

# %%
np.savetxt("RF_CISM_NCA_BM32_R0.dat", RF_CISM_NCA_BM32_R0, delimiter=",")
np.savetxt("RF_CISM_NCA_BM32_R1.dat", RF_CISM_NCA_BM32_R1, delimiter=",")
np.savetxt("RF_CISM_NCA_BM32_R2.dat", RF_CISM_NCA_BM32_R2, delimiter=",")
np.savetxt("RF_CISM_NCA_BM32_R3.dat", RF_CISM_NCA_BM32_R3, delimiter=",")
np.savetxt("RF_CISM_NCA_BM32_R4.dat", RF_CISM_NCA_BM32_R4, delimiter=",")
np.savetxt("RF_CISM_NCA_BM32_R5.dat", RF_CISM_NCA_BM32_R5, delimiter=",")
np.savetxt("RF_CISM_NCA_BM32_SU.dat", RF_CISM_NCA_BM32_SU, delimiter=",")

# %%
# Experiments
np.savetxt("CISM_NCA_BM01_R0.dat", CISM_NCA_BM01_R0, delimiter=",")
np.savetxt("CISM_NCA_BM01_R1.dat", CISM_NCA_BM01_R1, delimiter=",")
np.savetxt("CISM_NCA_BM01_R2.dat", CISM_NCA_BM01_R2, delimiter=",")
np.savetxt("CISM_NCA_BM01_R3.dat", CISM_NCA_BM01_R3, delimiter=",")
np.savetxt("CISM_NCA_BM01_R4.dat", CISM_NCA_BM01_R4, delimiter=",")
np.savetxt("CISM_NCA_BM01_R5.dat", CISM_NCA_BM01_R5, delimiter=",")
np.savetxt("CISM_NCA_BM01_SU.dat", CISM_NCA_BM01_SU, delimiter=",")

# %%
np.savetxt("CISM_NCA_BM02_R0.dat", CISM_NCA_BM02_R0, delimiter=",")
np.savetxt("CISM_NCA_BM02_R1.dat", CISM_NCA_BM02_R1, delimiter=",")
np.savetxt("CISM_NCA_BM02_R2.dat", CISM_NCA_BM02_R2, delimiter=",")
np.savetxt("CISM_NCA_BM02_R3.dat", CISM_NCA_BM02_R3, delimiter=",")
np.savetxt("CISM_NCA_BM02_R4.dat", CISM_NCA_BM02_R4, delimiter=",")
np.savetxt("CISM_NCA_BM02_R5.dat", CISM_NCA_BM02_R5, delimiter=",")
np.savetxt("CISM_NCA_BM02_SU.dat", CISM_NCA_BM02_SU, delimiter=",")

# %%
np.savetxt("CISM_NCA_BM04_R0.dat", CISM_NCA_BM04_R0, delimiter=",")
np.savetxt("CISM_NCA_BM04_R1.dat", CISM_NCA_BM04_R1, delimiter=",")
np.savetxt("CISM_NCA_BM04_R2.dat", CISM_NCA_BM04_R2, delimiter=",")
np.savetxt("CISM_NCA_BM04_R3.dat", CISM_NCA_BM04_R3, delimiter=",")
np.savetxt("CISM_NCA_BM04_R4.dat", CISM_NCA_BM04_R4, delimiter=",")
np.savetxt("CISM_NCA_BM04_R5.dat", CISM_NCA_BM04_R5, delimiter=",")
np.savetxt("CISM_NCA_BM04_SU.dat", CISM_NCA_BM04_SU, delimiter=",")

# %%
np.savetxt("CISM_NCA_BM08_R0.dat", CISM_NCA_BM08_R0, delimiter=",")
np.savetxt("CISM_NCA_BM08_R1.dat", CISM_NCA_BM08_R1, delimiter=",")
np.savetxt("CISM_NCA_BM08_R2.dat", CISM_NCA_BM08_R2, delimiter=",")
np.savetxt("CISM_NCA_BM08_R3.dat", CISM_NCA_BM08_R3, delimiter=",")
np.savetxt("CISM_NCA_BM08_R4.dat", CISM_NCA_BM08_R4, delimiter=",")
np.savetxt("CISM_NCA_BM08_R5.dat", CISM_NCA_BM08_R5, delimiter=",")
np.savetxt("CISM_NCA_BM08_SU.dat", CISM_NCA_BM08_SU, delimiter=",")

# %%
np.savetxt("CISM_NCA_BM16_R0.dat", CISM_NCA_BM16_R0, delimiter=",")
np.savetxt("CISM_NCA_BM16_R1.dat", CISM_NCA_BM16_R1, delimiter=",")
np.savetxt("CISM_NCA_BM16_R2.dat", CISM_NCA_BM16_R2, delimiter=",")
np.savetxt("CISM_NCA_BM16_R3.dat", CISM_NCA_BM16_R3, delimiter=",")
np.savetxt("CISM_NCA_BM16_R4.dat", CISM_NCA_BM16_R4, delimiter=",")
np.savetxt("CISM_NCA_BM16_R5.dat", CISM_NCA_BM16_R5, delimiter=",")
np.savetxt("CISM_NCA_BM16_SU.dat", CISM_NCA_BM16_SU, delimiter=",")

# %%
np.savetxt("CISM_NCA_BM32_R0.dat", CISM_NCA_BM32_R0, delimiter=",")
np.savetxt("CISM_NCA_BM32_R1.dat", CISM_NCA_BM32_R1, delimiter=",")
np.savetxt("CISM_NCA_BM32_R2.dat", CISM_NCA_BM32_R2, delimiter=",")
np.savetxt("CISM_NCA_BM32_R3.dat", CISM_NCA_BM32_R3, delimiter=",")
np.savetxt("CISM_NCA_BM32_R4.dat", CISM_NCA_BM32_R4, delimiter=",")
np.savetxt("CISM_NCA_BM32_R5.dat", CISM_NCA_BM32_R5, delimiter=",")
np.savetxt("CISM_NCA_BM32_SU.dat", CISM_NCA_BM32_SU, delimiter=",")
