# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv
#import pandas

# %%
slfact = -1e15 / 3.61e14 * 910 / 1000 # m3 / m2
print(slfact)
# Out:
# -2.5207756232686984

# %%
# GRIS_LSC = GRISLI_LSCE
# Experiment BM01

fname = "larmip_data/GRISLI_LSCE/ADD1_EAIS.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM01_R1 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM01_R1=np.array([x*slfact for x in GRIS_LSC_BM01_R1[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD1_Ross.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM01_R2 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM01_R2=np.array([x*slfact for x in GRIS_LSC_BM01_R2[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD1_Amundsen.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM01_R3 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM01_R3=np.array([x*slfact for x in GRIS_LSC_BM01_R3[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD1_Weddell.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM01_R4 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM01_R4=np.array([x*slfact for x in GRIS_LSC_BM01_R4[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD1_Peninsula.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM01_R5 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM01_R5=np.array([x*slfact for x in GRIS_LSC_BM01_R5[0:]])

GRIS_LSC_BM01_SU = GRIS_LSC_BM01_R1+GRIS_LSC_BM01_R2+GRIS_LSC_BM01_R3+GRIS_LSC_BM01_R4+GRIS_LSC_BM01_R5

# create and write response function
RF_GRIS_LSC_BM01_R1=np.diff(GRIS_LSC_BM01_R1)/1
RF_GRIS_LSC_BM01_R2=np.diff(GRIS_LSC_BM01_R2)/1
RF_GRIS_LSC_BM01_R3=np.diff(GRIS_LSC_BM01_R3)/1
RF_GRIS_LSC_BM01_R4=np.diff(GRIS_LSC_BM01_R4)/1
RF_GRIS_LSC_BM01_R5=np.diff(GRIS_LSC_BM01_R5)/1
RF_GRIS_LSC_BM01_SU=np.diff(GRIS_LSC_BM01_SU)/1


# plot
plt.plot(GRIS_LSC_BM01_R1,label="GRIS_LSC_BM01_R1")
plt.plot(GRIS_LSC_BM01_R2,label="GRIS_LSC_BM01_R2")
plt.plot(GRIS_LSC_BM01_R3,label="GRIS_LSC_BM01_R3")
plt.plot(GRIS_LSC_BM01_R4,label="GRIS_LSC_BM01_R4")
plt.plot(GRIS_LSC_BM01_R5,label="GRIS_LSC_BM01_R5")
plt.plot(GRIS_LSC_BM01_SU,label="GRIS_LSC_BM01_SU")
plt.legend()

print(len(RF_GRIS_LSC_BM01_R1))
# Out:
# 200

# %%
# GRIS_LSC = GRISLI_LSCE
# Experiment BM02

fname = "larmip_data/GRISLI_LSCE/ADD3_all.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM02_R0 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM02_R0=np.array([x*slfact for x in GRIS_LSC_BM02_R0[0:]])

fname = "larmip_data/GRISLI_LSCE/CORE_EAIS.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM02_R1 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM02_R1=np.array([x*slfact for x in GRIS_LSC_BM02_R1[0:]])

fname = "larmip_data/GRISLI_LSCE/CORE_Ross.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM02_R2 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM02_R2=np.array([x*slfact for x in GRIS_LSC_BM02_R2[0:]])

fname = "larmip_data/GRISLI_LSCE/CORE_Amundsen.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM02_R3 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM02_R3=np.array([x*slfact for x in GRIS_LSC_BM02_R3[0:]])

fname = "larmip_data/GRISLI_LSCE/CORE_Weddell.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM02_R4 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM02_R4=np.array([x*slfact for x in GRIS_LSC_BM02_R4[0:]])

fname = "larmip_data/GRISLI_LSCE/CORE_Peninsula.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM02_R5 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM02_R5=np.array([x*slfact for x in GRIS_LSC_BM02_R5[0:]])


GRIS_LSC_BM02_SU = GRIS_LSC_BM02_R1+GRIS_LSC_BM02_R2+GRIS_LSC_BM02_R3+GRIS_LSC_BM02_R4+GRIS_LSC_BM02_R5

# create and write response function
RF_GRIS_LSC_BM02_R0=np.diff(GRIS_LSC_BM02_R0)/2
RF_GRIS_LSC_BM02_R1=np.diff(GRIS_LSC_BM02_R1)/2
RF_GRIS_LSC_BM02_R2=np.diff(GRIS_LSC_BM02_R2)/2
RF_GRIS_LSC_BM02_R3=np.diff(GRIS_LSC_BM02_R3)/2
RF_GRIS_LSC_BM02_R4=np.diff(GRIS_LSC_BM02_R4)/2
RF_GRIS_LSC_BM02_R5=np.diff(GRIS_LSC_BM02_R5)/2
RF_GRIS_LSC_BM02_SU=np.diff(GRIS_LSC_BM02_SU)/2


# plot
plt.plot(GRIS_LSC_BM02_R0,label="GRIS_LSC_BM02_R0")
plt.plot(GRIS_LSC_BM02_R1,label="GRIS_LSC_BM02_R1")
plt.plot(GRIS_LSC_BM02_R2,label="GRIS_LSC_BM02_R2")
plt.plot(GRIS_LSC_BM02_R3,label="GRIS_LSC_BM02_R3")
plt.plot(GRIS_LSC_BM02_R4,label="GRIS_LSC_BM02_R4")
plt.plot(GRIS_LSC_BM02_R5,label="GRIS_LSC_BM02_R5")
plt.plot(GRIS_LSC_BM02_SU,label="GRIS_LSC_BM02_SU")
plt.legend()

print(len(RF_GRIS_LSC_BM02_R1))
# Out:
# 200

# %%
# GRIS_LSC = GRISLI_LSCE
# Experiment BM04

fname = "larmip_data/GRISLI_LSCE/ADD2_EAIS.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM04_R1 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM04_R1=np.array([x*slfact for x in GRIS_LSC_BM04_R1[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD2_Ross.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM04_R2 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM04_R2=np.array([x*slfact for x in GRIS_LSC_BM04_R2[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD2_Amundsen.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM04_R3 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM04_R3=np.array([x*slfact for x in GRIS_LSC_BM04_R3[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD2_Weddell.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM04_R4 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM04_R4=np.array([x*slfact for x in GRIS_LSC_BM04_R4[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD2_Peninsula.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM04_R5 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM04_R5=np.array([x*slfact for x in GRIS_LSC_BM04_R5[0:]])


GRIS_LSC_BM04_SU = GRIS_LSC_BM04_R1+GRIS_LSC_BM04_R2+GRIS_LSC_BM04_R3+GRIS_LSC_BM04_R4+GRIS_LSC_BM04_R5

# create and write response function
RF_GRIS_LSC_BM04_R1=np.diff(GRIS_LSC_BM04_R1)/4
RF_GRIS_LSC_BM04_R2=np.diff(GRIS_LSC_BM04_R2)/4
RF_GRIS_LSC_BM04_R3=np.diff(GRIS_LSC_BM04_R3)/4
RF_GRIS_LSC_BM04_R4=np.diff(GRIS_LSC_BM04_R4)/4
RF_GRIS_LSC_BM04_R5=np.diff(GRIS_LSC_BM04_R5)/4
RF_GRIS_LSC_BM04_SU=np.diff(GRIS_LSC_BM04_SU)/4


# plot
plt.plot(GRIS_LSC_BM04_R1,label="GRIS_LSC_BM04_R1")
plt.plot(GRIS_LSC_BM04_R2,label="GRIS_LSC_BM04_R2")
plt.plot(GRIS_LSC_BM04_R3,label="GRIS_LSC_BM04_R3")
plt.plot(GRIS_LSC_BM04_R4,label="GRIS_LSC_BM04_R4")
plt.plot(GRIS_LSC_BM04_R5,label="GRIS_LSC_BM04_R5")
plt.plot(GRIS_LSC_BM04_SU,label="GRIS_LSC_BM04_SU")
plt.legend()

print(len(RF_GRIS_LSC_BM04_R1))
# Out:
# 200

# %%
# GRIS_LSC = GRISLI_LSCE
# Experiment BM08

fname = "larmip_data/GRISLI_LSCE/ADD4_EAIS.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM08_R1 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM08_R1=np.array([x*slfact for x in GRIS_LSC_BM08_R1[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD4_Ross.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM08_R2 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM08_R2=np.array([x*slfact for x in GRIS_LSC_BM08_R2[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD4_Amundsen.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM08_R3 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM08_R3=np.array([x*slfact for x in GRIS_LSC_BM08_R3[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD4_Weddell.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM08_R4 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM08_R4=np.array([x*slfact for x in GRIS_LSC_BM08_R4[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD4_Peninsula.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM08_R5 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM08_R5=np.array([x*slfact for x in GRIS_LSC_BM08_R5[0:]])


GRIS_LSC_BM08_SU = GRIS_LSC_BM08_R1+GRIS_LSC_BM08_R2+GRIS_LSC_BM08_R3+GRIS_LSC_BM08_R4+GRIS_LSC_BM08_R5

# create and write response function
RF_GRIS_LSC_BM08_R1=np.diff(GRIS_LSC_BM08_R1)/8
RF_GRIS_LSC_BM08_R2=np.diff(GRIS_LSC_BM08_R2)/8
RF_GRIS_LSC_BM08_R3=np.diff(GRIS_LSC_BM08_R3)/8
RF_GRIS_LSC_BM08_R4=np.diff(GRIS_LSC_BM08_R4)/8
RF_GRIS_LSC_BM08_R5=np.diff(GRIS_LSC_BM08_R5)/8
RF_GRIS_LSC_BM08_SU=np.diff(GRIS_LSC_BM08_SU)/8


# plot
plt.plot(GRIS_LSC_BM08_R1,label="GRIS_LSC_BM08_R1")
plt.plot(GRIS_LSC_BM08_R2,label="GRIS_LSC_BM08_R2")
plt.plot(GRIS_LSC_BM08_R3,label="GRIS_LSC_BM08_R3")
plt.plot(GRIS_LSC_BM08_R4,label="GRIS_LSC_BM08_R4")
plt.plot(GRIS_LSC_BM08_R5,label="GRIS_LSC_BM08_R5")
plt.plot(GRIS_LSC_BM08_SU,label="GRIS_LSC_BM08_SU")
plt.legend()

print(len(RF_GRIS_LSC_BM08_R1))
# Out:
# 200

# %%
# GRIS_LSC = GRISLI_LSCE
# Experiment BM16

fname = "larmip_data/GRISLI_LSCE/ADD6_EAIS.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM16_R1 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM16_R1=np.array([x*slfact for x in GRIS_LSC_BM16_R1[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD6_Ross.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM16_R2 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM16_R2=np.array([x*slfact for x in GRIS_LSC_BM16_R2[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD6_Amundsen.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM16_R3 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM16_R3=np.array([x*slfact for x in GRIS_LSC_BM16_R3[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD6_Weddell.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM16_R4 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM16_R4=np.array([x*slfact for x in GRIS_LSC_BM16_R4[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD6_Peninsula.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM16_R5 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM16_R5=np.array([x*slfact for x in GRIS_LSC_BM16_R5[0:]])


GRIS_LSC_BM16_SU = GRIS_LSC_BM16_R1+GRIS_LSC_BM16_R2+GRIS_LSC_BM16_R3+GRIS_LSC_BM16_R4+GRIS_LSC_BM16_R5

# create and write response function
RF_GRIS_LSC_BM16_R1=np.diff(GRIS_LSC_BM16_R1)/16
RF_GRIS_LSC_BM16_R2=np.diff(GRIS_LSC_BM16_R2)/16
RF_GRIS_LSC_BM16_R3=np.diff(GRIS_LSC_BM16_R3)/16
RF_GRIS_LSC_BM16_R4=np.diff(GRIS_LSC_BM16_R4)/16
RF_GRIS_LSC_BM16_R5=np.diff(GRIS_LSC_BM16_R5)/16
RF_GRIS_LSC_BM16_SU=np.diff(GRIS_LSC_BM16_SU)/16


# plot
plt.plot(GRIS_LSC_BM16_R1,label="GRIS_LSC_BM16_R1")
plt.plot(GRIS_LSC_BM16_R2,label="GRIS_LSC_BM16_R2")
plt.plot(GRIS_LSC_BM16_R3,label="GRIS_LSC_BM16_R3")
plt.plot(GRIS_LSC_BM16_R4,label="GRIS_LSC_BM16_R4")
plt.plot(GRIS_LSC_BM16_R5,label="GRIS_LSC_BM16_R5")
plt.plot(GRIS_LSC_BM16_SU,label="GRIS_LSC_BM16_SU")
plt.legend()

print(len(RF_GRIS_LSC_BM16_R1))
# Out:
# 200

# %%
# GRIS_LSC = GRISLI_LSCE
# Experiment BM32

fname = "larmip_data/GRISLI_LSCE/ADD5_EAIS.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM32_R1 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM32_R1=np.array([x*slfact for x in GRIS_LSC_BM32_R1[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD5_Ross.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM32_R2 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM32_R2=np.array([x*slfact for x in GRIS_LSC_BM32_R2[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD5_Amundsen.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM32_R3 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM32_R3=np.array([x*slfact for x in GRIS_LSC_BM32_R3[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD5_Weddell.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM32_R4 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM32_R4=np.array([x*slfact for x in GRIS_LSC_BM32_R4[0:]])

fname = "larmip_data/GRISLI_LSCE/ADD5_Peninsula.txt" # File to read   
with open(fname) as f:
    GRIS_LSC_BM32_R5 = [float(row.split(" ")[1]) for row in f]
GRIS_LSC_BM32_R5=np.array([x*slfact for x in GRIS_LSC_BM32_R5[0:]])


GRIS_LSC_BM32_SU = GRIS_LSC_BM32_R1+GRIS_LSC_BM32_R2+GRIS_LSC_BM32_R3+GRIS_LSC_BM32_R4+GRIS_LSC_BM32_R5

# create and write response function
RF_GRIS_LSC_BM32_R1=np.diff(GRIS_LSC_BM32_R1)/32
RF_GRIS_LSC_BM32_R2=np.diff(GRIS_LSC_BM32_R2)/32
RF_GRIS_LSC_BM32_R3=np.diff(GRIS_LSC_BM32_R3)/32
RF_GRIS_LSC_BM32_R4=np.diff(GRIS_LSC_BM32_R4)/32
RF_GRIS_LSC_BM32_R5=np.diff(GRIS_LSC_BM32_R5)/32
RF_GRIS_LSC_BM32_SU=np.diff(GRIS_LSC_BM32_SU)/32


# plot
plt.plot(GRIS_LSC_BM32_R1,label="GRIS_LSC_BM32_R1")
plt.plot(GRIS_LSC_BM32_R2,label="GRIS_LSC_BM32_R2")
plt.plot(GRIS_LSC_BM32_R3,label="GRIS_LSC_BM32_R3")
plt.plot(GRIS_LSC_BM32_R4,label="GRIS_LSC_BM32_R4")
plt.plot(GRIS_LSC_BM32_R5,label="GRIS_LSC_BM32_R5")
plt.plot(GRIS_LSC_BM32_SU,label="GRIS_LSC_BM32_SU")
plt.legend()

print(len(RF_GRIS_LSC_BM32_R1))
# Out:
# 200

# %%
np.savetxt("RF_GRIS_LSC_BM01_R1.dat", RF_GRIS_LSC_BM01_R1, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM01_R2.dat", RF_GRIS_LSC_BM01_R2, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM01_R3.dat", RF_GRIS_LSC_BM01_R3, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM01_R4.dat", RF_GRIS_LSC_BM01_R4, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM01_R5.dat", RF_GRIS_LSC_BM01_R5, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM01_SU.dat", RF_GRIS_LSC_BM01_SU, delimiter=",")

# %%
np.savetxt("RF_GRIS_LSC_BM02_R0.dat", RF_GRIS_LSC_BM02_R0, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM02_R1.dat", RF_GRIS_LSC_BM02_R1, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM02_R2.dat", RF_GRIS_LSC_BM02_R2, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM02_R3.dat", RF_GRIS_LSC_BM02_R3, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM02_R4.dat", RF_GRIS_LSC_BM02_R4, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM02_R5.dat", RF_GRIS_LSC_BM02_R5, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM02_SU.dat", RF_GRIS_LSC_BM02_SU, delimiter=",")

# %%
np.savetxt("RF_GRIS_LSC_BM04_R1.dat", RF_GRIS_LSC_BM04_R1, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM04_R2.dat", RF_GRIS_LSC_BM04_R2, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM04_R3.dat", RF_GRIS_LSC_BM04_R3, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM04_R4.dat", RF_GRIS_LSC_BM04_R4, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM04_R5.dat", RF_GRIS_LSC_BM04_R5, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM04_SU.dat", RF_GRIS_LSC_BM04_SU, delimiter=",")

# %%
np.savetxt("RF_GRIS_LSC_BM08_R1.dat", RF_GRIS_LSC_BM08_R1, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM08_R2.dat", RF_GRIS_LSC_BM08_R2, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM08_R3.dat", RF_GRIS_LSC_BM08_R3, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM08_R4.dat", RF_GRIS_LSC_BM08_R4, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM08_R5.dat", RF_GRIS_LSC_BM08_R5, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM08_SU.dat", RF_GRIS_LSC_BM08_SU, delimiter=",")

# %%
np.savetxt("RF_GRIS_LSC_BM16_R1.dat", RF_GRIS_LSC_BM16_R1, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM16_R2.dat", RF_GRIS_LSC_BM16_R2, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM16_R3.dat", RF_GRIS_LSC_BM16_R3, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM16_R4.dat", RF_GRIS_LSC_BM16_R4, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM16_R5.dat", RF_GRIS_LSC_BM16_R5, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM16_SU.dat", RF_GRIS_LSC_BM16_SU, delimiter=",")

# %%
np.savetxt("RF_GRIS_LSC_BM32_R1.dat", RF_GRIS_LSC_BM32_R1, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM32_R2.dat", RF_GRIS_LSC_BM32_R2, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM32_R3.dat", RF_GRIS_LSC_BM32_R3, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM32_R4.dat", RF_GRIS_LSC_BM32_R4, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM32_R5.dat", RF_GRIS_LSC_BM32_R5, delimiter=",")
np.savetxt("RF_GRIS_LSC_BM32_SU.dat", RF_GRIS_LSC_BM32_SU, delimiter=",")

# %%
# Experiments
np.savetxt("GRIS_LSC_BM01_R1.dat", GRIS_LSC_BM01_R1, delimiter=",")
np.savetxt("GRIS_LSC_BM01_R2.dat", GRIS_LSC_BM01_R2, delimiter=",")
np.savetxt("GRIS_LSC_BM01_R3.dat", GRIS_LSC_BM01_R3, delimiter=",")
np.savetxt("GRIS_LSC_BM01_R4.dat", GRIS_LSC_BM01_R4, delimiter=",")
np.savetxt("GRIS_LSC_BM01_R5.dat", GRIS_LSC_BM01_R5, delimiter=",")
np.savetxt("GRIS_LSC_BM01_SU.dat", GRIS_LSC_BM01_SU, delimiter=",")

# %%
np.savetxt("GRIS_LSC_BM02_R0.dat", GRIS_LSC_BM02_R0, delimiter=",")
np.savetxt("GRIS_LSC_BM02_R1.dat", GRIS_LSC_BM02_R1, delimiter=",")
np.savetxt("GRIS_LSC_BM02_R2.dat", GRIS_LSC_BM02_R2, delimiter=",")
np.savetxt("GRIS_LSC_BM02_R3.dat", GRIS_LSC_BM02_R3, delimiter=",")
np.savetxt("GRIS_LSC_BM02_R4.dat", GRIS_LSC_BM02_R4, delimiter=",")
np.savetxt("GRIS_LSC_BM02_R5.dat", GRIS_LSC_BM02_R5, delimiter=",")
np.savetxt("GRIS_LSC_BM02_SU.dat", GRIS_LSC_BM02_SU, delimiter=",")

# %%
np.savetxt("GRIS_LSC_BM04_R1.dat", GRIS_LSC_BM04_R1, delimiter=",")
np.savetxt("GRIS_LSC_BM04_R2.dat", GRIS_LSC_BM04_R2, delimiter=",")
np.savetxt("GRIS_LSC_BM04_R3.dat", GRIS_LSC_BM04_R3, delimiter=",")
np.savetxt("GRIS_LSC_BM04_R4.dat", GRIS_LSC_BM04_R4, delimiter=",")
np.savetxt("GRIS_LSC_BM04_R5.dat", GRIS_LSC_BM04_R5, delimiter=",")
np.savetxt("GRIS_LSC_BM04_SU.dat", GRIS_LSC_BM04_SU, delimiter=",")

# %%
np.savetxt("GRIS_LSC_BM08_R1.dat", GRIS_LSC_BM08_R1, delimiter=",")
np.savetxt("GRIS_LSC_BM08_R2.dat", GRIS_LSC_BM08_R2, delimiter=",")
np.savetxt("GRIS_LSC_BM08_R3.dat", GRIS_LSC_BM08_R3, delimiter=",")
np.savetxt("GRIS_LSC_BM08_R4.dat", GRIS_LSC_BM08_R4, delimiter=",")
np.savetxt("GRIS_LSC_BM08_R5.dat", GRIS_LSC_BM08_R5, delimiter=",")
np.savetxt("GRIS_LSC_BM08_SU.dat", GRIS_LSC_BM08_SU, delimiter=",")

# %%
np.savetxt("GRIS_LSC_BM16_R1.dat", GRIS_LSC_BM16_R1, delimiter=",")
np.savetxt("GRIS_LSC_BM16_R2.dat", GRIS_LSC_BM16_R2, delimiter=",")
np.savetxt("GRIS_LSC_BM16_R3.dat", GRIS_LSC_BM16_R3, delimiter=",")
np.savetxt("GRIS_LSC_BM16_R4.dat", GRIS_LSC_BM16_R4, delimiter=",")
np.savetxt("GRIS_LSC_BM16_R5.dat", GRIS_LSC_BM16_R5, delimiter=",")
np.savetxt("GRIS_LSC_BM16_SU.dat", GRIS_LSC_BM16_SU, delimiter=",")

# %%
np.savetxt("GRIS_LSC_BM32_R1.dat", GRIS_LSC_BM32_R1, delimiter=",")
np.savetxt("GRIS_LSC_BM32_R2.dat", GRIS_LSC_BM32_R2, delimiter=",")
np.savetxt("GRIS_LSC_BM32_R3.dat", GRIS_LSC_BM32_R3, delimiter=",")
np.savetxt("GRIS_LSC_BM32_R4.dat", GRIS_LSC_BM32_R4, delimiter=",")
np.savetxt("GRIS_LSC_BM32_R5.dat", GRIS_LSC_BM32_R5, delimiter=",")
np.savetxt("GRIS_LSC_BM32_SU.dat", GRIS_LSC_BM32_SU, delimiter=",")
