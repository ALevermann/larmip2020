# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv

# %%
# CISM_NCA = CISM_NCAR
# Control experiment

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Control.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_Control = ncf.variables["limnsw"][:]

# %%
# CISM_NCA = CISM_NCAR
# Experiment BM01

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region6_1.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM01_R0 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM01_R0_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region1_1.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM01_R1 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM01_R1_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region2_1.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM01_R2 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM01_R2_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region3_1.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM01_R3 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM01_R3_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region4_1.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM01_R4 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM01_R4_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region5_1.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM01_R5 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM01_R5_time = ncf.variables["time"][:]

ISSM_JPL_BM01_SU = ISSM_JPL_BM01_R1+ISSM_JPL_BM01_R2+ISSM_JPL_BM01_R3+ISSM_JPL_BM01_R4+ISSM_JPL_BM01_R5 


# create and write response function
RF_ISSM_JPL_BM01_R0=np.diff(ISSM_JPL_BM01_R0)/1
RF_ISSM_JPL_BM01_R1=np.diff(ISSM_JPL_BM01_R1)/1
RF_ISSM_JPL_BM01_R2=np.diff(ISSM_JPL_BM01_R2)/1
RF_ISSM_JPL_BM01_R3=np.diff(ISSM_JPL_BM01_R3)/1
RF_ISSM_JPL_BM01_R4=np.diff(ISSM_JPL_BM01_R4)/1
RF_ISSM_JPL_BM01_R5=np.diff(ISSM_JPL_BM01_R5)/1
RF_ISSM_JPL_BM01_SU=np.diff(ISSM_JPL_BM01_SU)/1


# plot
plt.plot(ISSM_JPL_BM01_R0,label="ISSM_JPL_BM01_R0")
plt.plot(ISSM_JPL_BM01_R1,label="ISSM_JPL_BM01_R1")
plt.plot(ISSM_JPL_BM01_R2,label="ISSM_JPL_BM01_R2")
plt.plot(ISSM_JPL_BM01_R3,label="ISSM_JPL_BM01_R3")
plt.plot(ISSM_JPL_BM01_R4,label="ISSM_JPL_BM01_R4")
plt.plot(ISSM_JPL_BM01_R5,label="ISSM_JPL_BM01_R5")
plt.plot(ISSM_JPL_BM01_SU,label="ISSM_JPL_BM01_SU")
plt.legend()

print(len(RF_ISSM_JPL_BM01_R0))
# Out:
# 200

# %%
# CISM_NCA = CISM_NCAR
# Experiment BM02

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region6_2.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM02_R0 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM02_R0_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region1_2.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM02_R1 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM02_R1_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region2_2.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM02_R2 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM02_R2_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region3_2.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM02_R3 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM02_R3_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region4_2.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM02_R4 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM02_R4_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region5_2.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM02_R5 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM02_R5_time = ncf.variables["time"][:]

ISSM_JPL_BM02_SU = ISSM_JPL_BM02_R1+ISSM_JPL_BM02_R2+ISSM_JPL_BM02_R3+ISSM_JPL_BM02_R4+ISSM_JPL_BM02_R5 


# create and write response function
RF_ISSM_JPL_BM02_R0=np.diff(ISSM_JPL_BM02_R0)/2
RF_ISSM_JPL_BM02_R1=np.diff(ISSM_JPL_BM02_R1)/2
RF_ISSM_JPL_BM02_R2=np.diff(ISSM_JPL_BM02_R2)/2
RF_ISSM_JPL_BM02_R3=np.diff(ISSM_JPL_BM02_R3)/2
RF_ISSM_JPL_BM02_R4=np.diff(ISSM_JPL_BM02_R4)/2
RF_ISSM_JPL_BM02_R5=np.diff(ISSM_JPL_BM02_R5)/2
RF_ISSM_JPL_BM02_SU=np.diff(ISSM_JPL_BM02_SU)/2


# plot
plt.plot(ISSM_JPL_BM02_R0,label="ISSM_JPL_BM02_R0")
plt.plot(ISSM_JPL_BM02_R1,label="ISSM_JPL_BM02_R1")
plt.plot(ISSM_JPL_BM02_R2,label="ISSM_JPL_BM02_R2")
plt.plot(ISSM_JPL_BM02_R3,label="ISSM_JPL_BM02_R3")
plt.plot(ISSM_JPL_BM02_R4,label="ISSM_JPL_BM02_R4")
plt.plot(ISSM_JPL_BM02_R5,label="ISSM_JPL_BM02_R5")
plt.plot(ISSM_JPL_BM02_SU,label="ISSM_JPL_BM02_SU")
plt.legend()

# %%
# CISM_NCA = CISM_NCAR
# Experiment BM04

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region6_4.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM04_R0 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM04_R0_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region1_4.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM04_R1 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM04_R1_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region2_4.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM04_R2 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM04_R2_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region3_4.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM04_R3 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM04_R3_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region4_4.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM04_R4 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM04_R4_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region5_4.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM04_R5 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM04_R5_time = ncf.variables["time"][:]

ISSM_JPL_BM04_SU = ISSM_JPL_BM04_R1+ISSM_JPL_BM04_R2+ISSM_JPL_BM04_R3+ISSM_JPL_BM04_R4+ISSM_JPL_BM04_R5 


# create and write response function
RF_ISSM_JPL_BM04_R0=np.diff(ISSM_JPL_BM04_R0)/4
RF_ISSM_JPL_BM04_R1=np.diff(ISSM_JPL_BM04_R1)/4
RF_ISSM_JPL_BM04_R2=np.diff(ISSM_JPL_BM04_R2)/4
RF_ISSM_JPL_BM04_R3=np.diff(ISSM_JPL_BM04_R3)/4
RF_ISSM_JPL_BM04_R4=np.diff(ISSM_JPL_BM04_R4)/4
RF_ISSM_JPL_BM04_R5=np.diff(ISSM_JPL_BM04_R5)/4
RF_ISSM_JPL_BM04_SU=np.diff(ISSM_JPL_BM04_SU)/4


# plot
plt.plot(ISSM_JPL_BM04_R0,label="ISSM_JPL_BM04_R0")
plt.plot(ISSM_JPL_BM04_R1,label="ISSM_JPL_BM04_R1")
plt.plot(ISSM_JPL_BM04_R2,label="ISSM_JPL_BM04_R2")
plt.plot(ISSM_JPL_BM04_R3,label="ISSM_JPL_BM04_R3")
plt.plot(ISSM_JPL_BM04_R4,label="ISSM_JPL_BM04_R4")
plt.plot(ISSM_JPL_BM04_R5,label="ISSM_JPL_BM04_R5")
plt.plot(ISSM_JPL_BM04_SU,label="ISSM_JPL_BM04_SU")
plt.legend()

# %%
# CISM_NCA = CISM_NCAR
# Experiment BM08

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region6_8.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM08_R0 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM08_R0_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region1_8.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM08_R1 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM08_R1_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region2_8.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM08_R2 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM08_R2_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region3_8.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM08_R3 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM08_R3_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region4_8.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM08_R4 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM08_R4_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region5_8.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM08_R5 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM08_R5_time = ncf.variables["time"][:]

ISSM_JPL_BM08_SU = ISSM_JPL_BM08_R1+ISSM_JPL_BM08_R2+ISSM_JPL_BM08_R3+ISSM_JPL_BM08_R4+ISSM_JPL_BM08_R5 


# create and write response function
RF_ISSM_JPL_BM08_R0=np.diff(ISSM_JPL_BM08_R0)/8
RF_ISSM_JPL_BM08_R1=np.diff(ISSM_JPL_BM08_R1)/8
RF_ISSM_JPL_BM08_R2=np.diff(ISSM_JPL_BM08_R2)/8
RF_ISSM_JPL_BM08_R3=np.diff(ISSM_JPL_BM08_R3)/8
RF_ISSM_JPL_BM08_R4=np.diff(ISSM_JPL_BM08_R4)/8
RF_ISSM_JPL_BM08_R5=np.diff(ISSM_JPL_BM08_R5)/8
RF_ISSM_JPL_BM08_SU=np.diff(ISSM_JPL_BM08_SU)/8


# plot
plt.plot(ISSM_JPL_BM08_R0,label="ISSM_JPL_BM08_R0")
plt.plot(ISSM_JPL_BM08_R1,label="ISSM_JPL_BM08_R1")
plt.plot(ISSM_JPL_BM08_R2,label="ISSM_JPL_BM08_R2")
plt.plot(ISSM_JPL_BM08_R3,label="ISSM_JPL_BM08_R3")
plt.plot(ISSM_JPL_BM08_R4,label="ISSM_JPL_BM08_R4")
plt.plot(ISSM_JPL_BM08_R5,label="ISSM_JPL_BM08_R5")
plt.plot(ISSM_JPL_BM08_SU,label="ISSM_JPL_BM08_SU")
plt.legend()

# %%
# CISM_NCA = CISM_NCAR
# Experiment BM16

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region6_16.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM16_R0 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM16_R0_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region1_16.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM16_R1 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM16_R1_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region2_16.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM16_R2 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM16_R2_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region3_16.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM16_R3 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM16_R3_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region4_16.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM16_R4 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM16_R4_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region5_16.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM16_R5 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM16_R5_time = ncf.variables["time"][:]

ISSM_JPL_BM16_SU = ISSM_JPL_BM16_R1+ISSM_JPL_BM16_R2+ISSM_JPL_BM16_R3+ISSM_JPL_BM16_R4+ISSM_JPL_BM16_R5 


# create and write response function
RF_ISSM_JPL_BM16_R0=np.diff(ISSM_JPL_BM16_R0)/16
RF_ISSM_JPL_BM16_R1=np.diff(ISSM_JPL_BM16_R1)/16
RF_ISSM_JPL_BM16_R2=np.diff(ISSM_JPL_BM16_R2)/16
RF_ISSM_JPL_BM16_R3=np.diff(ISSM_JPL_BM16_R3)/16
RF_ISSM_JPL_BM16_R4=np.diff(ISSM_JPL_BM16_R4)/16
RF_ISSM_JPL_BM16_R5=np.diff(ISSM_JPL_BM16_R5)/16
RF_ISSM_JPL_BM16_SU=np.diff(ISSM_JPL_BM16_SU)/16


# plot
plt.plot(ISSM_JPL_BM16_R0,label="ISSM_JPL_BM16_R0")
plt.plot(ISSM_JPL_BM16_R1,label="ISSM_JPL_BM16_R1")
plt.plot(ISSM_JPL_BM16_R2,label="ISSM_JPL_BM16_R2")
plt.plot(ISSM_JPL_BM16_R3,label="ISSM_JPL_BM16_R3")
plt.plot(ISSM_JPL_BM16_R4,label="ISSM_JPL_BM16_R4")
plt.plot(ISSM_JPL_BM16_R5,label="ISSM_JPL_BM16_R5")
plt.plot(ISSM_JPL_BM16_SU,label="ISSM_JPL_BM16_SU")
plt.legend()

# %%
# CISM_NCA = CISM_NCAR
# Experiment BM32

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region6_32.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM32_R0 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM32_R0_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region1_32.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM32_R1 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM32_R1_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region2_32.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM32_R2 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM32_R2_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region3_32.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM32_R3 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM32_R3_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region4_32.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM32_R4 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM32_R4_time = ncf.variables["time"][:]

fname="larmip_data/ISSM_JPL/scalar_AIS_JPL_ISSM_JPL_LARMIP_Region5_32.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
ISSM_JPL_BM32_R5 = -(ncf.variables["limnsw"][:]-ISSM_JPL_Control)*2.764e-18
ISSM_JPL_BM32_R5_time = ncf.variables["time"][:]

ISSM_JPL_BM32_SU = ISSM_JPL_BM32_R1+ISSM_JPL_BM32_R2+ISSM_JPL_BM32_R3+ISSM_JPL_BM32_R4+ISSM_JPL_BM32_R5 


# create and write response function
RF_ISSM_JPL_BM32_R0=np.diff(ISSM_JPL_BM32_R0)/32
RF_ISSM_JPL_BM32_R1=np.diff(ISSM_JPL_BM32_R1)/32
RF_ISSM_JPL_BM32_R2=np.diff(ISSM_JPL_BM32_R2)/32
RF_ISSM_JPL_BM32_R3=np.diff(ISSM_JPL_BM32_R3)/32
RF_ISSM_JPL_BM32_R4=np.diff(ISSM_JPL_BM32_R4)/32
RF_ISSM_JPL_BM32_R5=np.diff(ISSM_JPL_BM32_R5)/32
RF_ISSM_JPL_BM32_SU=np.diff(ISSM_JPL_BM32_SU)/32


# plot
plt.plot(ISSM_JPL_BM32_R0,label="ISSM_JPL_BM32_R0")
plt.plot(ISSM_JPL_BM32_R1,label="ISSM_JPL_BM32_R1")
plt.plot(ISSM_JPL_BM32_R2,label="ISSM_JPL_BM32_R2")
plt.plot(ISSM_JPL_BM32_R3,label="ISSM_JPL_BM32_R3")
plt.plot(ISSM_JPL_BM32_R4,label="ISSM_JPL_BM32_R4")
plt.plot(ISSM_JPL_BM32_R5,label="ISSM_JPL_BM32_R5")
plt.plot(ISSM_JPL_BM32_SU,label="ISSM_JPL_BM32_SU")
plt.legend()

# %%
# Response functions
np.savetxt("RF_ISSM_JPL_BM01_R0.dat", RF_ISSM_JPL_BM01_R0, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM01_R1.dat", RF_ISSM_JPL_BM01_R1, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM01_R2.dat", RF_ISSM_JPL_BM01_R2, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM01_R3.dat", RF_ISSM_JPL_BM01_R3, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM01_R4.dat", RF_ISSM_JPL_BM01_R4, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM01_R5.dat", RF_ISSM_JPL_BM01_R5, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM01_SU.dat", RF_ISSM_JPL_BM01_SU, delimiter=",")

# %%
np.savetxt("RF_ISSM_JPL_BM02_R0.dat", RF_ISSM_JPL_BM02_R0, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM02_R1.dat", RF_ISSM_JPL_BM02_R1, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM02_R2.dat", RF_ISSM_JPL_BM02_R2, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM02_R3.dat", RF_ISSM_JPL_BM02_R3, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM02_R4.dat", RF_ISSM_JPL_BM02_R4, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM02_R5.dat", RF_ISSM_JPL_BM02_R5, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM02_SU.dat", RF_ISSM_JPL_BM02_SU, delimiter=",")

# %%
np.savetxt("RF_ISSM_JPL_BM04_R0.dat", RF_ISSM_JPL_BM04_R0, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM04_R1.dat", RF_ISSM_JPL_BM04_R1, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM04_R2.dat", RF_ISSM_JPL_BM04_R2, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM04_R3.dat", RF_ISSM_JPL_BM04_R3, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM04_R4.dat", RF_ISSM_JPL_BM04_R4, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM04_R5.dat", RF_ISSM_JPL_BM04_R5, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM04_SU.dat", RF_ISSM_JPL_BM04_SU, delimiter=",")

# %%
np.savetxt("RF_ISSM_JPL_BM08_R0.dat", RF_ISSM_JPL_BM08_R0, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM08_R1.dat", RF_ISSM_JPL_BM08_R1, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM08_R2.dat", RF_ISSM_JPL_BM08_R2, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM08_R3.dat", RF_ISSM_JPL_BM08_R3, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM08_R4.dat", RF_ISSM_JPL_BM08_R4, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM08_R5.dat", RF_ISSM_JPL_BM08_R5, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM08_SU.dat", RF_ISSM_JPL_BM08_SU, delimiter=",")

# %%
np.savetxt("RF_ISSM_JPL_BM16_R0.dat", RF_ISSM_JPL_BM16_R0, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM16_R1.dat", RF_ISSM_JPL_BM16_R1, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM16_R2.dat", RF_ISSM_JPL_BM16_R2, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM16_R3.dat", RF_ISSM_JPL_BM16_R3, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM16_R4.dat", RF_ISSM_JPL_BM16_R4, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM16_R5.dat", RF_ISSM_JPL_BM16_R5, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM16_SU.dat", RF_ISSM_JPL_BM16_SU, delimiter=",")

# %%
np.savetxt("RF_ISSM_JPL_BM32_R0.dat", RF_ISSM_JPL_BM32_R0, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM32_R1.dat", RF_ISSM_JPL_BM32_R1, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM32_R2.dat", RF_ISSM_JPL_BM32_R2, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM32_R3.dat", RF_ISSM_JPL_BM32_R3, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM32_R4.dat", RF_ISSM_JPL_BM32_R4, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM32_R5.dat", RF_ISSM_JPL_BM32_R5, delimiter=",")
np.savetxt("RF_ISSM_JPL_BM32_SU.dat", RF_ISSM_JPL_BM32_SU, delimiter=",")

# %%
# Experiments
np.savetxt("ISSM_JPL_BM01_R0.dat", ISSM_JPL_BM01_R0, delimiter=",")
np.savetxt("ISSM_JPL_BM01_R1.dat", ISSM_JPL_BM01_R1, delimiter=",")
np.savetxt("ISSM_JPL_BM01_R2.dat", ISSM_JPL_BM01_R2, delimiter=",")
np.savetxt("ISSM_JPL_BM01_R3.dat", ISSM_JPL_BM01_R3, delimiter=",")
np.savetxt("ISSM_JPL_BM01_R4.dat", ISSM_JPL_BM01_R4, delimiter=",")
np.savetxt("ISSM_JPL_BM01_R5.dat", ISSM_JPL_BM01_R5, delimiter=",")
np.savetxt("ISSM_JPL_BM01_SU.dat", ISSM_JPL_BM01_SU, delimiter=",")

# %%
np.savetxt("ISSM_JPL_BM02_R0.dat", ISSM_JPL_BM02_R0, delimiter=",")
np.savetxt("ISSM_JPL_BM02_R1.dat", ISSM_JPL_BM02_R1, delimiter=",")
np.savetxt("ISSM_JPL_BM02_R2.dat", ISSM_JPL_BM02_R2, delimiter=",")
np.savetxt("ISSM_JPL_BM02_R3.dat", ISSM_JPL_BM02_R3, delimiter=",")
np.savetxt("ISSM_JPL_BM02_R4.dat", ISSM_JPL_BM02_R4, delimiter=",")
np.savetxt("ISSM_JPL_BM02_R5.dat", ISSM_JPL_BM02_R5, delimiter=",")
np.savetxt("ISSM_JPL_BM02_SU.dat", ISSM_JPL_BM02_SU, delimiter=",")

# %%
np.savetxt("ISSM_JPL_BM04_R0.dat", ISSM_JPL_BM04_R0, delimiter=",")
np.savetxt("ISSM_JPL_BM04_R1.dat", ISSM_JPL_BM04_R1, delimiter=",")
np.savetxt("ISSM_JPL_BM04_R2.dat", ISSM_JPL_BM04_R2, delimiter=",")
np.savetxt("ISSM_JPL_BM04_R3.dat", ISSM_JPL_BM04_R3, delimiter=",")
np.savetxt("ISSM_JPL_BM04_R4.dat", ISSM_JPL_BM04_R4, delimiter=",")
np.savetxt("ISSM_JPL_BM04_R5.dat", ISSM_JPL_BM04_R5, delimiter=",")
np.savetxt("ISSM_JPL_BM04_SU.dat", ISSM_JPL_BM04_SU, delimiter=",")

# %%
np.savetxt("ISSM_JPL_BM08_R0.dat", ISSM_JPL_BM08_R0, delimiter=",")
np.savetxt("ISSM_JPL_BM08_R1.dat", ISSM_JPL_BM08_R1, delimiter=",")
np.savetxt("ISSM_JPL_BM08_R2.dat", ISSM_JPL_BM08_R2, delimiter=",")
np.savetxt("ISSM_JPL_BM08_R3.dat", ISSM_JPL_BM08_R3, delimiter=",")
np.savetxt("ISSM_JPL_BM08_R4.dat", ISSM_JPL_BM08_R4, delimiter=",")
np.savetxt("ISSM_JPL_BM08_R5.dat", ISSM_JPL_BM08_R5, delimiter=",")
np.savetxt("ISSM_JPL_BM08_SU.dat", ISSM_JPL_BM08_SU, delimiter=",")

# %%
np.savetxt("ISSM_JPL_BM16_R0.dat", ISSM_JPL_BM16_R0, delimiter=",")
np.savetxt("ISSM_JPL_BM16_R1.dat", ISSM_JPL_BM16_R1, delimiter=",")
np.savetxt("ISSM_JPL_BM16_R2.dat", ISSM_JPL_BM16_R2, delimiter=",")
np.savetxt("ISSM_JPL_BM16_R3.dat", ISSM_JPL_BM16_R3, delimiter=",")
np.savetxt("ISSM_JPL_BM16_R4.dat", ISSM_JPL_BM16_R4, delimiter=",")
np.savetxt("ISSM_JPL_BM16_R5.dat", ISSM_JPL_BM16_R5, delimiter=",")
np.savetxt("ISSM_JPL_BM16_SU.dat", ISSM_JPL_BM16_SU, delimiter=",")

# %%
np.savetxt("ISSM_JPL_BM32_R0.dat", ISSM_JPL_BM32_R0, delimiter=",")
np.savetxt("ISSM_JPL_BM32_R1.dat", ISSM_JPL_BM32_R1, delimiter=",")
np.savetxt("ISSM_JPL_BM32_R2.dat", ISSM_JPL_BM32_R2, delimiter=",")
np.savetxt("ISSM_JPL_BM32_R3.dat", ISSM_JPL_BM32_R3, delimiter=",")
np.savetxt("ISSM_JPL_BM32_R4.dat", ISSM_JPL_BM32_R4, delimiter=",")
np.savetxt("ISSM_JPL_BM32_R5.dat", ISSM_JPL_BM32_R5, delimiter=",")
np.savetxt("ISSM_JPL_BM32_SU.dat", ISSM_JPL_BM32_SU, delimiter=",")
