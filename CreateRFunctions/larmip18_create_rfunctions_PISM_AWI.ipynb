# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv

# %%
# CISM_NCA = CISM_NCAR
# Control experiment

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_ctrl.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_Control = ncf.variables["slvol"][:]

# %%
# PISM_AWI = PISM_AWI
# Experiment BM01

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_All_abmb01.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM01_R0 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM01_R0_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_EAIS_abmb01.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM01_R1 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM01_R1_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Ross_abmb01.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM01_R2 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM01_R2_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Amundsen_abmb01.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM01_R3 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM01_R3_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Weddell_abmb01.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM01_R4 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM01_R4_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Peninsula_abmb01.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM01_R5 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM01_R5_time = ncf.variables["time"][:]

PISM_AWI_BM01_SU = PISM_AWI_BM01_R1+PISM_AWI_BM01_R2+PISM_AWI_BM01_R3+PISM_AWI_BM01_R4+PISM_AWI_BM01_R5


# create and write response function
RF_PISM_AWI_BM01_R0=np.diff(PISM_AWI_BM01_R0)
RF_PISM_AWI_BM01_R1=np.diff(PISM_AWI_BM01_R1)
RF_PISM_AWI_BM01_R2=np.diff(PISM_AWI_BM01_R2)
RF_PISM_AWI_BM01_R3=np.diff(PISM_AWI_BM01_R3)
RF_PISM_AWI_BM01_R4=np.diff(PISM_AWI_BM01_R4)
RF_PISM_AWI_BM01_R5=np.diff(PISM_AWI_BM01_R5)
RF_PISM_AWI_BM01_SU=np.diff(PISM_AWI_BM01_SU)


# plot
plt.plot(PISM_AWI_BM01_R0,label="PISM_AWI_BM01_R0")
plt.plot(PISM_AWI_BM01_R1,label="PISM_AWI_BM01_R1")
plt.plot(PISM_AWI_BM01_R2,label="PISM_AWI_BM01_R2")
plt.plot(PISM_AWI_BM01_R3,label="PISM_AWI_BM01_R3")
plt.plot(PISM_AWI_BM01_R4,label="PISM_AWI_BM01_R4")
plt.plot(PISM_AWI_BM01_R5,label="PISM_AWI_BM01_R5")
plt.plot(PISM_AWI_BM01_SU,label="PISM_AWI_BM01_SU")
plt.legend()

RF_PISM_AWI_BM01_R0=np.append(RF_PISM_AWI_BM01_R0[0],RF_PISM_AWI_BM01_R0)
RF_PISM_AWI_BM01_R1=np.append(RF_PISM_AWI_BM01_R1[0],RF_PISM_AWI_BM01_R1)
RF_PISM_AWI_BM01_R2=np.append(RF_PISM_AWI_BM01_R2[0],RF_PISM_AWI_BM01_R2)
RF_PISM_AWI_BM01_R3=np.append(RF_PISM_AWI_BM01_R3[0],RF_PISM_AWI_BM01_R3)
RF_PISM_AWI_BM01_R4=np.append(RF_PISM_AWI_BM01_R4[0],RF_PISM_AWI_BM01_R4)
RF_PISM_AWI_BM01_R5=np.append(RF_PISM_AWI_BM01_R5[0],RF_PISM_AWI_BM01_R5)

print(len(RF_PISM_AWI_BM01_R0))
# Out:
# 200

# %%
# PISM_AWI = PISM_AWI
# Experiment BM02

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_All_abmb02.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM02_R0 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM02_R0_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_EAIS_abmb02.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM02_R1 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM02_R1_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Ross_abmb02.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM02_R2 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM02_R2_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Amundsen_abmb02.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM02_R3 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM02_R3_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Weddell_abmb02.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM02_R4 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM02_R4_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Peninsula_abmb02.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM02_R5 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM02_R5_time = ncf.variables["time"][:]

PISM_AWI_BM02_SU = PISM_AWI_BM02_R1+PISM_AWI_BM02_R2+PISM_AWI_BM02_R3+PISM_AWI_BM02_R4+PISM_AWI_BM02_R5


# create and write response function
RF_PISM_AWI_BM02_R0=np.diff(PISM_AWI_BM02_R0)/2
RF_PISM_AWI_BM02_R1=np.diff(PISM_AWI_BM02_R1)/2
RF_PISM_AWI_BM02_R2=np.diff(PISM_AWI_BM02_R2)/2
RF_PISM_AWI_BM02_R3=np.diff(PISM_AWI_BM02_R3)/2
RF_PISM_AWI_BM02_R4=np.diff(PISM_AWI_BM02_R4)/2
RF_PISM_AWI_BM02_R5=np.diff(PISM_AWI_BM02_R5)/2
RF_PISM_AWI_BM02_SU=np.diff(PISM_AWI_BM02_SU)/2


# plot
plt.plot(PISM_AWI_BM02_R0,label="PISM_AWI_BM02_R0")
plt.plot(PISM_AWI_BM02_R1,label="PISM_AWI_BM02_R1")
plt.plot(PISM_AWI_BM02_R2,label="PISM_AWI_BM02_R2")
plt.plot(PISM_AWI_BM02_R3,label="PISM_AWI_BM02_R3")
plt.plot(PISM_AWI_BM02_R4,label="PISM_AWI_BM02_R4")
plt.plot(PISM_AWI_BM02_R5,label="PISM_AWI_BM02_R5")
plt.plot(PISM_AWI_BM02_SU,label="PISM_AWI_BM02_SU")
plt.legend()

RF_PISM_AWI_BM02_R0=np.append(RF_PISM_AWI_BM02_R0[0],RF_PISM_AWI_BM02_R0)
RF_PISM_AWI_BM02_R1=np.append(RF_PISM_AWI_BM02_R1[0],RF_PISM_AWI_BM02_R1)
RF_PISM_AWI_BM02_R2=np.append(RF_PISM_AWI_BM02_R2[0],RF_PISM_AWI_BM02_R2)
RF_PISM_AWI_BM02_R3=np.append(RF_PISM_AWI_BM02_R3[0],RF_PISM_AWI_BM02_R3)
RF_PISM_AWI_BM02_R4=np.append(RF_PISM_AWI_BM02_R4[0],RF_PISM_AWI_BM02_R4)
RF_PISM_AWI_BM02_R5=np.append(RF_PISM_AWI_BM02_R5[0],RF_PISM_AWI_BM02_R5)

print(len(RF_PISM_AWI_BM02_R0))
# Out:
# 200

# %%
# PISM_AWI = PISM_AWI
# Experiment BM04

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_All_abmb04.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM04_R0 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM04_R0_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_EAIS_abmb04.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM04_R1 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM04_R1_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Ross_abmb04.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM04_R2 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM04_R2_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Amundsen_abmb04.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM04_R3 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM04_R3_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Weddell_abmb04.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM04_R4 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM04_R4_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Peninsula_abmb04.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM04_R5 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM04_R5_time = ncf.variables["time"][:]

PISM_AWI_BM04_SU = PISM_AWI_BM04_R1+PISM_AWI_BM04_R2+PISM_AWI_BM04_R3+PISM_AWI_BM04_R4+PISM_AWI_BM04_R5


# create and write response function
RF_PISM_AWI_BM04_R0=np.diff(PISM_AWI_BM04_R0)/4
RF_PISM_AWI_BM04_R1=np.diff(PISM_AWI_BM04_R1)/4
RF_PISM_AWI_BM04_R2=np.diff(PISM_AWI_BM04_R2)/4
RF_PISM_AWI_BM04_R3=np.diff(PISM_AWI_BM04_R3)/4
RF_PISM_AWI_BM04_R4=np.diff(PISM_AWI_BM04_R4)/4
RF_PISM_AWI_BM04_R5=np.diff(PISM_AWI_BM04_R5)/4
RF_PISM_AWI_BM04_SU=np.diff(PISM_AWI_BM04_SU)/4


# plot
plt.plot(PISM_AWI_BM04_R0,label="PISM_AWI_BM04_R0")
plt.plot(PISM_AWI_BM04_R1,label="PISM_AWI_BM04_R1")
plt.plot(PISM_AWI_BM04_R2,label="PISM_AWI_BM04_R2")
plt.plot(PISM_AWI_BM04_R3,label="PISM_AWI_BM04_R3")
plt.plot(PISM_AWI_BM04_R4,label="PISM_AWI_BM04_R4")
plt.plot(PISM_AWI_BM04_R5,label="PISM_AWI_BM04_R5")
plt.plot(PISM_AWI_BM04_SU,label="PISM_AWI_BM04_SU")
plt.legend()

RF_PISM_AWI_BM04_R0=np.append(RF_PISM_AWI_BM04_R0[0],RF_PISM_AWI_BM04_R0)
RF_PISM_AWI_BM04_R1=np.append(RF_PISM_AWI_BM04_R1[0],RF_PISM_AWI_BM04_R1)
RF_PISM_AWI_BM04_R2=np.append(RF_PISM_AWI_BM04_R2[0],RF_PISM_AWI_BM04_R2)
RF_PISM_AWI_BM04_R3=np.append(RF_PISM_AWI_BM04_R3[0],RF_PISM_AWI_BM04_R3)
RF_PISM_AWI_BM04_R4=np.append(RF_PISM_AWI_BM04_R4[0],RF_PISM_AWI_BM04_R4)
RF_PISM_AWI_BM04_R5=np.append(RF_PISM_AWI_BM04_R5[0],RF_PISM_AWI_BM04_R5)

print(len(RF_PISM_AWI_BM04_R0))
# Out:
# 200

# %%
# PISM_AWI = PISM_AWI
# Experiment BM08

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_All_abmb08.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM08_R0 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM08_R0_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_EAIS_abmb08.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM08_R1 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM08_R1_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Ross_abmb08.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM08_R2 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM08_R2_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Amundsen_abmb08.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM08_R3 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM08_R3_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Weddell_abmb08.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM08_R4 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM08_R4_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Peninsula_abmb08.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM08_R5 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM08_R5_time = ncf.variables["time"][:]

PISM_AWI_BM08_SU = PISM_AWI_BM08_R1+PISM_AWI_BM08_R2+PISM_AWI_BM08_R3+PISM_AWI_BM08_R4+PISM_AWI_BM08_R5


# create and write response function
RF_PISM_AWI_BM08_R0=np.diff(PISM_AWI_BM08_R0)/8
RF_PISM_AWI_BM08_R1=np.diff(PISM_AWI_BM08_R1)/8
RF_PISM_AWI_BM08_R2=np.diff(PISM_AWI_BM08_R2)/8
RF_PISM_AWI_BM08_R3=np.diff(PISM_AWI_BM08_R3)/8
RF_PISM_AWI_BM08_R4=np.diff(PISM_AWI_BM08_R4)/8
RF_PISM_AWI_BM08_R5=np.diff(PISM_AWI_BM08_R5)/8
RF_PISM_AWI_BM08_SU=np.diff(PISM_AWI_BM08_SU)/8


# plot
plt.plot(PISM_AWI_BM08_R0,label="PISM_AWI_BM08_R0")
plt.plot(PISM_AWI_BM08_R1,label="PISM_AWI_BM08_R1")
plt.plot(PISM_AWI_BM08_R2,label="PISM_AWI_BM08_R2")
plt.plot(PISM_AWI_BM08_R3,label="PISM_AWI_BM08_R3")
plt.plot(PISM_AWI_BM08_R4,label="PISM_AWI_BM08_R4")
plt.plot(PISM_AWI_BM08_R5,label="PISM_AWI_BM08_R5")
plt.plot(PISM_AWI_BM08_SU,label="PISM_AWI_BM08_SU")
plt.legend()

RF_PISM_AWI_BM08_R0=np.append(RF_PISM_AWI_BM08_R0[0],RF_PISM_AWI_BM08_R0)
RF_PISM_AWI_BM08_R1=np.append(RF_PISM_AWI_BM08_R1[0],RF_PISM_AWI_BM08_R1)
RF_PISM_AWI_BM08_R2=np.append(RF_PISM_AWI_BM08_R2[0],RF_PISM_AWI_BM08_R2)
RF_PISM_AWI_BM08_R3=np.append(RF_PISM_AWI_BM08_R3[0],RF_PISM_AWI_BM08_R3)
RF_PISM_AWI_BM08_R4=np.append(RF_PISM_AWI_BM08_R4[0],RF_PISM_AWI_BM08_R4)
RF_PISM_AWI_BM08_R5=np.append(RF_PISM_AWI_BM08_R5[0],RF_PISM_AWI_BM08_R5)

print(len(RF_PISM_AWI_BM08_R0))
# Out:
# 200

# %%
# PISM_AWI = PISM_AWI
# Experiment BM16

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_All_abmb16.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM16_R0 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM16_R0_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_EAIS_abmb16.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM16_R1 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM16_R1_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Ross_abmb16.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM16_R2 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM16_R2_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Amundsen_abmb16.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM16_R3 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM16_R3_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Weddell_abmb16.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM16_R4 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM16_R4_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Peninsula_abmb16.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM16_R5 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM16_R5_time = ncf.variables["time"][:]

PISM_AWI_BM16_SU = PISM_AWI_BM16_R1+PISM_AWI_BM16_R2+PISM_AWI_BM16_R3+PISM_AWI_BM16_R4+PISM_AWI_BM16_R5


# create and write response function
RF_PISM_AWI_BM16_R0=np.diff(PISM_AWI_BM16_R0)/16
RF_PISM_AWI_BM16_R1=np.diff(PISM_AWI_BM16_R1)/16
RF_PISM_AWI_BM16_R2=np.diff(PISM_AWI_BM16_R2)/16
RF_PISM_AWI_BM16_R3=np.diff(PISM_AWI_BM16_R3)/16
RF_PISM_AWI_BM16_R4=np.diff(PISM_AWI_BM16_R4)/16
RF_PISM_AWI_BM16_R5=np.diff(PISM_AWI_BM16_R5)/16
RF_PISM_AWI_BM16_SU=np.diff(PISM_AWI_BM16_SU)/16


# plot
plt.plot(PISM_AWI_BM16_R0,label="PISM_AWI_BM16_R0")
plt.plot(PISM_AWI_BM16_R1,label="PISM_AWI_BM16_R1")
plt.plot(PISM_AWI_BM16_R2,label="PISM_AWI_BM16_R2")
plt.plot(PISM_AWI_BM16_R3,label="PISM_AWI_BM16_R3")
plt.plot(PISM_AWI_BM16_R4,label="PISM_AWI_BM16_R4")
plt.plot(PISM_AWI_BM16_R5,label="PISM_AWI_BM16_R5")
plt.plot(PISM_AWI_BM16_SU,label="PISM_AWI_BM16_SU")
plt.legend()

RF_PISM_AWI_BM16_R0=np.append(RF_PISM_AWI_BM16_R0[0],RF_PISM_AWI_BM16_R0)
RF_PISM_AWI_BM16_R1=np.append(RF_PISM_AWI_BM16_R1[0],RF_PISM_AWI_BM16_R1)
RF_PISM_AWI_BM16_R2=np.append(RF_PISM_AWI_BM16_R2[0],RF_PISM_AWI_BM16_R2)
RF_PISM_AWI_BM16_R3=np.append(RF_PISM_AWI_BM16_R3[0],RF_PISM_AWI_BM16_R3)
RF_PISM_AWI_BM16_R4=np.append(RF_PISM_AWI_BM16_R4[0],RF_PISM_AWI_BM16_R4)
RF_PISM_AWI_BM16_R5=np.append(RF_PISM_AWI_BM16_R5[0],RF_PISM_AWI_BM16_R5)

print(len(RF_PISM_AWI_BM16_R0))
# Out:
# 200

# %%
# PISM_AWI = PISM_AWI
# Experiment BM32

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_All_abmb32.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM32_R0 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM32_R0_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_EAIS_abmb32.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM32_R1 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM32_R1_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Ross_abmb32.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM32_R2 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM32_R2_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Amundsen_abmb32.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM32_R3 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM32_R3_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Weddell_abmb32.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM32_R4 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM32_R4_time = ncf.variables["time"][:]

fname="larmip_data/PISM_AWI/AIS_AWI_PISM1Eq/slvol_AIS_AWI_PISM1Eq_LARMIP_16km_Peninsula_abmb32.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_AWI_BM32_R5 = -(ncf.variables["slvol"][:]-PISM_AWI_Control)
PISM_AWI_BM32_R5_time = ncf.variables["time"][:]

PISM_AWI_BM32_SU = PISM_AWI_BM32_R1+PISM_AWI_BM32_R2+PISM_AWI_BM32_R3+PISM_AWI_BM32_R4+PISM_AWI_BM32_R5


# create and write response function
RF_PISM_AWI_BM32_R0=np.diff(PISM_AWI_BM32_R0)/32
RF_PISM_AWI_BM32_R1=np.diff(PISM_AWI_BM32_R1)/32
RF_PISM_AWI_BM32_R2=np.diff(PISM_AWI_BM32_R2)/32
RF_PISM_AWI_BM32_R3=np.diff(PISM_AWI_BM32_R3)/32
RF_PISM_AWI_BM32_R4=np.diff(PISM_AWI_BM32_R4)/32
RF_PISM_AWI_BM32_R5=np.diff(PISM_AWI_BM32_R5)/32
RF_PISM_AWI_BM32_SU=np.diff(PISM_AWI_BM32_SU)/32


# plot
plt.plot(PISM_AWI_BM32_R0,label="PISM_AWI_BM32_R0")
plt.plot(PISM_AWI_BM32_R1,label="PISM_AWI_BM32_R1")
plt.plot(PISM_AWI_BM32_R2,label="PISM_AWI_BM32_R2")
plt.plot(PISM_AWI_BM32_R3,label="PISM_AWI_BM32_R3")
plt.plot(PISM_AWI_BM32_R4,label="PISM_AWI_BM32_R4")
plt.plot(PISM_AWI_BM32_R5,label="PISM_AWI_BM32_R5")
plt.plot(PISM_AWI_BM32_SU,label="PISM_AWI_BM32_SU")
plt.legend()

RF_PISM_AWI_BM32_R0=np.append(RF_PISM_AWI_BM32_R0[0],RF_PISM_AWI_BM32_R0)
RF_PISM_AWI_BM32_R1=np.append(RF_PISM_AWI_BM32_R1[0],RF_PISM_AWI_BM32_R1)
RF_PISM_AWI_BM32_R2=np.append(RF_PISM_AWI_BM32_R2[0],RF_PISM_AWI_BM32_R2)
RF_PISM_AWI_BM32_R3=np.append(RF_PISM_AWI_BM32_R3[0],RF_PISM_AWI_BM32_R3)
RF_PISM_AWI_BM32_R4=np.append(RF_PISM_AWI_BM32_R4[0],RF_PISM_AWI_BM32_R4)
RF_PISM_AWI_BM32_R5=np.append(RF_PISM_AWI_BM32_R5[0],RF_PISM_AWI_BM32_R5)

print(len(RF_PISM_AWI_BM32_R0))
# Out:
# 200

# %%
# Experiments
np.savetxt("RF_PISM_AWI_BM01_R0.dat", RF_PISM_AWI_BM01_R0, delimiter=",")
np.savetxt("RF_PISM_AWI_BM01_R1.dat", RF_PISM_AWI_BM01_R1, delimiter=",")
np.savetxt("RF_PISM_AWI_BM01_R2.dat", RF_PISM_AWI_BM01_R2, delimiter=",")
np.savetxt("RF_PISM_AWI_BM01_R3.dat", RF_PISM_AWI_BM01_R3, delimiter=",")
np.savetxt("RF_PISM_AWI_BM01_R4.dat", RF_PISM_AWI_BM01_R4, delimiter=",")
np.savetxt("RF_PISM_AWI_BM01_R5.dat", RF_PISM_AWI_BM01_R5, delimiter=",")
np.savetxt("RF_PISM_AWI_BM01_SU.dat", RF_PISM_AWI_BM01_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_AWI_BM02_R0.dat", RF_PISM_AWI_BM02_R0, delimiter=",")
np.savetxt("RF_PISM_AWI_BM02_R1.dat", RF_PISM_AWI_BM02_R1, delimiter=",")
np.savetxt("RF_PISM_AWI_BM02_R2.dat", RF_PISM_AWI_BM02_R2, delimiter=",")
np.savetxt("RF_PISM_AWI_BM02_R3.dat", RF_PISM_AWI_BM02_R3, delimiter=",")
np.savetxt("RF_PISM_AWI_BM02_R4.dat", RF_PISM_AWI_BM02_R4, delimiter=",")
np.savetxt("RF_PISM_AWI_BM02_R5.dat", RF_PISM_AWI_BM02_R5, delimiter=",")
np.savetxt("RF_PISM_AWI_BM02_SU.dat", RF_PISM_AWI_BM02_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_AWI_BM04_R0.dat", RF_PISM_AWI_BM04_R0, delimiter=",")
np.savetxt("RF_PISM_AWI_BM04_R1.dat", RF_PISM_AWI_BM04_R1, delimiter=",")
np.savetxt("RF_PISM_AWI_BM04_R2.dat", RF_PISM_AWI_BM04_R2, delimiter=",")
np.savetxt("RF_PISM_AWI_BM04_R3.dat", RF_PISM_AWI_BM04_R3, delimiter=",")
np.savetxt("RF_PISM_AWI_BM04_R4.dat", RF_PISM_AWI_BM04_R4, delimiter=",")
np.savetxt("RF_PISM_AWI_BM04_R5.dat", RF_PISM_AWI_BM04_R5, delimiter=",")
np.savetxt("RF_PISM_AWI_BM04_SU.dat", RF_PISM_AWI_BM04_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_AWI_BM08_R0.dat", RF_PISM_AWI_BM08_R0, delimiter=",")
np.savetxt("RF_PISM_AWI_BM08_R1.dat", RF_PISM_AWI_BM08_R1, delimiter=",")
np.savetxt("RF_PISM_AWI_BM08_R2.dat", RF_PISM_AWI_BM08_R2, delimiter=",")
np.savetxt("RF_PISM_AWI_BM08_R3.dat", RF_PISM_AWI_BM08_R3, delimiter=",")
np.savetxt("RF_PISM_AWI_BM08_R4.dat", RF_PISM_AWI_BM08_R4, delimiter=",")
np.savetxt("RF_PISM_AWI_BM08_R5.dat", RF_PISM_AWI_BM08_R5, delimiter=",")
np.savetxt("RF_PISM_AWI_BM08_SU.dat", RF_PISM_AWI_BM08_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_AWI_BM16_R0.dat", RF_PISM_AWI_BM16_R0, delimiter=",")
np.savetxt("RF_PISM_AWI_BM16_R1.dat", RF_PISM_AWI_BM16_R1, delimiter=",")
np.savetxt("RF_PISM_AWI_BM16_R2.dat", RF_PISM_AWI_BM16_R2, delimiter=",")
np.savetxt("RF_PISM_AWI_BM16_R3.dat", RF_PISM_AWI_BM16_R3, delimiter=",")
np.savetxt("RF_PISM_AWI_BM16_R4.dat", RF_PISM_AWI_BM16_R4, delimiter=",")
np.savetxt("RF_PISM_AWI_BM16_R5.dat", RF_PISM_AWI_BM16_R5, delimiter=",")
np.savetxt("RF_PISM_AWI_BM16_SU.dat", RF_PISM_AWI_BM16_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_AWI_BM32_R0.dat", RF_PISM_AWI_BM32_R0, delimiter=",")
np.savetxt("RF_PISM_AWI_BM32_R1.dat", RF_PISM_AWI_BM32_R1, delimiter=",")
np.savetxt("RF_PISM_AWI_BM32_R2.dat", RF_PISM_AWI_BM32_R2, delimiter=",")
np.savetxt("RF_PISM_AWI_BM32_R3.dat", RF_PISM_AWI_BM32_R3, delimiter=",")
np.savetxt("RF_PISM_AWI_BM32_R4.dat", RF_PISM_AWI_BM32_R4, delimiter=",")
np.savetxt("RF_PISM_AWI_BM32_R5.dat", RF_PISM_AWI_BM32_R5, delimiter=",")
np.savetxt("RF_PISM_AWI_BM32_SU.dat", RF_PISM_AWI_BM32_SU, delimiter=",")

# %%
# Experiments
np.savetxt("PISM_AWI_BM01_R0.dat", PISM_AWI_BM01_R0, delimiter=",")
np.savetxt("PISM_AWI_BM01_R1.dat", PISM_AWI_BM01_R1, delimiter=",")
np.savetxt("PISM_AWI_BM01_R2.dat", PISM_AWI_BM01_R2, delimiter=",")
np.savetxt("PISM_AWI_BM01_R3.dat", PISM_AWI_BM01_R3, delimiter=",")
np.savetxt("PISM_AWI_BM01_R4.dat", PISM_AWI_BM01_R4, delimiter=",")
np.savetxt("PISM_AWI_BM01_R5.dat", PISM_AWI_BM01_R5, delimiter=",")
np.savetxt("PISM_AWI_BM01_SU.dat", PISM_AWI_BM01_SU, delimiter=",")

# %%
np.savetxt("PISM_AWI_BM02_R0.dat", PISM_AWI_BM02_R0, delimiter=",")
np.savetxt("PISM_AWI_BM02_R1.dat", PISM_AWI_BM02_R1, delimiter=",")
np.savetxt("PISM_AWI_BM02_R2.dat", PISM_AWI_BM02_R2, delimiter=",")
np.savetxt("PISM_AWI_BM02_R3.dat", PISM_AWI_BM02_R3, delimiter=",")
np.savetxt("PISM_AWI_BM02_R4.dat", PISM_AWI_BM02_R4, delimiter=",")
np.savetxt("PISM_AWI_BM02_R5.dat", PISM_AWI_BM02_R5, delimiter=",")
np.savetxt("PISM_AWI_BM02_SU.dat", PISM_AWI_BM02_SU, delimiter=",")

# %%
np.savetxt("PISM_AWI_BM04_R0.dat", PISM_AWI_BM04_R0, delimiter=",")
np.savetxt("PISM_AWI_BM04_R1.dat", PISM_AWI_BM04_R1, delimiter=",")
np.savetxt("PISM_AWI_BM04_R2.dat", PISM_AWI_BM04_R2, delimiter=",")
np.savetxt("PISM_AWI_BM04_R3.dat", PISM_AWI_BM04_R3, delimiter=",")
np.savetxt("PISM_AWI_BM04_R4.dat", PISM_AWI_BM04_R4, delimiter=",")
np.savetxt("PISM_AWI_BM04_R5.dat", PISM_AWI_BM04_R5, delimiter=",")
np.savetxt("PISM_AWI_BM04_SU.dat", PISM_AWI_BM04_SU, delimiter=",")

# %%
np.savetxt("PISM_AWI_BM08_R0.dat", PISM_AWI_BM08_R0, delimiter=",")
np.savetxt("PISM_AWI_BM08_R1.dat", PISM_AWI_BM08_R1, delimiter=",")
np.savetxt("PISM_AWI_BM08_R2.dat", PISM_AWI_BM08_R2, delimiter=",")
np.savetxt("PISM_AWI_BM08_R3.dat", PISM_AWI_BM08_R3, delimiter=",")
np.savetxt("PISM_AWI_BM08_R4.dat", PISM_AWI_BM08_R4, delimiter=",")
np.savetxt("PISM_AWI_BM08_R5.dat", PISM_AWI_BM08_R5, delimiter=",")
np.savetxt("PISM_AWI_BM08_SU.dat", PISM_AWI_BM08_SU, delimiter=",")

# %%
np.savetxt("PISM_AWI_BM16_R0.dat", PISM_AWI_BM16_R0, delimiter=",")
np.savetxt("PISM_AWI_BM16_R1.dat", PISM_AWI_BM16_R1, delimiter=",")
np.savetxt("PISM_AWI_BM16_R2.dat", PISM_AWI_BM16_R2, delimiter=",")
np.savetxt("PISM_AWI_BM16_R3.dat", PISM_AWI_BM16_R3, delimiter=",")
np.savetxt("PISM_AWI_BM16_R4.dat", PISM_AWI_BM16_R4, delimiter=",")
np.savetxt("PISM_AWI_BM16_R5.dat", PISM_AWI_BM16_R5, delimiter=",")
np.savetxt("PISM_AWI_BM16_SU.dat", PISM_AWI_BM16_SU, delimiter=",")

# %%
np.savetxt("PISM_AWI_BM32_R0.dat", PISM_AWI_BM32_R0, delimiter=",")
np.savetxt("PISM_AWI_BM32_R1.dat", PISM_AWI_BM32_R1, delimiter=",")
np.savetxt("PISM_AWI_BM32_R2.dat", PISM_AWI_BM32_R2, delimiter=",")
np.savetxt("PISM_AWI_BM32_R3.dat", PISM_AWI_BM32_R3, delimiter=",")
np.savetxt("PISM_AWI_BM32_R4.dat", PISM_AWI_BM32_R4, delimiter=",")
np.savetxt("PISM_AWI_BM32_R5.dat", PISM_AWI_BM32_R5, delimiter=",")
np.savetxt("PISM_AWI_BM32_SU.dat", PISM_AWI_BM32_SU, delimiter=",")
