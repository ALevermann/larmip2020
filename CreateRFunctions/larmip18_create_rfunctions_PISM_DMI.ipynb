# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv

# %%
# PISM_DMI = PISM_DMI
# Control experiment
fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region1.Rate1.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_Control = ncf.variables["sea_level_contribution"][:]*0

# %%
# PISM_DMI = PISM_DMI
# Experiment BM01

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region1.Rate1.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM01_R1 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM01_R1_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region2.Rate1.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM01_R2 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM01_R2_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region3.Rate1.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM01_R3 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM01_R3_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region4.Rate1.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM01_R4 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM01_R4_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region5.Rate1.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM01_R5 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM01_R5_time = ncf.variables["time"][:]

PISM_DMI_BM01_SU = PISM_DMI_BM01_R1+PISM_DMI_BM01_R2+PISM_DMI_BM01_R3+PISM_DMI_BM01_R4+PISM_DMI_BM01_R5

# create and write response function
RF_PISM_DMI_BM01_R1=np.diff(PISM_DMI_BM01_R1)/1
RF_PISM_DMI_BM01_R2=np.diff(PISM_DMI_BM01_R2)/1
RF_PISM_DMI_BM01_R3=np.diff(PISM_DMI_BM01_R3)/1
RF_PISM_DMI_BM01_R4=np.diff(PISM_DMI_BM01_R4)/1
RF_PISM_DMI_BM01_R5=np.diff(PISM_DMI_BM01_R5)/1
RF_PISM_DMI_BM01_SU=np.diff(PISM_DMI_BM01_SU)/1

RF_PISM_DMI_BM01_R1=np.append(RF_PISM_DMI_BM01_R1[0],RF_PISM_DMI_BM01_R1)
RF_PISM_DMI_BM01_R2=np.append(RF_PISM_DMI_BM01_R2[0],RF_PISM_DMI_BM01_R2)
RF_PISM_DMI_BM01_R3=np.append(RF_PISM_DMI_BM01_R3[0],RF_PISM_DMI_BM01_R3)
RF_PISM_DMI_BM01_R4=np.append(RF_PISM_DMI_BM01_R4[0],RF_PISM_DMI_BM01_R4)
RF_PISM_DMI_BM01_R5=np.append(RF_PISM_DMI_BM01_R5[0],RF_PISM_DMI_BM01_R5)
RF_PISM_DMI_BM01_SU=np.append(RF_PISM_DMI_BM01_SU[0],RF_PISM_DMI_BM01_SU)

print(len(RF_PISM_DMI_BM01_R1))


# plot
plt.plot(PISM_DMI_BM01_R1,label="PISM_DMI_BM01_R1")
plt.plot(PISM_DMI_BM01_R2,label="PISM_DMI_BM01_R2")
plt.plot(PISM_DMI_BM01_R3,label="PISM_DMI_BM01_R3")
plt.plot(PISM_DMI_BM01_R4,label="PISM_DMI_BM01_R4")
plt.plot(PISM_DMI_BM01_R5,label="PISM_DMI_BM01_R5")
plt.plot(PISM_DMI_BM01_SU,label="PISM_DMI_BM01_SU")
# Out:
# 200

# %%
# PISM_DMI = PISM_DMI
# Experiment BM02

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region1.Rate2.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM02_R1 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM02_R1_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region2.Rate2.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM02_R2 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM02_R2_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region3.Rate2.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM02_R3 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM02_R3_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region4.Rate2.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM02_R4 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM02_R4_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region5.Rate2.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM02_R5 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM02_R5_time = ncf.variables["time"][:]

PISM_DMI_BM02_SU = PISM_DMI_BM02_R1+PISM_DMI_BM02_R2+PISM_DMI_BM02_R3+PISM_DMI_BM02_R4+PISM_DMI_BM02_R5


# create and write response function
RF_PISM_DMI_BM02_R1=np.diff(PISM_DMI_BM02_R1)/2
RF_PISM_DMI_BM02_R2=np.diff(PISM_DMI_BM02_R2)/2
RF_PISM_DMI_BM02_R3=np.diff(PISM_DMI_BM02_R3)/2
RF_PISM_DMI_BM02_R4=np.diff(PISM_DMI_BM02_R4)/2
RF_PISM_DMI_BM02_R5=np.diff(PISM_DMI_BM02_R5)/2
RF_PISM_DMI_BM02_SU=np.diff(PISM_DMI_BM02_SU)/2

RF_PISM_DMI_BM02_R1=np.append(RF_PISM_DMI_BM02_R1[0],RF_PISM_DMI_BM02_R1)
RF_PISM_DMI_BM02_R2=np.append(RF_PISM_DMI_BM02_R2[0],RF_PISM_DMI_BM02_R2)
RF_PISM_DMI_BM02_R3=np.append(RF_PISM_DMI_BM02_R3[0],RF_PISM_DMI_BM02_R3)
RF_PISM_DMI_BM02_R4=np.append(RF_PISM_DMI_BM02_R4[0],RF_PISM_DMI_BM02_R4)
RF_PISM_DMI_BM02_R5=np.append(RF_PISM_DMI_BM02_R5[0],RF_PISM_DMI_BM02_R5)
RF_PISM_DMI_BM02_SU=np.append(RF_PISM_DMI_BM02_SU[0],RF_PISM_DMI_BM02_SU)

print(len(RF_PISM_DMI_BM02_R1))


# plot
plt.plot(PISM_DMI_BM02_R1,label="PISM_DMI_BM02_R1")
plt.plot(PISM_DMI_BM02_R2,label="PISM_DMI_BM02_R2")
plt.plot(PISM_DMI_BM02_R3,label="PISM_DMI_BM02_R3")
plt.plot(PISM_DMI_BM02_R4,label="PISM_DMI_BM02_R4")
plt.plot(PISM_DMI_BM02_R5,label="PISM_DMI_BM02_R5")
plt.plot(PISM_DMI_BM02_SU,label="PISM_DMI_BM02_SU")
plt.legend()
# Out:
# 200

# %%
# PISM_DMI = PISM_DMI
# Experiment BM04

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region1.Rate4.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM04_R1 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM04_R1_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region2.Rate4.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM04_R2 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM04_R2_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region3.Rate4.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM04_R3 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM04_R3_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region4.Rate4.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM04_R4 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM04_R4_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region5.Rate4.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM04_R5 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM04_R5_time = ncf.variables["time"][:]

PISM_DMI_BM04_SU = PISM_DMI_BM04_R1+PISM_DMI_BM04_R2+PISM_DMI_BM04_R3+PISM_DMI_BM04_R4+PISM_DMI_BM04_R5


# create and write response function
RF_PISM_DMI_BM04_R1=np.diff(PISM_DMI_BM04_R1)/4
RF_PISM_DMI_BM04_R2=np.diff(PISM_DMI_BM04_R2)/4
RF_PISM_DMI_BM04_R3=np.diff(PISM_DMI_BM04_R3)/4
RF_PISM_DMI_BM04_R4=np.diff(PISM_DMI_BM04_R4)/4
RF_PISM_DMI_BM04_R5=np.diff(PISM_DMI_BM04_R5)/4
RF_PISM_DMI_BM04_SU=np.diff(PISM_DMI_BM04_SU)/4

RF_PISM_DMI_BM04_R1=np.append(RF_PISM_DMI_BM04_R1[0],RF_PISM_DMI_BM04_R1)
RF_PISM_DMI_BM04_R2=np.append(RF_PISM_DMI_BM04_R2[0],RF_PISM_DMI_BM04_R2)
RF_PISM_DMI_BM04_R3=np.append(RF_PISM_DMI_BM04_R3[0],RF_PISM_DMI_BM04_R3)
RF_PISM_DMI_BM04_R4=np.append(RF_PISM_DMI_BM04_R4[0],RF_PISM_DMI_BM04_R4)
RF_PISM_DMI_BM04_R5=np.append(RF_PISM_DMI_BM04_R5[0],RF_PISM_DMI_BM04_R5)
RF_PISM_DMI_BM04_SU=np.append(RF_PISM_DMI_BM04_SU[0],RF_PISM_DMI_BM04_SU)

print(len(RF_PISM_DMI_BM04_R1))

# plot
plt.plot(PISM_DMI_BM04_R1,label="PISM_DMI_BM04_R1")
plt.plot(PISM_DMI_BM04_R2,label="PISM_DMI_BM04_R2")
plt.plot(PISM_DMI_BM04_R3,label="PISM_DMI_BM04_R3")
plt.plot(PISM_DMI_BM04_R4,label="PISM_DMI_BM04_R4")
plt.plot(PISM_DMI_BM04_R5,label="PISM_DMI_BM04_R5")
plt.plot(PISM_DMI_BM04_SU,label="PISM_DMI_BM04_SU")
plt.legend()
# Out:
# 200

# %%
# PISM_DMI = PISM_DMI
# Experiment BM08

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region1.Rate8.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM08_R1 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM08_R1_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region2.Rate8.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM08_R2 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM08_R2_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region3.Rate8.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM08_R3 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM08_R3_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region4.Rate8.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM08_R4 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM08_R4_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region5.Rate8.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM08_R5 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM08_R5_time = ncf.variables["time"][:]

PISM_DMI_BM08_SU = PISM_DMI_BM08_R1+PISM_DMI_BM08_R2+PISM_DMI_BM08_R3+PISM_DMI_BM08_R4+PISM_DMI_BM08_R5


# create and write response function
RF_PISM_DMI_BM08_R1=np.diff(PISM_DMI_BM08_R1)/8
RF_PISM_DMI_BM08_R2=np.diff(PISM_DMI_BM08_R2)/8
RF_PISM_DMI_BM08_R3=np.diff(PISM_DMI_BM08_R3)/8
RF_PISM_DMI_BM08_R4=np.diff(PISM_DMI_BM08_R4)/8
RF_PISM_DMI_BM08_R5=np.diff(PISM_DMI_BM08_R5)/8
RF_PISM_DMI_BM08_SU=np.diff(PISM_DMI_BM08_SU)/8

RF_PISM_DMI_BM08_R1=np.append(RF_PISM_DMI_BM08_R1[0],RF_PISM_DMI_BM08_R1)
RF_PISM_DMI_BM08_R2=np.append(RF_PISM_DMI_BM08_R2[0],RF_PISM_DMI_BM08_R2)
RF_PISM_DMI_BM08_R3=np.append(RF_PISM_DMI_BM08_R3[0],RF_PISM_DMI_BM08_R3)
RF_PISM_DMI_BM08_R4=np.append(RF_PISM_DMI_BM08_R4[0],RF_PISM_DMI_BM08_R4)
RF_PISM_DMI_BM08_R5=np.append(RF_PISM_DMI_BM08_R5[0],RF_PISM_DMI_BM08_R5)
RF_PISM_DMI_BM08_SU=np.append(RF_PISM_DMI_BM08_SU[0],RF_PISM_DMI_BM08_SU)

print(len(RF_PISM_DMI_BM08_R1))


# plot
plt.plot(PISM_DMI_BM08_R1,label="PISM_DMI_BM08_R1")
plt.plot(PISM_DMI_BM08_R2,label="PISM_DMI_BM08_R2")
plt.plot(PISM_DMI_BM08_R3,label="PISM_DMI_BM08_R3")
plt.plot(PISM_DMI_BM08_R4,label="PISM_DMI_BM08_R4")
plt.plot(PISM_DMI_BM08_R5,label="PISM_DMI_BM08_R5")
plt.plot(PISM_DMI_BM08_SU,label="PISM_DMI_BM08_SU")
plt.legend()
# Out:
# 200

# %%
# PISM_DMI = PISM_DMI
# Experiment BM16

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region1.Rate16.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM16_R1 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM16_R1_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region2.Rate16.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM16_R2 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM16_R2_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region3.Rate16.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM16_R3 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM16_R3_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region4.Rate16.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM16_R4 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM16_R4_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region5.Rate16.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM16_R5 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM16_R5_time = ncf.variables["time"][:]

PISM_DMI_BM16_SU = PISM_DMI_BM16_R1+PISM_DMI_BM16_R2+PISM_DMI_BM16_R3+PISM_DMI_BM16_R4+PISM_DMI_BM16_R5


# create and write response function
RF_PISM_DMI_BM16_R1=np.diff(PISM_DMI_BM16_R1)/16
RF_PISM_DMI_BM16_R2=np.diff(PISM_DMI_BM16_R2)/16
RF_PISM_DMI_BM16_R3=np.diff(PISM_DMI_BM16_R3)/16
RF_PISM_DMI_BM16_R4=np.diff(PISM_DMI_BM16_R4)/16
RF_PISM_DMI_BM16_R5=np.diff(PISM_DMI_BM16_R5)/16
RF_PISM_DMI_BM16_SU=np.diff(PISM_DMI_BM16_SU)/16

RF_PISM_DMI_BM16_R1=np.append(RF_PISM_DMI_BM16_R1[0],RF_PISM_DMI_BM16_R1)
RF_PISM_DMI_BM16_R2=np.append(RF_PISM_DMI_BM16_R2[0],RF_PISM_DMI_BM16_R2)
RF_PISM_DMI_BM16_R3=np.append(RF_PISM_DMI_BM16_R3[0],RF_PISM_DMI_BM16_R3)
RF_PISM_DMI_BM16_R4=np.append(RF_PISM_DMI_BM16_R4[0],RF_PISM_DMI_BM16_R4)
RF_PISM_DMI_BM16_R5=np.append(RF_PISM_DMI_BM16_R5[0],RF_PISM_DMI_BM16_R5)
RF_PISM_DMI_BM16_SU=np.append(RF_PISM_DMI_BM16_SU[0],RF_PISM_DMI_BM16_SU)

print(len(RF_PISM_DMI_BM16_R1))


# plot
plt.plot(PISM_DMI_BM16_R1,label="PISM_DMI_BM16_R1")
plt.plot(PISM_DMI_BM16_R2,label="PISM_DMI_BM16_R2")
plt.plot(PISM_DMI_BM16_R3,label="PISM_DMI_BM16_R3")
plt.plot(PISM_DMI_BM16_R4,label="PISM_DMI_BM16_R4")
plt.plot(PISM_DMI_BM16_R5,label="PISM_DMI_BM16_R5")
plt.plot(PISM_DMI_BM16_SU,label="PISM_DMI_BM16_SU")
plt.legend()
# Out:
# 200

# %%
# PISM_DMI = PISM_DMI
# Experiment BM32

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region1.Rate32.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM32_R1 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM32_R1_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region2.Rate32.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM32_R2 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM32_R2_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region3.Rate32.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM32_R3 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM32_R3_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region4.Rate32.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM32_R4 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM32_R4_time = ncf.variables["time"][:]

fname="larmip_data/PISM_DMI/LARMIP_SeaLevelContribution_AllShelves_timeseries/LARMIP_region5.Rate32.DMI.PISM0.2000_2200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_DMI_BM32_R5 = (ncf.variables["sea_level_contribution"][:]-PISM_DMI_Control)
PISM_DMI_BM32_R5_time = ncf.variables["time"][:]

PISM_DMI_BM32_SU = PISM_DMI_BM32_R1+PISM_DMI_BM32_R2+PISM_DMI_BM32_R3+PISM_DMI_BM32_R4+PISM_DMI_BM32_R5


# create and write response function
RF_PISM_DMI_BM32_R1=np.diff(PISM_DMI_BM32_R1)/32
RF_PISM_DMI_BM32_R2=np.diff(PISM_DMI_BM32_R2)/32
RF_PISM_DMI_BM32_R3=np.diff(PISM_DMI_BM32_R3)/32
RF_PISM_DMI_BM32_R4=np.diff(PISM_DMI_BM32_R4)/32
RF_PISM_DMI_BM32_R5=np.diff(PISM_DMI_BM32_R5)/32
RF_PISM_DMI_BM32_SU=np.diff(PISM_DMI_BM32_SU)/32

RF_PISM_DMI_BM32_R1=np.append(RF_PISM_DMI_BM32_R1[0],RF_PISM_DMI_BM32_R1)
RF_PISM_DMI_BM32_R2=np.append(RF_PISM_DMI_BM32_R2[0],RF_PISM_DMI_BM32_R2)
RF_PISM_DMI_BM32_R3=np.append(RF_PISM_DMI_BM32_R3[0],RF_PISM_DMI_BM32_R3)
RF_PISM_DMI_BM32_R4=np.append(RF_PISM_DMI_BM32_R4[0],RF_PISM_DMI_BM32_R4)
RF_PISM_DMI_BM32_R5=np.append(RF_PISM_DMI_BM32_R5[0],RF_PISM_DMI_BM32_R5)
RF_PISM_DMI_BM32_SU=np.append(RF_PISM_DMI_BM32_SU[0],RF_PISM_DMI_BM32_SU)

print(len(RF_PISM_DMI_BM32_R1))


# plot
plt.plot(PISM_DMI_BM32_R1,label="PISM_DMI_BM32_R1")
plt.plot(PISM_DMI_BM32_R2,label="PISM_DMI_BM32_R2")
plt.plot(PISM_DMI_BM32_R3,label="PISM_DMI_BM32_R3")
plt.plot(PISM_DMI_BM32_R4,label="PISM_DMI_BM32_R4")
plt.plot(PISM_DMI_BM32_R5,label="PISM_DMI_BM32_R5")
plt.plot(PISM_DMI_BM32_SU,label="PISM_DMI_BM32_SU")
plt.legend()
# Out:
# 200

# %%
# Response functions
np.savetxt("RF_PISM_DMI_BM01_R1.dat", RF_PISM_DMI_BM01_R1, delimiter=",")
np.savetxt("RF_PISM_DMI_BM01_R2.dat", RF_PISM_DMI_BM01_R2, delimiter=",")
np.savetxt("RF_PISM_DMI_BM01_R3.dat", RF_PISM_DMI_BM01_R3, delimiter=",")
np.savetxt("RF_PISM_DMI_BM01_R4.dat", RF_PISM_DMI_BM01_R4, delimiter=",")
np.savetxt("RF_PISM_DMI_BM01_R5.dat", RF_PISM_DMI_BM01_R5, delimiter=",")
np.savetxt("RF_PISM_DMI_BM01_SU.dat", RF_PISM_DMI_BM01_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_DMI_BM02_R1.dat", RF_PISM_DMI_BM02_R1, delimiter=",")
np.savetxt("RF_PISM_DMI_BM02_R2.dat", RF_PISM_DMI_BM02_R2, delimiter=",")
np.savetxt("RF_PISM_DMI_BM02_R3.dat", RF_PISM_DMI_BM02_R3, delimiter=",")
np.savetxt("RF_PISM_DMI_BM02_R4.dat", RF_PISM_DMI_BM02_R4, delimiter=",")
np.savetxt("RF_PISM_DMI_BM02_R5.dat", RF_PISM_DMI_BM02_R5, delimiter=",")
np.savetxt("RF_PISM_DMI_BM02_SU.dat", RF_PISM_DMI_BM02_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_DMI_BM04_R1.dat", RF_PISM_DMI_BM04_R1, delimiter=",")
np.savetxt("RF_PISM_DMI_BM04_R2.dat", RF_PISM_DMI_BM04_R2, delimiter=",")
np.savetxt("RF_PISM_DMI_BM04_R3.dat", RF_PISM_DMI_BM04_R3, delimiter=",")
np.savetxt("RF_PISM_DMI_BM04_R4.dat", RF_PISM_DMI_BM04_R4, delimiter=",")
np.savetxt("RF_PISM_DMI_BM04_R5.dat", RF_PISM_DMI_BM04_R5, delimiter=",")
np.savetxt("RF_PISM_DMI_BM04_SU.dat", RF_PISM_DMI_BM04_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_DMI_BM08_R1.dat", RF_PISM_DMI_BM08_R1, delimiter=",")
np.savetxt("RF_PISM_DMI_BM08_R2.dat", RF_PISM_DMI_BM08_R2, delimiter=",")
np.savetxt("RF_PISM_DMI_BM08_R3.dat", RF_PISM_DMI_BM08_R3, delimiter=",")
np.savetxt("RF_PISM_DMI_BM08_R4.dat", RF_PISM_DMI_BM08_R4, delimiter=",")
np.savetxt("RF_PISM_DMI_BM08_R5.dat", RF_PISM_DMI_BM08_R5, delimiter=",")
np.savetxt("RF_PISM_DMI_BM08_SU.dat", RF_PISM_DMI_BM08_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_DMI_BM16_R1.dat", RF_PISM_DMI_BM16_R1, delimiter=",")
np.savetxt("RF_PISM_DMI_BM16_R2.dat", RF_PISM_DMI_BM16_R2, delimiter=",")
np.savetxt("RF_PISM_DMI_BM16_R3.dat", RF_PISM_DMI_BM16_R3, delimiter=",")
np.savetxt("RF_PISM_DMI_BM16_R4.dat", RF_PISM_DMI_BM16_R4, delimiter=",")
np.savetxt("RF_PISM_DMI_BM16_R5.dat", RF_PISM_DMI_BM16_R5, delimiter=",")
np.savetxt("RF_PISM_DMI_BM16_SU.dat", RF_PISM_DMI_BM16_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_DMI_BM32_R1.dat", RF_PISM_DMI_BM32_R1, delimiter=",")
np.savetxt("RF_PISM_DMI_BM32_R2.dat", RF_PISM_DMI_BM32_R2, delimiter=",")
np.savetxt("RF_PISM_DMI_BM32_R3.dat", RF_PISM_DMI_BM32_R3, delimiter=",")
np.savetxt("RF_PISM_DMI_BM32_R4.dat", RF_PISM_DMI_BM32_R4, delimiter=",")
np.savetxt("RF_PISM_DMI_BM32_R5.dat", RF_PISM_DMI_BM32_R5, delimiter=",")
np.savetxt("RF_PISM_DMI_BM32_SU.dat", RF_PISM_DMI_BM32_SU, delimiter=",")

# %%
# Experiments
np.savetxt("PISM_DMI_BM01_R1.dat", PISM_DMI_BM01_R1, delimiter=",")
np.savetxt("PISM_DMI_BM01_R2.dat", PISM_DMI_BM01_R2, delimiter=",")
np.savetxt("PISM_DMI_BM01_R3.dat", PISM_DMI_BM01_R3, delimiter=",")
np.savetxt("PISM_DMI_BM01_R4.dat", PISM_DMI_BM01_R4, delimiter=",")
np.savetxt("PISM_DMI_BM01_R5.dat", PISM_DMI_BM01_R5, delimiter=",")
np.savetxt("PISM_DMI_BM01_SU.dat", PISM_DMI_BM01_SU, delimiter=",")

# %%
np.savetxt("PISM_DMI_BM02_R1.dat", PISM_DMI_BM02_R1, delimiter=",")
np.savetxt("PISM_DMI_BM02_R2.dat", PISM_DMI_BM02_R2, delimiter=",")
np.savetxt("PISM_DMI_BM02_R3.dat", PISM_DMI_BM02_R3, delimiter=",")
np.savetxt("PISM_DMI_BM02_R4.dat", PISM_DMI_BM02_R4, delimiter=",")
np.savetxt("PISM_DMI_BM02_R5.dat", PISM_DMI_BM02_R5, delimiter=",")
np.savetxt("PISM_DMI_BM02_SU.dat", PISM_DMI_BM02_SU, delimiter=",")

# %%
np.savetxt("PISM_DMI_BM04_R1.dat", PISM_DMI_BM04_R1, delimiter=",")
np.savetxt("PISM_DMI_BM04_R2.dat", PISM_DMI_BM04_R2, delimiter=",")
np.savetxt("PISM_DMI_BM04_R3.dat", PISM_DMI_BM04_R3, delimiter=",")
np.savetxt("PISM_DMI_BM04_R4.dat", PISM_DMI_BM04_R4, delimiter=",")
np.savetxt("PISM_DMI_BM04_R5.dat", PISM_DMI_BM04_R5, delimiter=",")
np.savetxt("PISM_DMI_BM04_SU.dat", PISM_DMI_BM04_SU, delimiter=",")

# %%
np.savetxt("PISM_DMI_BM08_R1.dat", PISM_DMI_BM08_R1, delimiter=",")
np.savetxt("PISM_DMI_BM08_R2.dat", PISM_DMI_BM08_R2, delimiter=",")
np.savetxt("PISM_DMI_BM08_R3.dat", PISM_DMI_BM08_R3, delimiter=",")
np.savetxt("PISM_DMI_BM08_R4.dat", PISM_DMI_BM08_R4, delimiter=",")
np.savetxt("PISM_DMI_BM08_R5.dat", PISM_DMI_BM08_R5, delimiter=",")
np.savetxt("PISM_DMI_BM08_SU.dat", PISM_DMI_BM08_SU, delimiter=",")

# %%
np.savetxt("PISM_DMI_BM16_R1.dat", PISM_DMI_BM16_R1, delimiter=",")
np.savetxt("PISM_DMI_BM16_R2.dat", PISM_DMI_BM16_R2, delimiter=",")
np.savetxt("PISM_DMI_BM16_R3.dat", PISM_DMI_BM16_R3, delimiter=",")
np.savetxt("PISM_DMI_BM16_R4.dat", PISM_DMI_BM16_R4, delimiter=",")
np.savetxt("PISM_DMI_BM16_R5.dat", PISM_DMI_BM16_R5, delimiter=",")
np.savetxt("PISM_DMI_BM16_SU.dat", PISM_DMI_BM16_SU, delimiter=",")

# %%
np.savetxt("PISM_DMI_BM32_R1.dat", PISM_DMI_BM32_R1, delimiter=",")
np.savetxt("PISM_DMI_BM32_R2.dat", PISM_DMI_BM32_R2, delimiter=",")
np.savetxt("PISM_DMI_BM32_R3.dat", PISM_DMI_BM32_R3, delimiter=",")
np.savetxt("PISM_DMI_BM32_R4.dat", PISM_DMI_BM32_R4, delimiter=",")
np.savetxt("PISM_DMI_BM32_R5.dat", PISM_DMI_BM32_R5, delimiter=",")
np.savetxt("PISM_DMI_BM32_SU.dat", PISM_DMI_BM32_SU, delimiter=",")
