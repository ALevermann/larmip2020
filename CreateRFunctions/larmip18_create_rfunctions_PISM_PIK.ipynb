# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv

# %%
# PISM_PIK = PISM_PIK
# Experiment BM02

fname="larmip_data/PISM_PIK/ADD0.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_PIK_BM02_R1 = (ncf.variables["reg1"][:])
PISM_PIK_BM02_R2 = (ncf.variables["reg2"][:])
PISM_PIK_BM02_R3 = (ncf.variables["reg3"][:])
PISM_PIK_BM02_R4 = (ncf.variables["reg4"][:])
PISM_PIK_BM02_R5 = (ncf.variables["reg5"][:])
PISM_PIK_BM02_time = ncf.variables["time"][:]

PISM_PIK_BM02_SU = PISM_PIK_BM02_R1+PISM_PIK_BM02_R2+PISM_PIK_BM02_R3+PISM_PIK_BM02_R4+PISM_PIK_BM02_R5


# create and write response function
#RF_PISM_PIK_BM02_R0=np.diff(PISM_PIK_BM02_R0)/np.diff(PISM_PIK_BM02_time)/2
RF_PISM_PIK_BM02_R1=np.diff(PISM_PIK_BM02_R1)/np.diff(PISM_PIK_BM02_time)/2
RF_PISM_PIK_BM02_R2=np.diff(PISM_PIK_BM02_R2)/np.diff(PISM_PIK_BM02_time)/2
RF_PISM_PIK_BM02_R3=np.diff(PISM_PIK_BM02_R3)/np.diff(PISM_PIK_BM02_time)/2
RF_PISM_PIK_BM02_R4=np.diff(PISM_PIK_BM02_R4)/np.diff(PISM_PIK_BM02_time)/2
RF_PISM_PIK_BM02_R5=np.diff(PISM_PIK_BM02_R5)/np.diff(PISM_PIK_BM02_time)/2
RF_PISM_PIK_BM02_SU=np.diff(PISM_PIK_BM02_SU)/np.diff(PISM_PIK_BM02_time)/2


#RF_PISM_PIK_BM02_R0=np.append(RF_PISM_PIK_BM02_R0[0],RF_PISM_PIK_BM02_R0)
RF_PISM_PIK_BM02_R1=np.append(RF_PISM_PIK_BM02_R1[0],RF_PISM_PIK_BM02_R1)
RF_PISM_PIK_BM02_R2=np.append(RF_PISM_PIK_BM02_R2[0],RF_PISM_PIK_BM02_R2)
RF_PISM_PIK_BM02_R3=np.append(RF_PISM_PIK_BM02_R3[0],RF_PISM_PIK_BM02_R3)
RF_PISM_PIK_BM02_R4=np.append(RF_PISM_PIK_BM02_R4[0],RF_PISM_PIK_BM02_R4)
RF_PISM_PIK_BM02_R5=np.append(RF_PISM_PIK_BM02_R5[0],RF_PISM_PIK_BM02_R5)
RF_PISM_PIK_BM02_SU=np.append(RF_PISM_PIK_BM02_SU[0],RF_PISM_PIK_BM02_SU)


# plot
#plt.plot(PISM_PIK_BM02_R0,label="PISM_PIK_BM02_R0")
plt.plot(PISM_PIK_BM02_R1,label="PISM_PIK_BM02_R1")
plt.plot(PISM_PIK_BM02_R2,label="PISM_PIK_BM02_R2")
plt.plot(PISM_PIK_BM02_R3,label="PISM_PIK_BM02_R3")
plt.plot(PISM_PIK_BM02_R4,label="PISM_PIK_BM02_R4")
plt.plot(PISM_PIK_BM02_R5,label="PISM_PIK_BM02_R5")
plt.plot(PISM_PIK_BM02_SU,label="PISM_PIK_BM02_SU")
plt.legend()

# %%
# PISM_PIK = PISM_PIK
# Experiment BM04

fname="larmip_data/PISM_PIK/ADD2.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_PIK_BM04_R1 = (ncf.variables["reg1"][:])
PISM_PIK_BM04_R2 = (ncf.variables["reg2"][:])
PISM_PIK_BM04_R3 = (ncf.variables["reg3"][:])
PISM_PIK_BM04_R4 = (ncf.variables["reg4"][:])
PISM_PIK_BM04_R5 = (ncf.variables["reg5"][:])
PISM_PIK_BM04_time = ncf.variables["time"][:]

PISM_PIK_BM04_SU = PISM_PIK_BM04_R1+PISM_PIK_BM04_R2+PISM_PIK_BM04_R3+PISM_PIK_BM04_R4+PISM_PIK_BM04_R5


# create and write response function
RF_PISM_PIK_BM04_R1=np.diff(PISM_PIK_BM04_R1)/np.diff(PISM_PIK_BM04_time)/4
RF_PISM_PIK_BM04_R2=np.diff(PISM_PIK_BM04_R2)/np.diff(PISM_PIK_BM04_time)/4
RF_PISM_PIK_BM04_R3=np.diff(PISM_PIK_BM04_R3)/np.diff(PISM_PIK_BM04_time)/4
RF_PISM_PIK_BM04_R4=np.diff(PISM_PIK_BM04_R4)/np.diff(PISM_PIK_BM04_time)/4
RF_PISM_PIK_BM04_R5=np.diff(PISM_PIK_BM04_R5)/np.diff(PISM_PIK_BM04_time)/4
RF_PISM_PIK_BM04_SU=np.diff(PISM_PIK_BM04_SU)/np.diff(PISM_PIK_BM04_time)/4


RF_PISM_PIK_BM04_R1=np.append(RF_PISM_PIK_BM04_R1[0],RF_PISM_PIK_BM04_R1)
RF_PISM_PIK_BM04_R2=np.append(RF_PISM_PIK_BM04_R2[0],RF_PISM_PIK_BM04_R2)
RF_PISM_PIK_BM04_R3=np.append(RF_PISM_PIK_BM04_R3[0],RF_PISM_PIK_BM04_R3)
RF_PISM_PIK_BM04_R4=np.append(RF_PISM_PIK_BM04_R4[0],RF_PISM_PIK_BM04_R4)
RF_PISM_PIK_BM04_R5=np.append(RF_PISM_PIK_BM04_R5[0],RF_PISM_PIK_BM04_R5)
RF_PISM_PIK_BM04_SU=np.append(RF_PISM_PIK_BM04_SU[0],RF_PISM_PIK_BM04_SU)


# plot
plt.plot(PISM_PIK_BM04_R1,label="PISM_PIK_BM04_R1")
plt.plot(PISM_PIK_BM04_R2,label="PISM_PIK_BM04_R2")
plt.plot(PISM_PIK_BM04_R3,label="PISM_PIK_BM04_R3")
plt.plot(PISM_PIK_BM04_R4,label="PISM_PIK_BM04_R4")
plt.plot(PISM_PIK_BM04_R5,label="PISM_PIK_BM04_R5")
plt.plot(PISM_PIK_BM04_SU,label="PISM_PIK_BM04_SU")
plt.legend()

# %%
# PISM_PIK = PISM_PIK
# Experiment BM08

fname="larmip_data/PISM_PIK/ADD4.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_PIK_BM08_R1 = (ncf.variables["reg1"][:])
PISM_PIK_BM08_R2 = (ncf.variables["reg2"][:])
PISM_PIK_BM08_R3 = (ncf.variables["reg3"][:])
PISM_PIK_BM08_R4 = (ncf.variables["reg4"][:])
PISM_PIK_BM08_R5 = (ncf.variables["reg5"][:])
PISM_PIK_BM08_time = ncf.variables["time"][:]

PISM_PIK_BM08_SU = PISM_PIK_BM08_R1+PISM_PIK_BM08_R2+PISM_PIK_BM08_R3+PISM_PIK_BM08_R4+PISM_PIK_BM08_R5


# create and write response function
RF_PISM_PIK_BM08_R1=np.diff(PISM_PIK_BM08_R1)/np.diff(PISM_PIK_BM08_time)/8
RF_PISM_PIK_BM08_R2=np.diff(PISM_PIK_BM08_R2)/np.diff(PISM_PIK_BM08_time)/8
RF_PISM_PIK_BM08_R3=np.diff(PISM_PIK_BM08_R3)/np.diff(PISM_PIK_BM08_time)/8
RF_PISM_PIK_BM08_R4=np.diff(PISM_PIK_BM08_R4)/np.diff(PISM_PIK_BM08_time)/8
RF_PISM_PIK_BM08_R5=np.diff(PISM_PIK_BM08_R5)/np.diff(PISM_PIK_BM08_time)/8
RF_PISM_PIK_BM08_SU=np.diff(PISM_PIK_BM08_SU)/np.diff(PISM_PIK_BM08_time)/8


RF_PISM_PIK_BM08_R1=np.append(RF_PISM_PIK_BM08_R1[0],RF_PISM_PIK_BM08_R1)
RF_PISM_PIK_BM08_R2=np.append(RF_PISM_PIK_BM08_R2[0],RF_PISM_PIK_BM08_R2)
RF_PISM_PIK_BM08_R3=np.append(RF_PISM_PIK_BM08_R3[0],RF_PISM_PIK_BM08_R3)
RF_PISM_PIK_BM08_R4=np.append(RF_PISM_PIK_BM08_R4[0],RF_PISM_PIK_BM08_R4)
RF_PISM_PIK_BM08_R5=np.append(RF_PISM_PIK_BM08_R5[0],RF_PISM_PIK_BM08_R5)
RF_PISM_PIK_BM08_SU=np.append(RF_PISM_PIK_BM08_SU[0],RF_PISM_PIK_BM08_SU)


# plot
plt.plot(PISM_PIK_BM08_R1,label="PISM_PIK_BM08_R1")
plt.plot(PISM_PIK_BM08_R2,label="PISM_PIK_BM08_R2")
plt.plot(PISM_PIK_BM08_R3,label="PISM_PIK_BM08_R3")
plt.plot(PISM_PIK_BM08_R4,label="PISM_PIK_BM08_R4")
plt.plot(PISM_PIK_BM08_R5,label="PISM_PIK_BM08_R5")
plt.plot(PISM_PIK_BM08_SU,label="PISM_PIK_BM08_SU")
plt.legend()

# %%
# PISM_PIK = PISM_PIK
# Experiment BM16

fname="larmip_data/PISM_PIK/ADD6.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_PIK_BM16_R1 = (ncf.variables["reg1"][:])
PISM_PIK_BM16_R2 = (ncf.variables["reg2"][:])
PISM_PIK_BM16_R3 = (ncf.variables["reg3"][:])
PISM_PIK_BM16_R4 = (ncf.variables["reg4"][:])
PISM_PIK_BM16_R5 = (ncf.variables["reg5"][:])
PISM_PIK_BM16_time = ncf.variables["time"][:]

PISM_PIK_BM16_SU = PISM_PIK_BM16_R1+PISM_PIK_BM16_R2+PISM_PIK_BM16_R3+PISM_PIK_BM16_R4+PISM_PIK_BM16_R5


# create and write response function
RF_PISM_PIK_BM16_R1=np.diff(PISM_PIK_BM16_R1)/np.diff(PISM_PIK_BM16_time)/16
RF_PISM_PIK_BM16_R2=np.diff(PISM_PIK_BM16_R2)/np.diff(PISM_PIK_BM16_time)/16
RF_PISM_PIK_BM16_R3=np.diff(PISM_PIK_BM16_R3)/np.diff(PISM_PIK_BM16_time)/16
RF_PISM_PIK_BM16_R4=np.diff(PISM_PIK_BM16_R4)/np.diff(PISM_PIK_BM16_time)/16
RF_PISM_PIK_BM16_R5=np.diff(PISM_PIK_BM16_R5)/np.diff(PISM_PIK_BM16_time)/16
RF_PISM_PIK_BM16_SU=np.diff(PISM_PIK_BM16_SU)/np.diff(PISM_PIK_BM16_time)/16


RF_PISM_PIK_BM16_R1=np.append(RF_PISM_PIK_BM16_R1[0],RF_PISM_PIK_BM16_R1)
RF_PISM_PIK_BM16_R2=np.append(RF_PISM_PIK_BM16_R2[0],RF_PISM_PIK_BM16_R2)
RF_PISM_PIK_BM16_R3=np.append(RF_PISM_PIK_BM16_R3[0],RF_PISM_PIK_BM16_R3)
RF_PISM_PIK_BM16_R4=np.append(RF_PISM_PIK_BM16_R4[0],RF_PISM_PIK_BM16_R4)
RF_PISM_PIK_BM16_R5=np.append(RF_PISM_PIK_BM16_R5[0],RF_PISM_PIK_BM16_R5)
RF_PISM_PIK_BM16_SU=np.append(RF_PISM_PIK_BM16_SU[0],RF_PISM_PIK_BM16_SU)


# plot
plt.plot(PISM_PIK_BM16_R1,label="PISM_PIK_BM16_R1")
plt.plot(PISM_PIK_BM16_R2,label="PISM_PIK_BM16_R2")
plt.plot(PISM_PIK_BM16_R3,label="PISM_PIK_BM16_R3")
plt.plot(PISM_PIK_BM16_R4,label="PISM_PIK_BM16_R4")
plt.plot(PISM_PIK_BM16_R5,label="PISM_PIK_BM16_R5")
plt.plot(PISM_PIK_BM16_SU,label="PISM_PIK_BM16_SU")
plt.legend()

# %%
# PISM_PIK = PISM_PIK
# Experiment BM32

fname="larmip_data/PISM_PIK/ADD5.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
PISM_PIK_BM32_R1 = (ncf.variables["reg1"][:])
PISM_PIK_BM32_R2 = (ncf.variables["reg2"][:])
PISM_PIK_BM32_R3 = (ncf.variables["reg3"][:])
PISM_PIK_BM32_R4 = (ncf.variables["reg4"][:])
PISM_PIK_BM32_R5 = (ncf.variables["reg5"][:])
PISM_PIK_BM32_time = ncf.variables["time"][:]

PISM_PIK_BM32_SU = PISM_PIK_BM32_R1+PISM_PIK_BM32_R2+PISM_PIK_BM32_R3+PISM_PIK_BM32_R4+PISM_PIK_BM32_R5


# create and write response function
RF_PISM_PIK_BM32_R1=np.diff(PISM_PIK_BM32_R1)/np.diff(PISM_PIK_BM32_time)/32
RF_PISM_PIK_BM32_R2=np.diff(PISM_PIK_BM32_R2)/np.diff(PISM_PIK_BM32_time)/32
RF_PISM_PIK_BM32_R3=np.diff(PISM_PIK_BM32_R3)/np.diff(PISM_PIK_BM32_time)/32
RF_PISM_PIK_BM32_R4=np.diff(PISM_PIK_BM32_R4)/np.diff(PISM_PIK_BM32_time)/32
RF_PISM_PIK_BM32_R5=np.diff(PISM_PIK_BM32_R5)/np.diff(PISM_PIK_BM32_time)/32
RF_PISM_PIK_BM32_SU=np.diff(PISM_PIK_BM32_SU)/np.diff(PISM_PIK_BM32_time)/32


RF_PISM_PIK_BM32_R1=np.append(RF_PISM_PIK_BM32_R1[0],RF_PISM_PIK_BM32_R1)
RF_PISM_PIK_BM32_R2=np.append(RF_PISM_PIK_BM32_R2[0],RF_PISM_PIK_BM32_R2)
RF_PISM_PIK_BM32_R3=np.append(RF_PISM_PIK_BM32_R3[0],RF_PISM_PIK_BM32_R3)
RF_PISM_PIK_BM32_R4=np.append(RF_PISM_PIK_BM32_R4[0],RF_PISM_PIK_BM32_R4)
RF_PISM_PIK_BM32_R5=np.append(RF_PISM_PIK_BM32_R5[0],RF_PISM_PIK_BM32_R5)
RF_PISM_PIK_BM32_SU=np.append(RF_PISM_PIK_BM32_SU[0],RF_PISM_PIK_BM32_SU)


# plot
plt.plot(PISM_PIK_BM32_R1,label="PISM_PIK_BM32_R1")
plt.plot(PISM_PIK_BM32_R2,label="PISM_PIK_BM32_R2")
plt.plot(PISM_PIK_BM32_R3,label="PISM_PIK_BM32_R3")
plt.plot(PISM_PIK_BM32_R4,label="PISM_PIK_BM32_R4")
plt.plot(PISM_PIK_BM32_R5,label="PISM_PIK_BM32_R5")
plt.plot(PISM_PIK_BM32_SU,label="PISM_PIK_BM32_SU")
plt.legend()

# %%
np.savetxt("RF_PISM_PIK_BM02_R1.dat", RF_PISM_PIK_BM02_R1, delimiter=",")
np.savetxt("RF_PISM_PIK_BM02_R2.dat", RF_PISM_PIK_BM02_R2, delimiter=",")
np.savetxt("RF_PISM_PIK_BM02_R3.dat", RF_PISM_PIK_BM02_R3, delimiter=",")
np.savetxt("RF_PISM_PIK_BM02_R4.dat", RF_PISM_PIK_BM02_R4, delimiter=",")
np.savetxt("RF_PISM_PIK_BM02_R5.dat", RF_PISM_PIK_BM02_R5, delimiter=",")
np.savetxt("RF_PISM_PIK_BM02_SU.dat", RF_PISM_PIK_BM02_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_PIK_BM04_R1.dat", RF_PISM_PIK_BM04_R1, delimiter=",")
np.savetxt("RF_PISM_PIK_BM04_R2.dat", RF_PISM_PIK_BM04_R2, delimiter=",")
np.savetxt("RF_PISM_PIK_BM04_R3.dat", RF_PISM_PIK_BM04_R3, delimiter=",")
np.savetxt("RF_PISM_PIK_BM04_R4.dat", RF_PISM_PIK_BM04_R4, delimiter=",")
np.savetxt("RF_PISM_PIK_BM04_R5.dat", RF_PISM_PIK_BM04_R5, delimiter=",")
np.savetxt("RF_PISM_PIK_BM04_SU.dat", RF_PISM_PIK_BM04_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_PIK_BM08_R1.dat", RF_PISM_PIK_BM08_R1, delimiter=",")
np.savetxt("RF_PISM_PIK_BM08_R2.dat", RF_PISM_PIK_BM08_R2, delimiter=",")
np.savetxt("RF_PISM_PIK_BM08_R3.dat", RF_PISM_PIK_BM08_R3, delimiter=",")
np.savetxt("RF_PISM_PIK_BM08_R4.dat", RF_PISM_PIK_BM08_R4, delimiter=",")
np.savetxt("RF_PISM_PIK_BM08_R5.dat", RF_PISM_PIK_BM08_R5, delimiter=",")
np.savetxt("RF_PISM_PIK_BM08_SU.dat", RF_PISM_PIK_BM08_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_PIK_BM16_R1.dat", RF_PISM_PIK_BM16_R1, delimiter=",")
np.savetxt("RF_PISM_PIK_BM16_R2.dat", RF_PISM_PIK_BM16_R2, delimiter=",")
np.savetxt("RF_PISM_PIK_BM16_R3.dat", RF_PISM_PIK_BM16_R3, delimiter=",")
np.savetxt("RF_PISM_PIK_BM16_R4.dat", RF_PISM_PIK_BM16_R4, delimiter=",")
np.savetxt("RF_PISM_PIK_BM16_R5.dat", RF_PISM_PIK_BM16_R5, delimiter=",")
np.savetxt("RF_PISM_PIK_BM16_SU.dat", RF_PISM_PIK_BM16_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_PIK_BM32_R1.dat", RF_PISM_PIK_BM32_R1, delimiter=",")
np.savetxt("RF_PISM_PIK_BM32_R2.dat", RF_PISM_PIK_BM32_R2, delimiter=",")
np.savetxt("RF_PISM_PIK_BM32_R3.dat", RF_PISM_PIK_BM32_R3, delimiter=",")
np.savetxt("RF_PISM_PIK_BM32_R4.dat", RF_PISM_PIK_BM32_R4, delimiter=",")
np.savetxt("RF_PISM_PIK_BM32_R5.dat", RF_PISM_PIK_BM32_R5, delimiter=",")
np.savetxt("RF_PISM_PIK_BM32_SU.dat", RF_PISM_PIK_BM32_SU, delimiter=",")

# %%
np.savetxt("PISM_PIK_BM02_R1.dat", PISM_PIK_BM02_R1, delimiter=",")
np.savetxt("PISM_PIK_BM02_R2.dat", PISM_PIK_BM02_R2, delimiter=",")
np.savetxt("PISM_PIK_BM02_R3.dat", PISM_PIK_BM02_R3, delimiter=",")
np.savetxt("PISM_PIK_BM02_R4.dat", PISM_PIK_BM02_R4, delimiter=",")
np.savetxt("PISM_PIK_BM02_R5.dat", PISM_PIK_BM02_R5, delimiter=",")
np.savetxt("PISM_PIK_BM02_SU.dat", PISM_PIK_BM02_SU, delimiter=",")

# %%
np.savetxt("PISM_PIK_BM04_R1.dat", PISM_PIK_BM04_R1, delimiter=",")
np.savetxt("PISM_PIK_BM04_R2.dat", PISM_PIK_BM04_R2, delimiter=",")
np.savetxt("PISM_PIK_BM04_R3.dat", PISM_PIK_BM04_R3, delimiter=",")
np.savetxt("PISM_PIK_BM04_R4.dat", PISM_PIK_BM04_R4, delimiter=",")
np.savetxt("PISM_PIK_BM04_R5.dat", PISM_PIK_BM04_R5, delimiter=",")
np.savetxt("PISM_PIK_BM04_SU.dat", PISM_PIK_BM04_SU, delimiter=",")

# %%
np.savetxt("PISM_PIK_BM08_R1.dat", PISM_PIK_BM08_R1, delimiter=",")
np.savetxt("PISM_PIK_BM08_R2.dat", PISM_PIK_BM08_R2, delimiter=",")
np.savetxt("PISM_PIK_BM08_R3.dat", PISM_PIK_BM08_R3, delimiter=",")
np.savetxt("PISM_PIK_BM08_R4.dat", PISM_PIK_BM08_R4, delimiter=",")
np.savetxt("PISM_PIK_BM08_R5.dat", PISM_PIK_BM08_R5, delimiter=",")
np.savetxt("PISM_PIK_BM08_SU.dat", PISM_PIK_BM08_SU, delimiter=",")

# %%
np.savetxt("PISM_PIK_BM16_R1.dat", PISM_PIK_BM16_R1, delimiter=",")
np.savetxt("PISM_PIK_BM16_R2.dat", PISM_PIK_BM16_R2, delimiter=",")
np.savetxt("PISM_PIK_BM16_R3.dat", PISM_PIK_BM16_R3, delimiter=",")
np.savetxt("PISM_PIK_BM16_R4.dat", PISM_PIK_BM16_R4, delimiter=",")
np.savetxt("PISM_PIK_BM16_R5.dat", PISM_PIK_BM16_R5, delimiter=",")
np.savetxt("PISM_PIK_BM16_SU.dat", PISM_PIK_BM16_SU, delimiter=",")

# %%
np.savetxt("PISM_PIK_BM32_R1.dat", PISM_PIK_BM32_R1, delimiter=",")
np.savetxt("PISM_PIK_BM32_R2.dat", PISM_PIK_BM32_R2, delimiter=",")
np.savetxt("PISM_PIK_BM32_R3.dat", PISM_PIK_BM32_R3, delimiter=",")
np.savetxt("PISM_PIK_BM32_R4.dat", PISM_PIK_BM32_R4, delimiter=",")
np.savetxt("PISM_PIK_BM32_R5.dat", PISM_PIK_BM32_R5, delimiter=",")
np.savetxt("PISM_PIK_BM32_SU.dat", PISM_PIK_BM32_SU, delimiter=",")
