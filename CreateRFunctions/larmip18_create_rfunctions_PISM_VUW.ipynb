# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv
#import pandas

# %%
# PISM_VUW = PISM_VUW
# Experiment BM01

PISM_VUW_BM01_R0=[]
fname = "larmip_data/PISM_VUW/realslvol_ALL-1_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM01_R0_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM01_R0.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM01_R0_5yrstep[j+1]-PISM_VUW_BM01_R0_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM01_R0.append(sl)
PISM_VUW_BM01_R0=np.array(PISM_VUW_BM01_R0[:-1])
PISM_VUW_BM01_R0_5yrstep=PISM_VUW_BM01_R0_5yrstep[1:]

PISM_VUW_BM01_R1=[]
fname = "larmip_data/PISM_VUW/realslvol_R1-1_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM01_R1_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM01_R1.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM01_R1_5yrstep[j+1]-PISM_VUW_BM01_R1_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM01_R1.append(sl)
PISM_VUW_BM01_R1=np.array(PISM_VUW_BM01_R1[:-1])
PISM_VUW_BM01_R1_5yrstep=PISM_VUW_BM01_R1_5yrstep[1:]

PISM_VUW_BM01_R2=[]
fname = "larmip_data/PISM_VUW/realslvol_R2-1_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM01_R2_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM01_R2.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM01_R2_5yrstep[j+1]-PISM_VUW_BM01_R2_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM01_R2.append(sl)
PISM_VUW_BM01_R2=np.array(PISM_VUW_BM01_R2[:-1])
PISM_VUW_BM01_R2_5yrstep=PISM_VUW_BM01_R2_5yrstep[1:]

PISM_VUW_BM01_R3=[]
fname = "larmip_data/PISM_VUW/realslvol_R3-1_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM01_R3_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM01_R3.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM01_R3_5yrstep[j+1]-PISM_VUW_BM01_R3_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM01_R3.append(sl)
PISM_VUW_BM01_R3=np.array(PISM_VUW_BM01_R3[:-1])
PISM_VUW_BM01_R3_5yrstep=PISM_VUW_BM01_R3_5yrstep[1:]

PISM_VUW_BM01_R4=[]
fname = "larmip_data/PISM_VUW/realslvol_R4-1_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM01_R4_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM01_R4.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM01_R4_5yrstep[j+1]-PISM_VUW_BM01_R4_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM01_R4.append(sl)
PISM_VUW_BM01_R4=np.array(PISM_VUW_BM01_R4[:-1])
PISM_VUW_BM01_R4_5yrstep=PISM_VUW_BM01_R4_5yrstep[1:]

PISM_VUW_BM01_R5=[]
fname = "larmip_data/PISM_VUW/realslvol_R5-1_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM01_R5_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM01_R5.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM01_R5_5yrstep[j+1]-PISM_VUW_BM01_R5_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM01_R5.append(sl)
PISM_VUW_BM01_R5=np.array(PISM_VUW_BM01_R5[:-1])
PISM_VUW_BM01_R5_5yrstep=PISM_VUW_BM01_R5_5yrstep[1:]

PISM_VUW_BM01_SU = PISM_VUW_BM01_R1+PISM_VUW_BM01_R2+PISM_VUW_BM01_R3+PISM_VUW_BM01_R4+PISM_VUW_BM01_R5


# create and write response function
RF_PISM_VUW_BM01_R0=np.diff(PISM_VUW_BM01_R0)/1
RF_PISM_VUW_BM01_R1=np.diff(PISM_VUW_BM01_R1)/1
RF_PISM_VUW_BM01_R2=np.diff(PISM_VUW_BM01_R2)/1
RF_PISM_VUW_BM01_R3=np.diff(PISM_VUW_BM01_R3)/1
RF_PISM_VUW_BM01_R4=np.diff(PISM_VUW_BM01_R4)/1
RF_PISM_VUW_BM01_R5=np.diff(PISM_VUW_BM01_R5)/1
RF_PISM_VUW_BM01_SU=np.diff(PISM_VUW_BM01_SU)/1


# plot
plt.plot(PISM_VUW_BM01_R0,label="PISM_VUW_BM01_R0")
plt.plot(PISM_VUW_BM01_R1,label="PISM_VUW_BM01_R1")
plt.plot(PISM_VUW_BM01_R2,label="PISM_VUW_BM01_R2")
plt.plot(PISM_VUW_BM01_R3,label="PISM_VUW_BM01_R3")
plt.plot(PISM_VUW_BM01_R4,label="PISM_VUW_BM01_R4")
plt.plot(PISM_VUW_BM01_R5,label="PISM_VUW_BM01_R5")
plt.plot(PISM_VUW_BM01_SU,label="PISM_VUW_BM01_SU")
plt.legend()

RF_PISM_VUW_BM01_R0=np.append(RF_PISM_VUW_BM01_R0[0],RF_PISM_VUW_BM01_R0)
RF_PISM_VUW_BM01_R1=np.append(RF_PISM_VUW_BM01_R1[0],RF_PISM_VUW_BM01_R1)
RF_PISM_VUW_BM01_R2=np.append(RF_PISM_VUW_BM01_R2[0],RF_PISM_VUW_BM01_R2)
RF_PISM_VUW_BM01_R3=np.append(RF_PISM_VUW_BM01_R3[0],RF_PISM_VUW_BM01_R3)
RF_PISM_VUW_BM01_R4=np.append(RF_PISM_VUW_BM01_R4[0],RF_PISM_VUW_BM01_R4)
RF_PISM_VUW_BM01_R5=np.append(RF_PISM_VUW_BM01_R5[0],RF_PISM_VUW_BM01_R5)
RF_PISM_VUW_BM01_SU=np.append(RF_PISM_VUW_BM01_SU[0],RF_PISM_VUW_BM01_SU)

print(len(RF_PISM_VUW_BM01_R0))
# Out:
# 200

# %%
# PISM_VUW = PISM_VUW
# Experiment BM02

PISM_VUW_BM02_R0=[]
fname = "larmip_data/PISM_VUW/realslvol_ALL-2_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM02_R0_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM02_R0.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM02_R0_5yrstep[j+1]-PISM_VUW_BM02_R0_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM02_R0.append(sl)
PISM_VUW_BM02_R0=np.array(PISM_VUW_BM02_R0[:-1])
PISM_VUW_BM02_R0_5yrstep=PISM_VUW_BM02_R0_5yrstep[1:]

PISM_VUW_BM02_R1=[]
fname = "larmip_data/PISM_VUW/realslvol_R1-2_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM02_R1_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM02_R1.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM02_R1_5yrstep[j+1]-PISM_VUW_BM02_R1_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM02_R1.append(sl)
PISM_VUW_BM02_R1=np.array(PISM_VUW_BM02_R1[:-1])
PISM_VUW_BM02_R1_5yrstep=PISM_VUW_BM02_R1_5yrstep[1:]

PISM_VUW_BM02_R2=[]
fname = "larmip_data/PISM_VUW/realslvol_R2-2_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM02_R2_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM02_R2.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM02_R2_5yrstep[j+1]-PISM_VUW_BM02_R2_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM02_R2.append(sl)
PISM_VUW_BM02_R2=np.array(PISM_VUW_BM02_R2[:-1])
PISM_VUW_BM02_R2_5yrstep=PISM_VUW_BM02_R2_5yrstep[1:]

PISM_VUW_BM02_R3=[]
fname = "larmip_data/PISM_VUW/realslvol_R3-2_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM02_R3_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM02_R3.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM02_R3_5yrstep[j+1]-PISM_VUW_BM02_R3_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM02_R3.append(sl)
PISM_VUW_BM02_R3=np.array(PISM_VUW_BM02_R3[:-1])
PISM_VUW_BM02_R3_5yrstep=PISM_VUW_BM02_R3_5yrstep[1:]

PISM_VUW_BM02_R4=[]
fname = "larmip_data/PISM_VUW/realslvol_R4-2_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM02_R4_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM02_R4.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM02_R4_5yrstep[j+1]-PISM_VUW_BM02_R4_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM02_R4.append(sl)
PISM_VUW_BM02_R4=np.array(PISM_VUW_BM02_R4[:-1])
PISM_VUW_BM02_R4_5yrstep=PISM_VUW_BM02_R4_5yrstep[1:]

PISM_VUW_BM02_R5=[]
fname = "larmip_data/PISM_VUW/realslvol_R5-2_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM02_R5_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM02_R5.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM02_R5_5yrstep[j+1]-PISM_VUW_BM02_R5_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM02_R5.append(sl)
PISM_VUW_BM02_R5=np.array(PISM_VUW_BM02_R5[:-1])
PISM_VUW_BM02_R5_5yrstep=PISM_VUW_BM02_R5_5yrstep[1:]

PISM_VUW_BM02_SU = PISM_VUW_BM02_R1+PISM_VUW_BM02_R2+PISM_VUW_BM02_R3+PISM_VUW_BM02_R4+PISM_VUW_BM02_R5


# create and write response function
RF_PISM_VUW_BM02_R0=np.diff(PISM_VUW_BM02_R0)/2
RF_PISM_VUW_BM02_R1=np.diff(PISM_VUW_BM02_R1)/2
RF_PISM_VUW_BM02_R2=np.diff(PISM_VUW_BM02_R2)/2
RF_PISM_VUW_BM02_R3=np.diff(PISM_VUW_BM02_R3)/2
RF_PISM_VUW_BM02_R4=np.diff(PISM_VUW_BM02_R4)/2
RF_PISM_VUW_BM02_R5=np.diff(PISM_VUW_BM02_R5)/2
RF_PISM_VUW_BM02_SU=np.diff(PISM_VUW_BM02_SU)/2


# plot
plt.plot(PISM_VUW_BM02_R0,label="PISM_VUW_BM02_R0")
plt.plot(PISM_VUW_BM02_R1,label="PISM_VUW_BM02_R1")
plt.plot(PISM_VUW_BM02_R2,label="PISM_VUW_BM02_R2")
plt.plot(PISM_VUW_BM02_R3,label="PISM_VUW_BM02_R3")
plt.plot(PISM_VUW_BM02_R4,label="PISM_VUW_BM02_R4")
plt.plot(PISM_VUW_BM02_R5,label="PISM_VUW_BM02_R5")
plt.plot(PISM_VUW_BM02_SU,label="PISM_VUW_BM02_SU")
#plt.plot(time,PISM_VUW_BM02_R0_5yrstep,label="PISM_VUW_BM02_R0_5yrstep")
#plt.plot(time,PISM_VUW_BM02_R1_5yrstep,label="PISM_VUW_BM02_R1_5yrstep")
#plt.plot(time,PISM_VUW_BM02_R2_5yrstep,label="PISM_VUW_BM02_R2_5yrstep")
#plt.plot(time,PISM_VUW_BM02_R3_5yrstep,label="PISM_VUW_BM02_R3_5yrstep")
#plt.plot(time,PISM_VUW_BM02_R4_5yrstep,label="PISM_VUW_BM02_R4_5yrstep")
#plt.plot(time,PISM_VUW_BM02_R5_5yrstep,label="PISM_VUW_BM02_R5_5yrstep")
plt.legend()

RF_PISM_VUW_BM02_R0=np.append(RF_PISM_VUW_BM02_R0[0],RF_PISM_VUW_BM02_R0)
RF_PISM_VUW_BM02_R1=np.append(RF_PISM_VUW_BM02_R1[0],RF_PISM_VUW_BM02_R1)
RF_PISM_VUW_BM02_R2=np.append(RF_PISM_VUW_BM02_R2[0],RF_PISM_VUW_BM02_R2)
RF_PISM_VUW_BM02_R3=np.append(RF_PISM_VUW_BM02_R3[0],RF_PISM_VUW_BM02_R3)
RF_PISM_VUW_BM02_R4=np.append(RF_PISM_VUW_BM02_R4[0],RF_PISM_VUW_BM02_R4)
RF_PISM_VUW_BM02_R5=np.append(RF_PISM_VUW_BM02_R5[0],RF_PISM_VUW_BM02_R5)
RF_PISM_VUW_BM02_SU=np.append(RF_PISM_VUW_BM02_SU[0],RF_PISM_VUW_BM02_SU)

print(len(RF_PISM_VUW_BM02_R0))
# Out:
# 200

# %%
# PISM_VUW = PISM_VUW
# Experiment BM04

PISM_VUW_BM04_R0=[]
fname = "larmip_data/PISM_VUW/realslvol_ALL-4_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM04_R0_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM04_R0.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM04_R0_5yrstep[j+1]-PISM_VUW_BM04_R0_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM04_R0.append(sl)
PISM_VUW_BM04_R0=np.array(PISM_VUW_BM04_R0[:-1])
PISM_VUW_BM04_R0_5yrstep=PISM_VUW_BM04_R0_5yrstep[1:]

PISM_VUW_BM04_R1=[]
fname = "larmip_data/PISM_VUW/realslvol_R1-4_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM04_R1_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM04_R1.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM04_R1_5yrstep[j+1]-PISM_VUW_BM04_R1_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM04_R1.append(sl)
PISM_VUW_BM04_R1=np.array(PISM_VUW_BM04_R1[:-1])
PISM_VUW_BM04_R1_5yrstep=PISM_VUW_BM04_R1_5yrstep[1:]

PISM_VUW_BM04_R2=[]
fname = "larmip_data/PISM_VUW/realslvol_R2-4_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM04_R2_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM04_R2.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM04_R2_5yrstep[j+1]-PISM_VUW_BM04_R2_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM04_R2.append(sl)
PISM_VUW_BM04_R2=np.array(PISM_VUW_BM04_R2[:-1])
PISM_VUW_BM04_R2_5yrstep=PISM_VUW_BM04_R2_5yrstep[1:]

PISM_VUW_BM04_R3=[]
fname = "larmip_data/PISM_VUW/realslvol_R3-4_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM04_R3_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM04_R3.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM04_R3_5yrstep[j+1]-PISM_VUW_BM04_R3_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM04_R3.append(sl)
PISM_VUW_BM04_R3=np.array(PISM_VUW_BM04_R3[:-1])
PISM_VUW_BM04_R3_5yrstep=PISM_VUW_BM04_R3_5yrstep[1:]

PISM_VUW_BM04_R4=[]
fname = "larmip_data/PISM_VUW/realslvol_R4-4_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM04_R4_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM04_R4.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM04_R4_5yrstep[j+1]-PISM_VUW_BM04_R4_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM04_R4.append(sl)
PISM_VUW_BM04_R4=np.array(PISM_VUW_BM04_R4[:-1])
PISM_VUW_BM04_R4_5yrstep=PISM_VUW_BM04_R4_5yrstep[1:]

PISM_VUW_BM04_R5=[]
fname = "larmip_data/PISM_VUW/realslvol_R5-4_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM04_R5_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM04_R5.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM04_R5_5yrstep[j+1]-PISM_VUW_BM04_R5_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM04_R5.append(sl)
PISM_VUW_BM04_R5=np.array(PISM_VUW_BM04_R5[:-1])
PISM_VUW_BM04_R5_5yrstep=PISM_VUW_BM04_R5_5yrstep[1:]

PISM_VUW_BM04_SU = PISM_VUW_BM04_R1+PISM_VUW_BM04_R2+PISM_VUW_BM04_R3+PISM_VUW_BM04_R4+PISM_VUW_BM04_R5


# create and write response function
RF_PISM_VUW_BM04_R0=np.diff(PISM_VUW_BM04_R0)/4
RF_PISM_VUW_BM04_R1=np.diff(PISM_VUW_BM04_R1)/4
RF_PISM_VUW_BM04_R2=np.diff(PISM_VUW_BM04_R2)/4
RF_PISM_VUW_BM04_R3=np.diff(PISM_VUW_BM04_R3)/4
RF_PISM_VUW_BM04_R4=np.diff(PISM_VUW_BM04_R4)/4
RF_PISM_VUW_BM04_R5=np.diff(PISM_VUW_BM04_R5)/4
RF_PISM_VUW_BM04_SU=np.diff(PISM_VUW_BM04_SU)/4


# plot
plt.plot(PISM_VUW_BM04_R0,label="PISM_VUW_BM04_R0")
plt.plot(PISM_VUW_BM04_R1,label="PISM_VUW_BM04_R1")
plt.plot(PISM_VUW_BM04_R2,label="PISM_VUW_BM04_R2")
plt.plot(PISM_VUW_BM04_R3,label="PISM_VUW_BM04_R3")
plt.plot(PISM_VUW_BM04_R4,label="PISM_VUW_BM04_R4")
plt.plot(PISM_VUW_BM04_R5,label="PISM_VUW_BM04_R5")
plt.plot(PISM_VUW_BM04_SU,label="PISM_VUW_BM04_SU")
#plt.plot(time,PISM_VUW_BM04_R0_5yrstep,label="PISM_VUW_BM04_R0_5yrstep")
#plt.plot(time,PISM_VUW_BM04_R1_5yrstep,label="PISM_VUW_BM04_R1_5yrstep")
#plt.plot(time,PISM_VUW_BM04_R2_5yrstep,label="PISM_VUW_BM04_R2_5yrstep")
#plt.plot(time,PISM_VUW_BM04_R3_5yrstep,label="PISM_VUW_BM04_R3_5yrstep")
#plt.plot(time,PISM_VUW_BM04_R4_5yrstep,label="PISM_VUW_BM04_R4_5yrstep")
#plt.plot(time,PISM_VUW_BM04_R5_5yrstep,label="PISM_VUW_BM04_R5_5yrstep")
plt.legend()

RF_PISM_VUW_BM04_R0=np.append(RF_PISM_VUW_BM04_R0[0],RF_PISM_VUW_BM04_R0)
RF_PISM_VUW_BM04_R1=np.append(RF_PISM_VUW_BM04_R1[0],RF_PISM_VUW_BM04_R1)
RF_PISM_VUW_BM04_R2=np.append(RF_PISM_VUW_BM04_R2[0],RF_PISM_VUW_BM04_R2)
RF_PISM_VUW_BM04_R3=np.append(RF_PISM_VUW_BM04_R3[0],RF_PISM_VUW_BM04_R3)
RF_PISM_VUW_BM04_R4=np.append(RF_PISM_VUW_BM04_R4[0],RF_PISM_VUW_BM04_R4)
RF_PISM_VUW_BM04_R5=np.append(RF_PISM_VUW_BM04_R5[0],RF_PISM_VUW_BM04_R5)
RF_PISM_VUW_BM04_SU=np.append(RF_PISM_VUW_BM04_SU[0],RF_PISM_VUW_BM04_SU)

print(len(RF_PISM_VUW_BM04_R0))
# Out:
# 200

# %%
# PISM_VUW = PISM_VUW
# Experiment BM08

PISM_VUW_BM08_R0=[]
fname = "larmip_data/PISM_VUW/realslvol_ALL-8_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM08_R0_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM08_R0.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM08_R0_5yrstep[j+1]-PISM_VUW_BM08_R0_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM08_R0.append(sl)
PISM_VUW_BM08_R0=np.array(PISM_VUW_BM08_R0[:-1])
PISM_VUW_BM08_R0_5yrstep=PISM_VUW_BM08_R0_5yrstep[1:]

PISM_VUW_BM08_R1=[]
fname = "larmip_data/PISM_VUW/realslvol_R1-8_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM08_R1_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM08_R1.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM08_R1_5yrstep[j+1]-PISM_VUW_BM08_R1_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM08_R1.append(sl)
PISM_VUW_BM08_R1=np.array(PISM_VUW_BM08_R1[:-1])
PISM_VUW_BM08_R1_5yrstep=PISM_VUW_BM08_R1_5yrstep[1:]

PISM_VUW_BM08_R2=[]
fname = "larmip_data/PISM_VUW/realslvol_R2-8_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM08_R2_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM08_R2.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM08_R2_5yrstep[j+1]-PISM_VUW_BM08_R2_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM08_R2.append(sl)
PISM_VUW_BM08_R2=np.array(PISM_VUW_BM08_R2[:-1])
PISM_VUW_BM08_R2_5yrstep=PISM_VUW_BM08_R2_5yrstep[1:]

PISM_VUW_BM08_R3=[]
fname = "larmip_data/PISM_VUW/realslvol_R3-8_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM08_R3_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM08_R3.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM08_R3_5yrstep[j+1]-PISM_VUW_BM08_R3_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM08_R3.append(sl)
PISM_VUW_BM08_R3=np.array(PISM_VUW_BM08_R3[:-1])
PISM_VUW_BM08_R3_5yrstep=PISM_VUW_BM08_R3_5yrstep[1:]

PISM_VUW_BM08_R4=[]
fname = "larmip_data/PISM_VUW/realslvol_R4-8_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM08_R4_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM08_R4.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM08_R4_5yrstep[j+1]-PISM_VUW_BM08_R4_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM08_R4.append(sl)
PISM_VUW_BM08_R4=np.array(PISM_VUW_BM08_R4[:-1])
PISM_VUW_BM08_R4_5yrstep=PISM_VUW_BM08_R4_5yrstep[1:]

PISM_VUW_BM08_R5=[]
fname = "larmip_data/PISM_VUW/realslvol_R5-8_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM08_R5_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM08_R5.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM08_R5_5yrstep[j+1]-PISM_VUW_BM08_R5_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM08_R5.append(sl)
PISM_VUW_BM08_R5=np.array(PISM_VUW_BM08_R5[:-1])
PISM_VUW_BM08_R5_5yrstep=PISM_VUW_BM08_R5_5yrstep[1:]

PISM_VUW_BM08_SU = PISM_VUW_BM08_R1+PISM_VUW_BM08_R2+PISM_VUW_BM08_R3+PISM_VUW_BM08_R4+PISM_VUW_BM08_R5


# create and write response function
RF_PISM_VUW_BM08_R0=np.diff(PISM_VUW_BM08_R0)/8
RF_PISM_VUW_BM08_R1=np.diff(PISM_VUW_BM08_R1)/8
RF_PISM_VUW_BM08_R2=np.diff(PISM_VUW_BM08_R2)/8
RF_PISM_VUW_BM08_R3=np.diff(PISM_VUW_BM08_R3)/8
RF_PISM_VUW_BM08_R4=np.diff(PISM_VUW_BM08_R4)/8
RF_PISM_VUW_BM08_R5=np.diff(PISM_VUW_BM08_R5)/8
RF_PISM_VUW_BM08_SU=np.diff(PISM_VUW_BM08_SU)/8


# plot
plt.plot(PISM_VUW_BM08_R0,label="PISM_VUW_BM08_R0")
plt.plot(PISM_VUW_BM08_R1,label="PISM_VUW_BM08_R1")
plt.plot(PISM_VUW_BM08_R2,label="PISM_VUW_BM08_R2")
plt.plot(PISM_VUW_BM08_R3,label="PISM_VUW_BM08_R3")
plt.plot(PISM_VUW_BM08_R4,label="PISM_VUW_BM08_R4")
plt.plot(PISM_VUW_BM08_R5,label="PISM_VUW_BM08_R5")
plt.plot(PISM_VUW_BM08_SU,label="PISM_VUW_BM08_SU")
#plt.plot(time,PISM_VUW_BM08_R0_5yrstep,label="PISM_VUW_BM08_R0_5yrstep")
#plt.plot(time,PISM_VUW_BM08_R1_5yrstep,label="PISM_VUW_BM08_R1_5yrstep")
#plt.plot(time,PISM_VUW_BM08_R2_5yrstep,label="PISM_VUW_BM08_R2_5yrstep")
#plt.plot(time,PISM_VUW_BM08_R3_5yrstep,label="PISM_VUW_BM08_R3_5yrstep")
#plt.plot(time,PISM_VUW_BM08_R4_5yrstep,label="PISM_VUW_BM08_R4_5yrstep")
#plt.plot(time,PISM_VUW_BM08_R5_5yrstep,label="PISM_VUW_BM08_R5_5yrstep")
plt.legend()

RF_PISM_VUW_BM08_R0=np.append(RF_PISM_VUW_BM08_R0[0],RF_PISM_VUW_BM08_R0)
RF_PISM_VUW_BM08_R1=np.append(RF_PISM_VUW_BM08_R1[0],RF_PISM_VUW_BM08_R1)
RF_PISM_VUW_BM08_R2=np.append(RF_PISM_VUW_BM08_R2[0],RF_PISM_VUW_BM08_R2)
RF_PISM_VUW_BM08_R3=np.append(RF_PISM_VUW_BM08_R3[0],RF_PISM_VUW_BM08_R3)
RF_PISM_VUW_BM08_R4=np.append(RF_PISM_VUW_BM08_R4[0],RF_PISM_VUW_BM08_R4)
RF_PISM_VUW_BM08_R5=np.append(RF_PISM_VUW_BM08_R5[0],RF_PISM_VUW_BM08_R5)
RF_PISM_VUW_BM08_SU=np.append(RF_PISM_VUW_BM08_SU[0],RF_PISM_VUW_BM08_SU)

print(len(RF_PISM_VUW_BM08_R0))
# Out:
# 200

# %%
# PISM_VUW = PISM_VUW
# Experiment BM16

PISM_VUW_BM16_R0=[]
fname = "larmip_data/PISM_VUW/realslvol_ALL-16_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM16_R0_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM16_R0.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM16_R0_5yrstep[j+1]-PISM_VUW_BM16_R0_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM16_R0.append(sl)
PISM_VUW_BM16_R0=np.array(PISM_VUW_BM16_R0[:-1])
PISM_VUW_BM16_R0_5yrstep=PISM_VUW_BM16_R0_5yrstep[1:]

PISM_VUW_BM16_R1=[]
fname = "larmip_data/PISM_VUW/realslvol_R1-16_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM16_R1_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM16_R1.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM16_R1_5yrstep[j+1]-PISM_VUW_BM16_R1_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM16_R1.append(sl)
PISM_VUW_BM16_R1=np.array(PISM_VUW_BM16_R1[:-1])
PISM_VUW_BM16_R1_5yrstep=PISM_VUW_BM16_R1_5yrstep[1:]

PISM_VUW_BM16_R2=[]
fname = "larmip_data/PISM_VUW/realslvol_R2-16_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM16_R2_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM16_R2.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM16_R2_5yrstep[j+1]-PISM_VUW_BM16_R2_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM16_R2.append(sl)
PISM_VUW_BM16_R2=np.array(PISM_VUW_BM16_R2[:-1])
PISM_VUW_BM16_R2_5yrstep=PISM_VUW_BM16_R2_5yrstep[1:]

PISM_VUW_BM16_R3=[]
fname = "larmip_data/PISM_VUW/realslvol_R3-16_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM16_R3_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM16_R3.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM16_R3_5yrstep[j+1]-PISM_VUW_BM16_R3_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM16_R3.append(sl)
PISM_VUW_BM16_R3=np.array(PISM_VUW_BM16_R3[:-1])
PISM_VUW_BM16_R3_5yrstep=PISM_VUW_BM16_R3_5yrstep[1:]

PISM_VUW_BM16_R4=[]
fname = "larmip_data/PISM_VUW/realslvol_R4-16_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM16_R4_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM16_R4.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM16_R4_5yrstep[j+1]-PISM_VUW_BM16_R4_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM16_R4.append(sl)
PISM_VUW_BM16_R4=np.array(PISM_VUW_BM16_R4[:-1])
PISM_VUW_BM16_R4_5yrstep=PISM_VUW_BM16_R4_5yrstep[1:]

PISM_VUW_BM16_R5=[]
fname = "larmip_data/PISM_VUW/realslvol_R5-16_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM16_R5_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM16_R5.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM16_R5_5yrstep[j+1]-PISM_VUW_BM16_R5_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM16_R5.append(sl)
PISM_VUW_BM16_R5=np.array(PISM_VUW_BM16_R5[:-1])
PISM_VUW_BM16_R5_5yrstep=PISM_VUW_BM16_R5_5yrstep[1:]

PISM_VUW_BM16_SU = PISM_VUW_BM16_R1+PISM_VUW_BM16_R2+PISM_VUW_BM16_R3+PISM_VUW_BM16_R4+PISM_VUW_BM16_R5


# create and write response function
RF_PISM_VUW_BM16_R0=np.diff(PISM_VUW_BM16_R0)/16
RF_PISM_VUW_BM16_R1=np.diff(PISM_VUW_BM16_R1)/16
RF_PISM_VUW_BM16_R2=np.diff(PISM_VUW_BM16_R2)/16
RF_PISM_VUW_BM16_R3=np.diff(PISM_VUW_BM16_R3)/16
RF_PISM_VUW_BM16_R4=np.diff(PISM_VUW_BM16_R4)/16
RF_PISM_VUW_BM16_R5=np.diff(PISM_VUW_BM16_R5)/16
RF_PISM_VUW_BM16_SU=np.diff(PISM_VUW_BM16_SU)/16


# plot
plt.plot(PISM_VUW_BM16_R0,label="PISM_VUW_BM16_R0")
plt.plot(PISM_VUW_BM16_R1,label="PISM_VUW_BM16_R1")
plt.plot(PISM_VUW_BM16_R2,label="PISM_VUW_BM16_R2")
plt.plot(PISM_VUW_BM16_R3,label="PISM_VUW_BM16_R3")
plt.plot(PISM_VUW_BM16_R4,label="PISM_VUW_BM16_R4")
plt.plot(PISM_VUW_BM16_R5,label="PISM_VUW_BM16_R5")
plt.plot(PISM_VUW_BM16_SU,label="PISM_VUW_BM16_SU")
#plt.plot(time,PISM_VUW_BM16_R0_5yrstep,label="PISM_VUW_BM16_R0_5yrstep")
#plt.plot(time,PISM_VUW_BM16_R1_5yrstep,label="PISM_VUW_BM16_R1_5yrstep")
#plt.plot(time,PISM_VUW_BM16_R2_5yrstep,label="PISM_VUW_BM16_R2_5yrstep")
#plt.plot(time,PISM_VUW_BM16_R3_5yrstep,label="PISM_VUW_BM16_R3_5yrstep")
#plt.plot(time,PISM_VUW_BM16_R4_5yrstep,label="PISM_VUW_BM16_R4_5yrstep")
#plt.plot(time,PISM_VUW_BM16_R5_5yrstep,label="PISM_VUW_BM16_R5_5yrstep")
plt.legend()

RF_PISM_VUW_BM16_R0=np.append(RF_PISM_VUW_BM16_R0[0],RF_PISM_VUW_BM16_R0)
RF_PISM_VUW_BM16_R1=np.append(RF_PISM_VUW_BM16_R1[0],RF_PISM_VUW_BM16_R1)
RF_PISM_VUW_BM16_R2=np.append(RF_PISM_VUW_BM16_R2[0],RF_PISM_VUW_BM16_R2)
RF_PISM_VUW_BM16_R3=np.append(RF_PISM_VUW_BM16_R3[0],RF_PISM_VUW_BM16_R3)
RF_PISM_VUW_BM16_R4=np.append(RF_PISM_VUW_BM16_R4[0],RF_PISM_VUW_BM16_R4)
RF_PISM_VUW_BM16_R5=np.append(RF_PISM_VUW_BM16_R5[0],RF_PISM_VUW_BM16_R5)
RF_PISM_VUW_BM16_SU=np.append(RF_PISM_VUW_BM16_SU[0],RF_PISM_VUW_BM16_SU)

print(len(RF_PISM_VUW_BM16_R0))
# Out:
# 200

# %%
# PISM_VUW = PISM_VUW
# Experiment BM32

PISM_VUW_BM32_R0=[]
fname = "larmip_data/PISM_VUW/realslvol_ALL-32_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM32_R0_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM32_R0.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM32_R0_5yrstep[j+1]-PISM_VUW_BM32_R0_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM32_R0.append(sl)
PISM_VUW_BM32_R0=np.array(PISM_VUW_BM32_R0[:-1])
PISM_VUW_BM32_R0_5yrstep=PISM_VUW_BM32_R0_5yrstep[1:]

PISM_VUW_BM32_R1=[]
fname = "larmip_data/PISM_VUW/realslvol_R1-32_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM32_R1_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM32_R1.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM32_R1_5yrstep[j+1]-PISM_VUW_BM32_R1_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM32_R1.append(sl)
PISM_VUW_BM32_R1=np.array(PISM_VUW_BM32_R1[:-1])
PISM_VUW_BM32_R1_5yrstep=PISM_VUW_BM32_R1_5yrstep[1:]

PISM_VUW_BM32_R2=[]
fname = "larmip_data/PISM_VUW/realslvol_R2-32_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM32_R2_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM32_R2.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM32_R2_5yrstep[j+1]-PISM_VUW_BM32_R2_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM32_R2.append(sl)
PISM_VUW_BM32_R2=np.array(PISM_VUW_BM32_R2[:-1])
PISM_VUW_BM32_R2_5yrstep=PISM_VUW_BM32_R2_5yrstep[1:]

PISM_VUW_BM32_R3=[]
fname = "larmip_data/PISM_VUW/realslvol_R3-32_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM32_R3_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM32_R3.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM32_R3_5yrstep[j+1]-PISM_VUW_BM32_R3_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM32_R3.append(sl)
PISM_VUW_BM32_R3=np.array(PISM_VUW_BM32_R3[:-1])
PISM_VUW_BM32_R3_5yrstep=PISM_VUW_BM32_R3_5yrstep[1:]

PISM_VUW_BM32_R4=[]
fname = "larmip_data/PISM_VUW/realslvol_R4-32_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM32_R4_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM32_R4.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM32_R4_5yrstep[j+1]-PISM_VUW_BM32_R4_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM32_R4.append(sl)
PISM_VUW_BM32_R4=np.array(PISM_VUW_BM32_R4[:-1])
PISM_VUW_BM32_R4_5yrstep=PISM_VUW_BM32_R4_5yrstep[1:]

PISM_VUW_BM32_R5=[]
fname = "larmip_data/PISM_VUW/realslvol_R5-32_sgm.txt" # File to read
with open(fname) as f:
    PISM_VUW_BM32_R5_5yrstep = np.array([float(row[5:]) for row in f])
sl = 0.0
PISM_VUW_BM32_R5.append(sl)
for j in range(40):
    sl_step = (PISM_VUW_BM32_R5_5yrstep[j+1]-PISM_VUW_BM32_R5_5yrstep[j])/5
    for i in range(5):
        sl = sl+sl_step
        PISM_VUW_BM32_R5.append(sl)
PISM_VUW_BM32_R5=np.array(PISM_VUW_BM32_R5[:-1])
PISM_VUW_BM32_R5_5yrstep=PISM_VUW_BM32_R5_5yrstep[1:]

PISM_VUW_BM32_SU = PISM_VUW_BM32_R1+PISM_VUW_BM32_R2+PISM_VUW_BM32_R3+PISM_VUW_BM32_R4+PISM_VUW_BM32_R5


# create and write response function
RF_PISM_VUW_BM32_R0=np.diff(PISM_VUW_BM32_R0)/32
RF_PISM_VUW_BM32_R1=np.diff(PISM_VUW_BM32_R1)/32
RF_PISM_VUW_BM32_R2=np.diff(PISM_VUW_BM32_R2)/32
RF_PISM_VUW_BM32_R3=np.diff(PISM_VUW_BM32_R3)/32
RF_PISM_VUW_BM32_R4=np.diff(PISM_VUW_BM32_R4)/32
RF_PISM_VUW_BM32_R5=np.diff(PISM_VUW_BM32_R5)/32
RF_PISM_VUW_BM32_SU=np.diff(PISM_VUW_BM32_SU)/32


# plot
plt.plot(PISM_VUW_BM32_R0,label="PISM_VUW_BM32_R0")
plt.plot(PISM_VUW_BM32_R1,label="PISM_VUW_BM32_R1")
plt.plot(PISM_VUW_BM32_R2,label="PISM_VUW_BM32_R2")
plt.plot(PISM_VUW_BM32_R3,label="PISM_VUW_BM32_R3")
plt.plot(PISM_VUW_BM32_R4,label="PISM_VUW_BM32_R4")
plt.plot(PISM_VUW_BM32_R5,label="PISM_VUW_BM32_R5")
plt.plot(PISM_VUW_BM32_SU,label="PISM_VUW_BM32_SU")
#plt.plot(time,PISM_VUW_BM32_R0_5yrstep,label="PISM_VUW_BM32_R0_5yrstep")
#plt.plot(time,PISM_VUW_BM32_R1_5yrstep,label="PISM_VUW_BM32_R1_5yrstep")
#plt.plot(time,PISM_VUW_BM32_R2_5yrstep,label="PISM_VUW_BM32_R2_5yrstep")
#plt.plot(time,PISM_VUW_BM32_R3_5yrstep,label="PISM_VUW_BM32_R3_5yrstep")
#plt.plot(time,PISM_VUW_BM32_R4_5yrstep,label="PISM_VUW_BM32_R4_5yrstep")
#plt.plot(time,PISM_VUW_BM32_R5_5yrstep,label="PISM_VUW_BM32_R5_5yrstep")
plt.legend()

RF_PISM_VUW_BM32_R0=np.append(RF_PISM_VUW_BM32_R0[0],RF_PISM_VUW_BM32_R0)
RF_PISM_VUW_BM32_R1=np.append(RF_PISM_VUW_BM32_R1[0],RF_PISM_VUW_BM32_R1)
RF_PISM_VUW_BM32_R2=np.append(RF_PISM_VUW_BM32_R2[0],RF_PISM_VUW_BM32_R2)
RF_PISM_VUW_BM32_R3=np.append(RF_PISM_VUW_BM32_R3[0],RF_PISM_VUW_BM32_R3)
RF_PISM_VUW_BM32_R4=np.append(RF_PISM_VUW_BM32_R4[0],RF_PISM_VUW_BM32_R4)
RF_PISM_VUW_BM32_R5=np.append(RF_PISM_VUW_BM32_R5[0],RF_PISM_VUW_BM32_R5)
RF_PISM_VUW_BM32_SU=np.append(RF_PISM_VUW_BM32_SU[0],RF_PISM_VUW_BM32_SU)

print(len(RF_PISM_VUW_BM32_R0))
# Out:
# 200

# %%
# Response functions
np.savetxt("RF_PISM_VUW_BM01_R0.dat", RF_PISM_VUW_BM01_R0, delimiter=",")
np.savetxt("RF_PISM_VUW_BM01_R1.dat", RF_PISM_VUW_BM01_R1, delimiter=",")
np.savetxt("RF_PISM_VUW_BM01_R2.dat", RF_PISM_VUW_BM01_R2, delimiter=",")
np.savetxt("RF_PISM_VUW_BM01_R3.dat", RF_PISM_VUW_BM01_R3, delimiter=",")
np.savetxt("RF_PISM_VUW_BM01_R4.dat", RF_PISM_VUW_BM01_R4, delimiter=",")
np.savetxt("RF_PISM_VUW_BM01_R5.dat", RF_PISM_VUW_BM01_R5, delimiter=",")
np.savetxt("RF_PISM_VUW_BM01_SU.dat", RF_PISM_VUW_BM01_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_VUW_BM02_R0.dat", RF_PISM_VUW_BM02_R0, delimiter=",")
np.savetxt("RF_PISM_VUW_BM02_R1.dat", RF_PISM_VUW_BM02_R1, delimiter=",")
np.savetxt("RF_PISM_VUW_BM02_R2.dat", RF_PISM_VUW_BM02_R2, delimiter=",")
np.savetxt("RF_PISM_VUW_BM02_R3.dat", RF_PISM_VUW_BM02_R3, delimiter=",")
np.savetxt("RF_PISM_VUW_BM02_R4.dat", RF_PISM_VUW_BM02_R4, delimiter=",")
np.savetxt("RF_PISM_VUW_BM02_R5.dat", RF_PISM_VUW_BM02_R5, delimiter=",")
np.savetxt("RF_PISM_VUW_BM02_SU.dat", RF_PISM_VUW_BM02_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_VUW_BM04_R0.dat", RF_PISM_VUW_BM04_R0, delimiter=",")
np.savetxt("RF_PISM_VUW_BM04_R1.dat", RF_PISM_VUW_BM04_R1, delimiter=",")
np.savetxt("RF_PISM_VUW_BM04_R2.dat", RF_PISM_VUW_BM04_R2, delimiter=",")
np.savetxt("RF_PISM_VUW_BM04_R3.dat", RF_PISM_VUW_BM04_R3, delimiter=",")
np.savetxt("RF_PISM_VUW_BM04_R4.dat", RF_PISM_VUW_BM04_R4, delimiter=",")
np.savetxt("RF_PISM_VUW_BM04_R5.dat", RF_PISM_VUW_BM04_R5, delimiter=",")
np.savetxt("RF_PISM_VUW_BM04_SU.dat", RF_PISM_VUW_BM04_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_VUW_BM08_R0.dat", RF_PISM_VUW_BM08_R0, delimiter=",")
np.savetxt("RF_PISM_VUW_BM08_R1.dat", RF_PISM_VUW_BM08_R1, delimiter=",")
np.savetxt("RF_PISM_VUW_BM08_R2.dat", RF_PISM_VUW_BM08_R2, delimiter=",")
np.savetxt("RF_PISM_VUW_BM08_R3.dat", RF_PISM_VUW_BM08_R3, delimiter=",")
np.savetxt("RF_PISM_VUW_BM08_R4.dat", RF_PISM_VUW_BM08_R4, delimiter=",")
np.savetxt("RF_PISM_VUW_BM08_R5.dat", RF_PISM_VUW_BM08_R5, delimiter=",")
np.savetxt("RF_PISM_VUW_BM08_SU.dat", RF_PISM_VUW_BM08_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_VUW_BM16_R0.dat", RF_PISM_VUW_BM16_R0, delimiter=",")
np.savetxt("RF_PISM_VUW_BM16_R1.dat", RF_PISM_VUW_BM16_R1, delimiter=",")
np.savetxt("RF_PISM_VUW_BM16_R2.dat", RF_PISM_VUW_BM16_R2, delimiter=",")
np.savetxt("RF_PISM_VUW_BM16_R3.dat", RF_PISM_VUW_BM16_R3, delimiter=",")
np.savetxt("RF_PISM_VUW_BM16_R4.dat", RF_PISM_VUW_BM16_R4, delimiter=",")
np.savetxt("RF_PISM_VUW_BM16_R5.dat", RF_PISM_VUW_BM16_R5, delimiter=",")
np.savetxt("RF_PISM_VUW_BM16_SU.dat", RF_PISM_VUW_BM16_SU, delimiter=",")

# %%
np.savetxt("RF_PISM_VUW_BM32_R0.dat", RF_PISM_VUW_BM32_R0, delimiter=",")
np.savetxt("RF_PISM_VUW_BM32_R1.dat", RF_PISM_VUW_BM32_R1, delimiter=",")
np.savetxt("RF_PISM_VUW_BM32_R2.dat", RF_PISM_VUW_BM32_R2, delimiter=",")
np.savetxt("RF_PISM_VUW_BM32_R3.dat", RF_PISM_VUW_BM32_R3, delimiter=",")
np.savetxt("RF_PISM_VUW_BM32_R4.dat", RF_PISM_VUW_BM32_R4, delimiter=",")
np.savetxt("RF_PISM_VUW_BM32_R5.dat", RF_PISM_VUW_BM32_R5, delimiter=",")
np.savetxt("RF_PISM_VUW_BM32_SU.dat", RF_PISM_VUW_BM32_SU, delimiter=",")

# %%
# Experiments
np.savetxt("PISM_VUW_BM01_R0.dat", PISM_VUW_BM01_R0, delimiter=",")
np.savetxt("PISM_VUW_BM01_R1.dat", PISM_VUW_BM01_R1, delimiter=",")
np.savetxt("PISM_VUW_BM01_R2.dat", PISM_VUW_BM01_R2, delimiter=",")
np.savetxt("PISM_VUW_BM01_R3.dat", PISM_VUW_BM01_R3, delimiter=",")
np.savetxt("PISM_VUW_BM01_R4.dat", PISM_VUW_BM01_R4, delimiter=",")
np.savetxt("PISM_VUW_BM01_R5.dat", PISM_VUW_BM01_R5, delimiter=",")
np.savetxt("PISM_VUW_BM01_SU.dat", PISM_VUW_BM01_SU, delimiter=",")

# %%
np.savetxt("PISM_VUW_BM02_R0.dat", PISM_VUW_BM02_R0, delimiter=",")
np.savetxt("PISM_VUW_BM02_R1.dat", PISM_VUW_BM02_R1, delimiter=",")
np.savetxt("PISM_VUW_BM02_R2.dat", PISM_VUW_BM02_R2, delimiter=",")
np.savetxt("PISM_VUW_BM02_R3.dat", PISM_VUW_BM02_R3, delimiter=",")
np.savetxt("PISM_VUW_BM02_R4.dat", PISM_VUW_BM02_R4, delimiter=",")
np.savetxt("PISM_VUW_BM02_R5.dat", PISM_VUW_BM02_R5, delimiter=",")
np.savetxt("PISM_VUW_BM02_SU.dat", PISM_VUW_BM02_SU, delimiter=",")

# %%
np.savetxt("PISM_VUW_BM04_R0.dat", PISM_VUW_BM04_R0, delimiter=",")
np.savetxt("PISM_VUW_BM04_R1.dat", PISM_VUW_BM04_R1, delimiter=",")
np.savetxt("PISM_VUW_BM04_R2.dat", PISM_VUW_BM04_R2, delimiter=",")
np.savetxt("PISM_VUW_BM04_R3.dat", PISM_VUW_BM04_R3, delimiter=",")
np.savetxt("PISM_VUW_BM04_R4.dat", PISM_VUW_BM04_R4, delimiter=",")
np.savetxt("PISM_VUW_BM04_R5.dat", PISM_VUW_BM04_R5, delimiter=",")
np.savetxt("PISM_VUW_BM04_SU.dat", PISM_VUW_BM04_SU, delimiter=",")

# %%
np.savetxt("PISM_VUW_BM08_R0.dat", PISM_VUW_BM08_R0, delimiter=",")
np.savetxt("PISM_VUW_BM08_R1.dat", PISM_VUW_BM08_R1, delimiter=",")
np.savetxt("PISM_VUW_BM08_R2.dat", PISM_VUW_BM08_R2, delimiter=",")
np.savetxt("PISM_VUW_BM08_R3.dat", PISM_VUW_BM08_R3, delimiter=",")
np.savetxt("PISM_VUW_BM08_R4.dat", PISM_VUW_BM08_R4, delimiter=",")
np.savetxt("PISM_VUW_BM08_R5.dat", PISM_VUW_BM08_R5, delimiter=",")
np.savetxt("PISM_VUW_BM08_SU.dat", PISM_VUW_BM08_SU, delimiter=",")

# %%
np.savetxt("PISM_VUW_BM16_R0.dat", PISM_VUW_BM16_R0, delimiter=",")
np.savetxt("PISM_VUW_BM16_R1.dat", PISM_VUW_BM16_R1, delimiter=",")
np.savetxt("PISM_VUW_BM16_R2.dat", PISM_VUW_BM16_R2, delimiter=",")
np.savetxt("PISM_VUW_BM16_R3.dat", PISM_VUW_BM16_R3, delimiter=",")
np.savetxt("PISM_VUW_BM16_R4.dat", PISM_VUW_BM16_R4, delimiter=",")
np.savetxt("PISM_VUW_BM16_R5.dat", PISM_VUW_BM16_R5, delimiter=",")
np.savetxt("PISM_VUW_BM16_SU.dat", PISM_VUW_BM16_SU, delimiter=",")

# %%
np.savetxt("PISM_VUW_BM32_R0.dat", PISM_VUW_BM32_R0, delimiter=",")
np.savetxt("PISM_VUW_BM32_R1.dat", PISM_VUW_BM32_R1, delimiter=",")
np.savetxt("PISM_VUW_BM32_R2.dat", PISM_VUW_BM32_R2, delimiter=",")
np.savetxt("PISM_VUW_BM32_R3.dat", PISM_VUW_BM32_R3, delimiter=",")
np.savetxt("PISM_VUW_BM32_R4.dat", PISM_VUW_BM32_R4, delimiter=",")
np.savetxt("PISM_VUW_BM32_R5.dat", PISM_VUW_BM32_R5, delimiter=",")
np.savetxt("PISM_VUW_BM32_SU.dat", PISM_VUW_BM32_SU, delimiter=",")
