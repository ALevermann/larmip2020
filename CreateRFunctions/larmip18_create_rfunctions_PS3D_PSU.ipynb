# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv
#import pandas

# %%
# PS3D_PSU = PennState3D
# Experiment BM01

fname = "larmip_data/PennState3D/tab_REGall_ADD1" # File to read
with open(fname) as f:
    PS3D_PSU_BM01_R0 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM01_R0=PS3D_PSU_BM01_R0[1:]

fname = "larmip_data/PennState3D/tab_REG1_ADD1" # File to read
with open(fname) as f:
    PS3D_PSU_BM01_R1 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM01_R1=PS3D_PSU_BM01_R1[1:]

fname = "larmip_data/PennState3D/tab_REG2_ADD1" # File to read
with open(fname) as f:
    PS3D_PSU_BM01_R2 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM01_R2=PS3D_PSU_BM01_R2[1:]

fname = "larmip_data/PennState3D/tab_REG3_ADD1" # File to read
with open(fname) as f:
    PS3D_PSU_BM01_R3 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM01_R3=PS3D_PSU_BM01_R3[1:]

fname = "larmip_data/PennState3D/tab_REG4_ADD1" # File to read
with open(fname) as f:
    PS3D_PSU_BM01_R4 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM01_R4=PS3D_PSU_BM01_R4[1:]

fname = "larmip_data/PennState3D/tab_REG5_ADD1" # File to read
with open(fname) as f:
    PS3D_PSU_BM01_R5 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM01_R5=PS3D_PSU_BM01_R5[1:]

PS3D_PSU_BM01_SU = PS3D_PSU_BM01_R1+PS3D_PSU_BM01_R2+PS3D_PSU_BM01_R3+PS3D_PSU_BM01_R4+PS3D_PSU_BM01_R5


# create and write response function
RF_PS3D_PSU_BM01_R0=np.diff(PS3D_PSU_BM01_R0)/1
RF_PS3D_PSU_BM01_R1=np.diff(PS3D_PSU_BM01_R1)/1
RF_PS3D_PSU_BM01_R2=np.diff(PS3D_PSU_BM01_R2)/1
RF_PS3D_PSU_BM01_R3=np.diff(PS3D_PSU_BM01_R3)/1
RF_PS3D_PSU_BM01_R4=np.diff(PS3D_PSU_BM01_R4)/1
RF_PS3D_PSU_BM01_R5=np.diff(PS3D_PSU_BM01_R5)/1
RF_PS3D_PSU_BM01_SU=np.diff(PS3D_PSU_BM01_SU)/1


# plot
plt.plot(PS3D_PSU_BM01_R0,label="PS3D_PSU_BM01_R0")
plt.plot(PS3D_PSU_BM01_R1,label="PS3D_PSU_BM01_R1")
plt.plot(PS3D_PSU_BM01_R2,label="PS3D_PSU_BM01_R2")
plt.plot(PS3D_PSU_BM01_R3,label="PS3D_PSU_BM01_R3")
plt.plot(PS3D_PSU_BM01_R4,label="PS3D_PSU_BM01_R4")
plt.plot(PS3D_PSU_BM01_R5,label="PS3D_PSU_BM01_R5")
plt.plot(PS3D_PSU_BM01_SU,label="PS3D_PSU_BM01_SU")
plt.legend()

RF_PS3D_PSU_BM01_R0=np.append(RF_PS3D_PSU_BM01_R0[0],RF_PS3D_PSU_BM01_R0)
RF_PS3D_PSU_BM01_R1=np.append(RF_PS3D_PSU_BM01_R1[0],RF_PS3D_PSU_BM01_R1)
RF_PS3D_PSU_BM01_R2=np.append(RF_PS3D_PSU_BM01_R2[0],RF_PS3D_PSU_BM01_R2)
RF_PS3D_PSU_BM01_R3=np.append(RF_PS3D_PSU_BM01_R3[0],RF_PS3D_PSU_BM01_R3)
RF_PS3D_PSU_BM01_R4=np.append(RF_PS3D_PSU_BM01_R4[0],RF_PS3D_PSU_BM01_R4)
RF_PS3D_PSU_BM01_R5=np.append(RF_PS3D_PSU_BM01_R5[0],RF_PS3D_PSU_BM01_R5)

print(len(RF_PS3D_PSU_BM01_R0))
# Out:
# 200

# %%
# PS3D_PSU = PennState3D
# Experiment BM02

fname = "larmip_data/PennState3D/tab_REGall_ADD2" # File to read
with open(fname) as f:
    PS3D_PSU_BM02_R0 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM02_R0=PS3D_PSU_BM02_R0[1:]

fname = "larmip_data/PennState3D/tab_REG1_ADD2" # File to read
with open(fname) as f:
    PS3D_PSU_BM02_R1 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM02_R1=PS3D_PSU_BM02_R1[1:]

fname = "larmip_data/PennState3D/tab_REG2_ADD2" # File to read
with open(fname) as f:
    PS3D_PSU_BM02_R2 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM02_R2=PS3D_PSU_BM02_R2[1:]

fname = "larmip_data/PennState3D/tab_REG3_ADD2" # File to read
with open(fname) as f:
    PS3D_PSU_BM02_R3 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM02_R3=PS3D_PSU_BM02_R3[1:]

fname = "larmip_data/PennState3D/tab_REG4_ADD2" # File to read
with open(fname) as f:
    PS3D_PSU_BM02_R4 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM02_R4=PS3D_PSU_BM02_R4[1:]

fname = "larmip_data/PennState3D/tab_REG5_ADD2" # File to read
with open(fname) as f:
    PS3D_PSU_BM02_R5 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM02_R5=PS3D_PSU_BM02_R5[1:]

PS3D_PSU_BM02_SU = PS3D_PSU_BM02_R1+PS3D_PSU_BM02_R2+PS3D_PSU_BM02_R3+PS3D_PSU_BM02_R4+PS3D_PSU_BM02_R5


# create and write response function
RF_PS3D_PSU_BM02_R0=np.diff(PS3D_PSU_BM02_R0)/2
RF_PS3D_PSU_BM02_R1=np.diff(PS3D_PSU_BM02_R1)/2
RF_PS3D_PSU_BM02_R2=np.diff(PS3D_PSU_BM02_R2)/2
RF_PS3D_PSU_BM02_R3=np.diff(PS3D_PSU_BM02_R3)/2
RF_PS3D_PSU_BM02_R4=np.diff(PS3D_PSU_BM02_R4)/2
RF_PS3D_PSU_BM02_R5=np.diff(PS3D_PSU_BM02_R5)/2
RF_PS3D_PSU_BM02_SU=np.diff(PS3D_PSU_BM02_SU)/2


# plot
plt.plot(PS3D_PSU_BM02_R0,label="PS3D_PSU_BM02_R0")
plt.plot(PS3D_PSU_BM02_R1,label="PS3D_PSU_BM02_R1")
plt.plot(PS3D_PSU_BM02_R2,label="PS3D_PSU_BM02_R2")
plt.plot(PS3D_PSU_BM02_R3,label="PS3D_PSU_BM02_R3")
plt.plot(PS3D_PSU_BM02_R4,label="PS3D_PSU_BM02_R4")
plt.plot(PS3D_PSU_BM02_R5,label="PS3D_PSU_BM02_R5")
plt.plot(PS3D_PSU_BM02_SU,label="PS3D_PSU_BM02_SU")
plt.legend()

RF_PS3D_PSU_BM02_R0=np.append(RF_PS3D_PSU_BM02_R0[0],RF_PS3D_PSU_BM02_R0)
RF_PS3D_PSU_BM02_R1=np.append(RF_PS3D_PSU_BM02_R1[0],RF_PS3D_PSU_BM02_R1)
RF_PS3D_PSU_BM02_R2=np.append(RF_PS3D_PSU_BM02_R2[0],RF_PS3D_PSU_BM02_R2)
RF_PS3D_PSU_BM02_R3=np.append(RF_PS3D_PSU_BM02_R3[0],RF_PS3D_PSU_BM02_R3)
RF_PS3D_PSU_BM02_R4=np.append(RF_PS3D_PSU_BM02_R4[0],RF_PS3D_PSU_BM02_R4)
RF_PS3D_PSU_BM02_R5=np.append(RF_PS3D_PSU_BM02_R5[0],RF_PS3D_PSU_BM02_R5)
RF_PS3D_PSU_BM02_SU=np.append(RF_PS3D_PSU_BM02_SU[0],RF_PS3D_PSU_BM02_SU)

print(len(RF_PS3D_PSU_BM02_R0))
# Out:
# 200

# %%
# PS3D_PSU = PennState3D
# Experiment BM04

fname = "larmip_data/PennState3D/tab_REGall_ADD4" # File to read
with open(fname) as f:
    PS3D_PSU_BM04_R0 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM04_R0=PS3D_PSU_BM04_R0[1:]

fname = "larmip_data/PennState3D/tab_REG1_ADD4" # File to read
with open(fname) as f:
    PS3D_PSU_BM04_R1 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM04_R1=PS3D_PSU_BM04_R1[1:]

fname = "larmip_data/PennState3D/tab_REG2_ADD4" # File to read
with open(fname) as f:
    PS3D_PSU_BM04_R2 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM04_R2=PS3D_PSU_BM04_R2[1:]

fname = "larmip_data/PennState3D/tab_REG3_ADD4" # File to read
with open(fname) as f:
    PS3D_PSU_BM04_R3 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM04_R3=PS3D_PSU_BM04_R3[1:]

fname = "larmip_data/PennState3D/tab_REG4_ADD4" # File to read
with open(fname) as f:
    PS3D_PSU_BM04_R4 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM04_R4=PS3D_PSU_BM04_R4[1:]

fname = "larmip_data/PennState3D/tab_REG5_ADD4" # File to read
with open(fname) as f:
    PS3D_PSU_BM04_R5 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM04_R5=PS3D_PSU_BM04_R5[1:]

PS3D_PSU_BM04_SU = PS3D_PSU_BM04_R1+PS3D_PSU_BM04_R2+PS3D_PSU_BM04_R3+PS3D_PSU_BM04_R4+PS3D_PSU_BM04_R5


# create and write response function
RF_PS3D_PSU_BM04_R0=np.diff(PS3D_PSU_BM04_R0)/4
RF_PS3D_PSU_BM04_R1=np.diff(PS3D_PSU_BM04_R1)/4
RF_PS3D_PSU_BM04_R2=np.diff(PS3D_PSU_BM04_R2)/4
RF_PS3D_PSU_BM04_R3=np.diff(PS3D_PSU_BM04_R3)/4
RF_PS3D_PSU_BM04_R4=np.diff(PS3D_PSU_BM04_R4)/4
RF_PS3D_PSU_BM04_R5=np.diff(PS3D_PSU_BM04_R5)/4
RF_PS3D_PSU_BM04_SU=np.diff(PS3D_PSU_BM04_SU)/4


# plot
plt.plot(PS3D_PSU_BM04_R0,label="PS3D_PSU_BM04_R0")
plt.plot(PS3D_PSU_BM04_R1,label="PS3D_PSU_BM04_R1")
plt.plot(PS3D_PSU_BM04_R2,label="PS3D_PSU_BM04_R2")
plt.plot(PS3D_PSU_BM04_R3,label="PS3D_PSU_BM04_R3")
plt.plot(PS3D_PSU_BM04_R4,label="PS3D_PSU_BM04_R4")
plt.plot(PS3D_PSU_BM04_R5,label="PS3D_PSU_BM04_R5")
plt.plot(PS3D_PSU_BM04_SU,label="PS3D_PSU_BM04_SU")
plt.legend()

RF_PS3D_PSU_BM04_R0=np.append(RF_PS3D_PSU_BM04_R0[0],RF_PS3D_PSU_BM04_R0)
RF_PS3D_PSU_BM04_R1=np.append(RF_PS3D_PSU_BM04_R1[0],RF_PS3D_PSU_BM04_R1)
RF_PS3D_PSU_BM04_R2=np.append(RF_PS3D_PSU_BM04_R2[0],RF_PS3D_PSU_BM04_R2)
RF_PS3D_PSU_BM04_R3=np.append(RF_PS3D_PSU_BM04_R3[0],RF_PS3D_PSU_BM04_R3)
RF_PS3D_PSU_BM04_R4=np.append(RF_PS3D_PSU_BM04_R4[0],RF_PS3D_PSU_BM04_R4)
RF_PS3D_PSU_BM04_R5=np.append(RF_PS3D_PSU_BM04_R5[0],RF_PS3D_PSU_BM04_R5)
RF_PS3D_PSU_BM04_SU=np.append(RF_PS3D_PSU_BM04_SU[0],RF_PS3D_PSU_BM04_SU)

print(len(RF_PS3D_PSU_BM04_R0))
# Out:
# 200

# %%
# PS3D_PSU = PennState3D
# Experiment BM08

fname = "larmip_data/PennState3D/tab_REGall_ADD8" # File to read
with open(fname) as f:
    PS3D_PSU_BM08_R0 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM08_R0=PS3D_PSU_BM08_R0[1:]

fname = "larmip_data/PennState3D/tab_REG1_ADD8" # File to read
with open(fname) as f:
    PS3D_PSU_BM08_R1 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM08_R1=PS3D_PSU_BM08_R1[1:]

fname = "larmip_data/PennState3D/tab_REG2_ADD8" # File to read
with open(fname) as f:
    PS3D_PSU_BM08_R2 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM08_R2=PS3D_PSU_BM08_R2[1:]

fname = "larmip_data/PennState3D/tab_REG3_ADD8" # File to read
with open(fname) as f:
    PS3D_PSU_BM08_R3 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM08_R3=PS3D_PSU_BM08_R3[1:]

fname = "larmip_data/PennState3D/tab_REG4_ADD8" # File to read
with open(fname) as f:
    PS3D_PSU_BM08_R4 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM08_R4=PS3D_PSU_BM08_R4[1:]

fname = "larmip_data/PennState3D/tab_REG5_ADD8" # File to read
with open(fname) as f:
    PS3D_PSU_BM08_R5 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM08_R5=PS3D_PSU_BM08_R5[1:]

PS3D_PSU_BM08_SU = PS3D_PSU_BM08_R1+PS3D_PSU_BM08_R2+PS3D_PSU_BM08_R3+PS3D_PSU_BM08_R4+PS3D_PSU_BM08_R5


# create and write response function
RF_PS3D_PSU_BM08_R0=np.diff(PS3D_PSU_BM08_R0)/8
RF_PS3D_PSU_BM08_R1=np.diff(PS3D_PSU_BM08_R1)/8
RF_PS3D_PSU_BM08_R2=np.diff(PS3D_PSU_BM08_R2)/8
RF_PS3D_PSU_BM08_R3=np.diff(PS3D_PSU_BM08_R3)/8
RF_PS3D_PSU_BM08_R4=np.diff(PS3D_PSU_BM08_R4)/8
RF_PS3D_PSU_BM08_R5=np.diff(PS3D_PSU_BM08_R5)/8
RF_PS3D_PSU_BM08_SU=np.diff(PS3D_PSU_BM08_SU)/8


# plot
plt.plot(PS3D_PSU_BM08_R0,label="PS3D_PSU_BM08_R0")
plt.plot(PS3D_PSU_BM08_R1,label="PS3D_PSU_BM08_R1")
plt.plot(PS3D_PSU_BM08_R2,label="PS3D_PSU_BM08_R2")
plt.plot(PS3D_PSU_BM08_R3,label="PS3D_PSU_BM08_R3")
plt.plot(PS3D_PSU_BM08_R4,label="PS3D_PSU_BM08_R4")
plt.plot(PS3D_PSU_BM08_R5,label="PS3D_PSU_BM08_R5")
plt.plot(PS3D_PSU_BM08_SU,label="PS3D_PSU_BM08_SU")
plt.legend()

RF_PS3D_PSU_BM08_R0=np.append(RF_PS3D_PSU_BM08_R0[0],RF_PS3D_PSU_BM08_R0)
RF_PS3D_PSU_BM08_R1=np.append(RF_PS3D_PSU_BM08_R1[0],RF_PS3D_PSU_BM08_R1)
RF_PS3D_PSU_BM08_R2=np.append(RF_PS3D_PSU_BM08_R2[0],RF_PS3D_PSU_BM08_R2)
RF_PS3D_PSU_BM08_R3=np.append(RF_PS3D_PSU_BM08_R3[0],RF_PS3D_PSU_BM08_R3)
RF_PS3D_PSU_BM08_R4=np.append(RF_PS3D_PSU_BM08_R4[0],RF_PS3D_PSU_BM08_R4)
RF_PS3D_PSU_BM08_R5=np.append(RF_PS3D_PSU_BM08_R5[0],RF_PS3D_PSU_BM08_R5)
RF_PS3D_PSU_BM08_SU=np.append(RF_PS3D_PSU_BM08_SU[0],RF_PS3D_PSU_BM08_SU)

print(len(RF_PS3D_PSU_BM08_R0))
# Out:
# 200

# %%
# PS3D_PSU = PennState3D
# Experiment BM16

fname = "larmip_data/PennState3D/tab_REGall_ADD16" # File to read
with open(fname) as f:
    PS3D_PSU_BM16_R0 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM16_R0=PS3D_PSU_BM16_R0[1:]

fname = "larmip_data/PennState3D/tab_REG1_ADD16" # File to read
with open(fname) as f:
    PS3D_PSU_BM16_R1 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM16_R1=PS3D_PSU_BM16_R1[1:]

fname = "larmip_data/PennState3D/tab_REG2_ADD16" # File to read
with open(fname) as f:
    PS3D_PSU_BM16_R2 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM16_R2=PS3D_PSU_BM16_R2[1:]

fname = "larmip_data/PennState3D/tab_REG3_ADD16" # File to read
with open(fname) as f:
    PS3D_PSU_BM16_R3 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM16_R3=PS3D_PSU_BM16_R3[1:]

fname = "larmip_data/PennState3D/tab_REG4_ADD16" # File to read
with open(fname) as f:
    PS3D_PSU_BM16_R4 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM16_R4=PS3D_PSU_BM16_R4[1:]

fname = "larmip_data/PennState3D/tab_REG5_ADD16" # File to read
with open(fname) as f:
    PS3D_PSU_BM16_R5 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM16_R5=PS3D_PSU_BM16_R5[1:]

PS3D_PSU_BM16_SU = PS3D_PSU_BM16_R1+PS3D_PSU_BM16_R2+PS3D_PSU_BM16_R3+PS3D_PSU_BM16_R4+PS3D_PSU_BM16_R5


# create and write response function
RF_PS3D_PSU_BM16_R0=np.diff(PS3D_PSU_BM16_R0)/16
RF_PS3D_PSU_BM16_R1=np.diff(PS3D_PSU_BM16_R1)/16
RF_PS3D_PSU_BM16_R2=np.diff(PS3D_PSU_BM16_R2)/16
RF_PS3D_PSU_BM16_R3=np.diff(PS3D_PSU_BM16_R3)/16
RF_PS3D_PSU_BM16_R4=np.diff(PS3D_PSU_BM16_R4)/16
RF_PS3D_PSU_BM16_R5=np.diff(PS3D_PSU_BM16_R5)/16
RF_PS3D_PSU_BM16_SU=np.diff(PS3D_PSU_BM16_SU)/16


# plot
plt.plot(PS3D_PSU_BM16_R0,label="PS3D_PSU_BM16_R0")
plt.plot(PS3D_PSU_BM16_R1,label="PS3D_PSU_BM16_R1")
plt.plot(PS3D_PSU_BM16_R2,label="PS3D_PSU_BM16_R2")
plt.plot(PS3D_PSU_BM16_R3,label="PS3D_PSU_BM16_R3")
plt.plot(PS3D_PSU_BM16_R4,label="PS3D_PSU_BM16_R4")
plt.plot(PS3D_PSU_BM16_R5,label="PS3D_PSU_BM16_R5")
plt.plot(PS3D_PSU_BM16_SU,label="PS3D_PSU_BM16_SU")
plt.legend()

RF_PS3D_PSU_BM16_R0=np.append(RF_PS3D_PSU_BM16_R0[0],RF_PS3D_PSU_BM16_R0)
RF_PS3D_PSU_BM16_R1=np.append(RF_PS3D_PSU_BM16_R1[0],RF_PS3D_PSU_BM16_R1)
RF_PS3D_PSU_BM16_R2=np.append(RF_PS3D_PSU_BM16_R2[0],RF_PS3D_PSU_BM16_R2)
RF_PS3D_PSU_BM16_R3=np.append(RF_PS3D_PSU_BM16_R3[0],RF_PS3D_PSU_BM16_R3)
RF_PS3D_PSU_BM16_R4=np.append(RF_PS3D_PSU_BM16_R4[0],RF_PS3D_PSU_BM16_R4)
RF_PS3D_PSU_BM16_R5=np.append(RF_PS3D_PSU_BM16_R5[0],RF_PS3D_PSU_BM16_R5)
RF_PS3D_PSU_BM16_SU=np.append(RF_PS3D_PSU_BM16_SU[0],RF_PS3D_PSU_BM16_SU)

print(len(RF_PS3D_PSU_BM16_R0))
# Out:
# 200

# %%
# PS3D_PSU = PennState3D
# Experiment BM32

fname = "larmip_data/PennState3D/tab_REGall_ADD32" # File to read
with open(fname) as f:
    PS3D_PSU_BM32_R0 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM32_R0=PS3D_PSU_BM32_R0[1:]

fname = "larmip_data/PennState3D/tab_REG1_ADD32" # File to read
with open(fname) as f:
    PS3D_PSU_BM32_R1 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM32_R1=PS3D_PSU_BM32_R1[1:]

fname = "larmip_data/PennState3D/tab_REG2_ADD32" # File to read
with open(fname) as f:
    PS3D_PSU_BM32_R2 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM32_R2=PS3D_PSU_BM32_R2[1:]

fname = "larmip_data/PennState3D/tab_REG3_ADD32" # File to read
with open(fname) as f:
    PS3D_PSU_BM32_R3 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM32_R3=PS3D_PSU_BM32_R3[1:]

fname = "larmip_data/PennState3D/tab_REG4_ADD32" # File to read
with open(fname) as f:
    PS3D_PSU_BM32_R4 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM32_R4=PS3D_PSU_BM32_R4[1:]

fname = "larmip_data/PennState3D/tab_REG5_ADD32" # File to read
with open(fname) as f:
    PS3D_PSU_BM32_R5 = np.array([float(row[5:]) for row in f])
PS3D_PSU_BM32_R5=PS3D_PSU_BM32_R5[1:]

PS3D_PSU_BM32_SU = PS3D_PSU_BM32_R1+PS3D_PSU_BM32_R2+PS3D_PSU_BM32_R3+PS3D_PSU_BM32_R4+PS3D_PSU_BM32_R5


# create and write response function
RF_PS3D_PSU_BM32_R0=np.diff(PS3D_PSU_BM32_R0)/32
RF_PS3D_PSU_BM32_R1=np.diff(PS3D_PSU_BM32_R1)/32
RF_PS3D_PSU_BM32_R2=np.diff(PS3D_PSU_BM32_R2)/32
RF_PS3D_PSU_BM32_R3=np.diff(PS3D_PSU_BM32_R3)/32
RF_PS3D_PSU_BM32_R4=np.diff(PS3D_PSU_BM32_R4)/32
RF_PS3D_PSU_BM32_R5=np.diff(PS3D_PSU_BM32_R5)/32
RF_PS3D_PSU_BM32_SU=np.diff(PS3D_PSU_BM32_SU)/32


# plot
plt.plot(PS3D_PSU_BM32_R0,label="PS3D_PSU_BM32_R0")
plt.plot(PS3D_PSU_BM32_R1,label="PS3D_PSU_BM32_R1")
plt.plot(PS3D_PSU_BM32_R2,label="PS3D_PSU_BM32_R2")
plt.plot(PS3D_PSU_BM32_R3,label="PS3D_PSU_BM32_R3")
plt.plot(PS3D_PSU_BM32_R4,label="PS3D_PSU_BM32_R4")
plt.plot(PS3D_PSU_BM32_R5,label="PS3D_PSU_BM32_R5")
plt.plot(PS3D_PSU_BM32_SU,label="PS3D_PSU_BM32_SU")
plt.legend()

RF_PS3D_PSU_BM32_R0=np.append(RF_PS3D_PSU_BM32_R0[0],RF_PS3D_PSU_BM32_R0)
RF_PS3D_PSU_BM32_R1=np.append(RF_PS3D_PSU_BM32_R1[0],RF_PS3D_PSU_BM32_R1)
RF_PS3D_PSU_BM32_R2=np.append(RF_PS3D_PSU_BM32_R2[0],RF_PS3D_PSU_BM32_R2)
RF_PS3D_PSU_BM32_R3=np.append(RF_PS3D_PSU_BM32_R3[0],RF_PS3D_PSU_BM32_R3)
RF_PS3D_PSU_BM32_R4=np.append(RF_PS3D_PSU_BM32_R4[0],RF_PS3D_PSU_BM32_R4)
RF_PS3D_PSU_BM32_R5=np.append(RF_PS3D_PSU_BM32_R5[0],RF_PS3D_PSU_BM32_R5)
RF_PS3D_PSU_BM32_SU=np.append(RF_PS3D_PSU_BM32_SU[0],RF_PS3D_PSU_BM32_SU)

print(len(RF_PS3D_PSU_BM32_R0))
# Out:
# 200

# %%
# Response functions
np.savetxt("RF_PS3D_PSU_BM01_R0.dat", RF_PS3D_PSU_BM01_R0, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM01_R1.dat", RF_PS3D_PSU_BM01_R1, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM01_R2.dat", RF_PS3D_PSU_BM01_R2, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM01_R3.dat", RF_PS3D_PSU_BM01_R3, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM01_R4.dat", RF_PS3D_PSU_BM01_R4, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM01_R5.dat", RF_PS3D_PSU_BM01_R5, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM01_SU.dat", RF_PS3D_PSU_BM01_SU, delimiter=",")

# %%
np.savetxt("RF_PS3D_PSU_BM02_R0.dat", RF_PS3D_PSU_BM02_R0, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM02_R1.dat", RF_PS3D_PSU_BM02_R1, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM02_R2.dat", RF_PS3D_PSU_BM02_R2, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM02_R3.dat", RF_PS3D_PSU_BM02_R3, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM02_R4.dat", RF_PS3D_PSU_BM02_R4, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM02_R5.dat", RF_PS3D_PSU_BM02_R5, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM02_SU.dat", RF_PS3D_PSU_BM02_SU, delimiter=",")

# %%
np.savetxt("RF_PS3D_PSU_BM04_R0.dat", RF_PS3D_PSU_BM04_R0, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM04_R1.dat", RF_PS3D_PSU_BM04_R1, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM04_R2.dat", RF_PS3D_PSU_BM04_R2, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM04_R3.dat", RF_PS3D_PSU_BM04_R3, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM04_R4.dat", RF_PS3D_PSU_BM04_R4, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM04_R5.dat", RF_PS3D_PSU_BM04_R5, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM04_SU.dat", RF_PS3D_PSU_BM04_SU, delimiter=",")

# %%
np.savetxt("RF_PS3D_PSU_BM08_R0.dat", RF_PS3D_PSU_BM08_R0, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM08_R1.dat", RF_PS3D_PSU_BM08_R1, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM08_R2.dat", RF_PS3D_PSU_BM08_R2, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM08_R3.dat", RF_PS3D_PSU_BM08_R3, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM08_R4.dat", RF_PS3D_PSU_BM08_R4, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM08_R5.dat", RF_PS3D_PSU_BM08_R5, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM08_SU.dat", RF_PS3D_PSU_BM08_SU, delimiter=",")

# %%
np.savetxt("RF_PS3D_PSU_BM16_R0.dat", RF_PS3D_PSU_BM16_R0, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM16_R1.dat", RF_PS3D_PSU_BM16_R1, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM16_R2.dat", RF_PS3D_PSU_BM16_R2, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM16_R3.dat", RF_PS3D_PSU_BM16_R3, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM16_R4.dat", RF_PS3D_PSU_BM16_R4, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM16_R5.dat", RF_PS3D_PSU_BM16_R5, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM16_SU.dat", RF_PS3D_PSU_BM16_SU, delimiter=",")

# %%
np.savetxt("RF_PS3D_PSU_BM32_R0.dat", RF_PS3D_PSU_BM32_R0, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM32_R1.dat", RF_PS3D_PSU_BM32_R1, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM32_R2.dat", RF_PS3D_PSU_BM32_R2, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM32_R3.dat", RF_PS3D_PSU_BM32_R3, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM32_R4.dat", RF_PS3D_PSU_BM32_R4, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM32_R5.dat", RF_PS3D_PSU_BM32_R5, delimiter=",")
np.savetxt("RF_PS3D_PSU_BM32_SU.dat", RF_PS3D_PSU_BM32_SU, delimiter=",")

# %%
# Experiments
np.savetxt("PS3D_PSU_BM01_R0.dat", PS3D_PSU_BM01_R0, delimiter=",")
np.savetxt("PS3D_PSU_BM01_R1.dat", PS3D_PSU_BM01_R1, delimiter=",")
np.savetxt("PS3D_PSU_BM01_R2.dat", PS3D_PSU_BM01_R2, delimiter=",")
np.savetxt("PS3D_PSU_BM01_R3.dat", PS3D_PSU_BM01_R3, delimiter=",")
np.savetxt("PS3D_PSU_BM01_R4.dat", PS3D_PSU_BM01_R4, delimiter=",")
np.savetxt("PS3D_PSU_BM01_R5.dat", PS3D_PSU_BM01_R5, delimiter=",")
np.savetxt("PS3D_PSU_BM01_SU.dat", PS3D_PSU_BM01_SU, delimiter=",")

# %%
np.savetxt("PS3D_PSU_BM02_R0.dat", PS3D_PSU_BM02_R0, delimiter=",")
np.savetxt("PS3D_PSU_BM02_R1.dat", PS3D_PSU_BM02_R1, delimiter=",")
np.savetxt("PS3D_PSU_BM02_R2.dat", PS3D_PSU_BM02_R2, delimiter=",")
np.savetxt("PS3D_PSU_BM02_R3.dat", PS3D_PSU_BM02_R3, delimiter=",")
np.savetxt("PS3D_PSU_BM02_R4.dat", PS3D_PSU_BM02_R4, delimiter=",")
np.savetxt("PS3D_PSU_BM02_R5.dat", PS3D_PSU_BM02_R5, delimiter=",")
np.savetxt("PS3D_PSU_BM02_SU.dat", PS3D_PSU_BM02_SU, delimiter=",")

# %%
np.savetxt("PS3D_PSU_BM04_R0.dat", PS3D_PSU_BM04_R0, delimiter=",")
np.savetxt("PS3D_PSU_BM04_R1.dat", PS3D_PSU_BM04_R1, delimiter=",")
np.savetxt("PS3D_PSU_BM04_R2.dat", PS3D_PSU_BM04_R2, delimiter=",")
np.savetxt("PS3D_PSU_BM04_R3.dat", PS3D_PSU_BM04_R3, delimiter=",")
np.savetxt("PS3D_PSU_BM04_R4.dat", PS3D_PSU_BM04_R4, delimiter=",")
np.savetxt("PS3D_PSU_BM04_R5.dat", PS3D_PSU_BM04_R5, delimiter=",")
np.savetxt("PS3D_PSU_BM04_SU.dat", PS3D_PSU_BM04_SU, delimiter=",")

# %%
np.savetxt("PS3D_PSU_BM08_R0.dat", PS3D_PSU_BM08_R0, delimiter=",")
np.savetxt("PS3D_PSU_BM08_R1.dat", PS3D_PSU_BM08_R1, delimiter=",")
np.savetxt("PS3D_PSU_BM08_R2.dat", PS3D_PSU_BM08_R2, delimiter=",")
np.savetxt("PS3D_PSU_BM08_R3.dat", PS3D_PSU_BM08_R3, delimiter=",")
np.savetxt("PS3D_PSU_BM08_R4.dat", PS3D_PSU_BM08_R4, delimiter=",")
np.savetxt("PS3D_PSU_BM08_R5.dat", PS3D_PSU_BM08_R5, delimiter=",")
np.savetxt("PS3D_PSU_BM08_SU.dat", PS3D_PSU_BM08_SU, delimiter=",")

# %%
np.savetxt("PS3D_PSU_BM16_R0.dat", PS3D_PSU_BM16_R0, delimiter=",")
np.savetxt("PS3D_PSU_BM16_R1.dat", PS3D_PSU_BM16_R1, delimiter=",")
np.savetxt("PS3D_PSU_BM16_R2.dat", PS3D_PSU_BM16_R2, delimiter=",")
np.savetxt("PS3D_PSU_BM16_R3.dat", PS3D_PSU_BM16_R3, delimiter=",")
np.savetxt("PS3D_PSU_BM16_R4.dat", PS3D_PSU_BM16_R4, delimiter=",")
np.savetxt("PS3D_PSU_BM16_R5.dat", PS3D_PSU_BM16_R5, delimiter=",")
np.savetxt("PS3D_PSU_BM16_SU.dat", PS3D_PSU_BM16_SU, delimiter=",")

# %%
np.savetxt("PS3D_PSU_BM32_R0.dat", PS3D_PSU_BM32_R0, delimiter=",")
np.savetxt("PS3D_PSU_BM32_R1.dat", PS3D_PSU_BM32_R1, delimiter=",")
np.savetxt("PS3D_PSU_BM32_R2.dat", PS3D_PSU_BM32_R2, delimiter=",")
np.savetxt("PS3D_PSU_BM32_R3.dat", PS3D_PSU_BM32_R3, delimiter=",")
np.savetxt("PS3D_PSU_BM32_R4.dat", PS3D_PSU_BM32_R4, delimiter=",")
np.savetxt("PS3D_PSU_BM32_R5.dat", PS3D_PSU_BM32_R5, delimiter=",")
np.savetxt("PS3D_PSU_BM32_SU.dat", PS3D_PSU_BM32_SU, delimiter=",")
