# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv

# %%
# SICO_UHO = SICOPOLIS
# Control experiment
fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp_ctrl.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_Control = ncf.variables["V_sle"][::]

# %%
# SICO_UHO = SICOPOLIS
# Experiment BM01

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp11111.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM01_R0 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM01_R0_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp10000.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM01_R1 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM01_R1_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp01000.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM01_R2 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM01_R2_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00100.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM01_R3 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM01_R3_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00010.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM01_R4 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM01_R4_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00001.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM01_R5 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM01_R5_time = ncf.variables["t"][::]

SICO_UHO_BM01_SU = SICO_UHO_BM01_R1+SICO_UHO_BM01_R2+SICO_UHO_BM01_R3+SICO_UHO_BM01_R4+SICO_UHO_BM01_R5


# create and write response function
RF_SICO_UHO_BM01_R0=np.diff(SICO_UHO_BM01_R0)
RF_SICO_UHO_BM01_R1=np.diff(SICO_UHO_BM01_R1)
RF_SICO_UHO_BM01_R2=np.diff(SICO_UHO_BM01_R2)
RF_SICO_UHO_BM01_R3=np.diff(SICO_UHO_BM01_R3)
RF_SICO_UHO_BM01_R4=np.diff(SICO_UHO_BM01_R4)
RF_SICO_UHO_BM01_R5=np.diff(SICO_UHO_BM01_R5)
RF_SICO_UHO_BM01_SU=np.diff(SICO_UHO_BM01_SU)


# plot
plt.plot(SICO_UHO_BM01_R0,label="SICO_UHO_BM01_R0")
plt.plot(SICO_UHO_BM01_R1,label="SICO_UHO_BM01_R1")
plt.plot(SICO_UHO_BM01_R2,label="SICO_UHO_BM01_R2")
plt.plot(SICO_UHO_BM01_R3,label="SICO_UHO_BM01_R3")
plt.plot(SICO_UHO_BM01_R4,label="SICO_UHO_BM01_R4")
plt.plot(SICO_UHO_BM01_R5,label="SICO_UHO_BM01_R5")
plt.plot(SICO_UHO_BM01_SU,label="SICO_UHO_BM01_SU")
plt.legend()

RF_SICO_UHO_BM01_R0=np.append(RF_SICO_UHO_BM01_R0[0],RF_SICO_UHO_BM01_R0)
RF_SICO_UHO_BM01_R1=np.append(RF_SICO_UHO_BM01_R1[0],RF_SICO_UHO_BM01_R1)
RF_SICO_UHO_BM01_R2=np.append(RF_SICO_UHO_BM01_R2[0],RF_SICO_UHO_BM01_R2)
RF_SICO_UHO_BM01_R3=np.append(RF_SICO_UHO_BM01_R3[0],RF_SICO_UHO_BM01_R3)
RF_SICO_UHO_BM01_R4=np.append(RF_SICO_UHO_BM01_R4[0],RF_SICO_UHO_BM01_R4)
RF_SICO_UHO_BM01_R5=np.append(RF_SICO_UHO_BM01_R5[0],RF_SICO_UHO_BM01_R5)
RF_SICO_UHO_BM01_SU=np.append(RF_SICO_UHO_BM01_SU[0],RF_SICO_UHO_BM01_SU)

print(len(RF_SICO_UHO_BM01_R0))
# Out:
# 200

# %%
# SICO_UHO = SICOPOLIS
# Experiment BM02

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp22222.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM02_R0 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM02_R0_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp20000.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM02_R1 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM02_R1_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp02000.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM02_R2 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM02_R2_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00200.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM02_R3 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM02_R3_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00020.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM02_R4 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM02_R4_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00002.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM02_R5 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM02_R5_time = ncf.variables["t"][::]

SICO_UHO_BM02_SU = SICO_UHO_BM02_R1+SICO_UHO_BM02_R2+SICO_UHO_BM02_R3+SICO_UHO_BM02_R4+SICO_UHO_BM02_R5


# create and write response function
RF_SICO_UHO_BM02_R0=np.diff(SICO_UHO_BM02_R0)/2
RF_SICO_UHO_BM02_R1=np.diff(SICO_UHO_BM02_R1)/2
RF_SICO_UHO_BM02_R2=np.diff(SICO_UHO_BM02_R2)/2
RF_SICO_UHO_BM02_R3=np.diff(SICO_UHO_BM02_R3)/2
RF_SICO_UHO_BM02_R4=np.diff(SICO_UHO_BM02_R4)/2
RF_SICO_UHO_BM02_R5=np.diff(SICO_UHO_BM02_R5)/2
RF_SICO_UHO_BM02_SU=np.diff(SICO_UHO_BM02_SU)/2


# plot
plt.plot(SICO_UHO_BM02_R0,label="SICO_UHO_BM02_R0")
plt.plot(SICO_UHO_BM02_R1,label="SICO_UHO_BM02_R1")
plt.plot(SICO_UHO_BM02_R2,label="SICO_UHO_BM02_R2")
plt.plot(SICO_UHO_BM02_R3,label="SICO_UHO_BM02_R3")
plt.plot(SICO_UHO_BM02_R4,label="SICO_UHO_BM02_R4")
plt.plot(SICO_UHO_BM02_R5,label="SICO_UHO_BM02_R5")
plt.plot(SICO_UHO_BM02_SU,label="SICO_UHO_BM02_SU")
plt.legend()

RF_SICO_UHO_BM02_R0=np.append(RF_SICO_UHO_BM02_R0[0],RF_SICO_UHO_BM02_R0)
RF_SICO_UHO_BM02_R1=np.append(RF_SICO_UHO_BM02_R1[0],RF_SICO_UHO_BM02_R1)
RF_SICO_UHO_BM02_R2=np.append(RF_SICO_UHO_BM02_R2[0],RF_SICO_UHO_BM02_R2)
RF_SICO_UHO_BM02_R3=np.append(RF_SICO_UHO_BM02_R3[0],RF_SICO_UHO_BM02_R3)
RF_SICO_UHO_BM02_R4=np.append(RF_SICO_UHO_BM02_R4[0],RF_SICO_UHO_BM02_R4)
RF_SICO_UHO_BM02_R5=np.append(RF_SICO_UHO_BM02_R5[0],RF_SICO_UHO_BM02_R5)
RF_SICO_UHO_BM02_SU=np.append(RF_SICO_UHO_BM02_SU[0],RF_SICO_UHO_BM02_SU)

print(len(RF_SICO_UHO_BM02_R0))
# Out:
# 200

# %%
# SICO_UHO = SICOPOLIS
# Experiment BM04

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp44444.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM04_R0 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM04_R0_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp40000.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM04_R1 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM04_R1_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp04000.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM04_R2 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM04_R2_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00400.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM04_R3 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM04_R3_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00040.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM04_R4 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM04_R4_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00004.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM04_R5 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM04_R5_time = ncf.variables["t"][::]

SICO_UHO_BM04_SU = SICO_UHO_BM04_R1+SICO_UHO_BM04_R2+SICO_UHO_BM04_R3+SICO_UHO_BM04_R4+SICO_UHO_BM04_R5


# create and write response function
RF_SICO_UHO_BM04_R0=np.diff(SICO_UHO_BM04_R0)/4
RF_SICO_UHO_BM04_R1=np.diff(SICO_UHO_BM04_R1)/4
RF_SICO_UHO_BM04_R2=np.diff(SICO_UHO_BM04_R2)/4
RF_SICO_UHO_BM04_R3=np.diff(SICO_UHO_BM04_R3)/4
RF_SICO_UHO_BM04_R4=np.diff(SICO_UHO_BM04_R4)/4
RF_SICO_UHO_BM04_R5=np.diff(SICO_UHO_BM04_R5)/4
RF_SICO_UHO_BM04_SU=np.diff(SICO_UHO_BM04_SU)/4


# plot
plt.plot(SICO_UHO_BM04_R0,label="SICO_UHO_BM04_R0")
plt.plot(SICO_UHO_BM04_R1,label="SICO_UHO_BM04_R1")
plt.plot(SICO_UHO_BM04_R2,label="SICO_UHO_BM04_R2")
plt.plot(SICO_UHO_BM04_R3,label="SICO_UHO_BM04_R3")
plt.plot(SICO_UHO_BM04_R4,label="SICO_UHO_BM04_R4")
plt.plot(SICO_UHO_BM04_R5,label="SICO_UHO_BM04_R5")
plt.plot(SICO_UHO_BM04_SU,label="SICO_UHO_BM04_SU")
plt.legend()

RF_SICO_UHO_BM04_R0=np.append(RF_SICO_UHO_BM04_R0[0],RF_SICO_UHO_BM04_R0)
RF_SICO_UHO_BM04_R1=np.append(RF_SICO_UHO_BM04_R1[0],RF_SICO_UHO_BM04_R1)
RF_SICO_UHO_BM04_R2=np.append(RF_SICO_UHO_BM04_R2[0],RF_SICO_UHO_BM04_R2)
RF_SICO_UHO_BM04_R3=np.append(RF_SICO_UHO_BM04_R3[0],RF_SICO_UHO_BM04_R3)
RF_SICO_UHO_BM04_R4=np.append(RF_SICO_UHO_BM04_R4[0],RF_SICO_UHO_BM04_R4)
RF_SICO_UHO_BM04_R5=np.append(RF_SICO_UHO_BM04_R5[0],RF_SICO_UHO_BM04_R5)
RF_SICO_UHO_BM04_SU=np.append(RF_SICO_UHO_BM04_SU[0],RF_SICO_UHO_BM04_SU)

print(len(RF_SICO_UHO_BM04_R0))
# Out:
# 200

# %%
# SICO_UHO = SICOPOLIS
# Experiment BM08

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp88888.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM08_R0 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM08_R0_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp80000.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM08_R1 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM08_R1_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp08000.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM08_R2 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM08_R2_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00800.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM08_R3 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM08_R3_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00080.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM08_R4 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM08_R4_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00008.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM08_R5 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM08_R5_time = ncf.variables["t"][::]

SICO_UHO_BM08_SU = SICO_UHO_BM08_R1+SICO_UHO_BM08_R2+SICO_UHO_BM08_R3+SICO_UHO_BM08_R4+SICO_UHO_BM08_R5


# create and write response function
RF_SICO_UHO_BM08_R0=np.diff(SICO_UHO_BM08_R0)/8
RF_SICO_UHO_BM08_R1=np.diff(SICO_UHO_BM08_R1)/8
RF_SICO_UHO_BM08_R2=np.diff(SICO_UHO_BM08_R2)/8
RF_SICO_UHO_BM08_R3=np.diff(SICO_UHO_BM08_R3)/8
RF_SICO_UHO_BM08_R4=np.diff(SICO_UHO_BM08_R4)/8
RF_SICO_UHO_BM08_R5=np.diff(SICO_UHO_BM08_R5)/8
RF_SICO_UHO_BM08_SU=np.diff(SICO_UHO_BM08_SU)/8


# plot
plt.plot(SICO_UHO_BM08_R0,label="SICO_UHO_BM08_R0")
plt.plot(SICO_UHO_BM08_R1,label="SICO_UHO_BM08_R1")
plt.plot(SICO_UHO_BM08_R2,label="SICO_UHO_BM08_R2")
plt.plot(SICO_UHO_BM08_R3,label="SICO_UHO_BM08_R3")
plt.plot(SICO_UHO_BM08_R4,label="SICO_UHO_BM08_R4")
plt.plot(SICO_UHO_BM08_R5,label="SICO_UHO_BM08_R5")
plt.plot(SICO_UHO_BM08_SU,label="SICO_UHO_BM08_SU")
plt.legend()

RF_SICO_UHO_BM08_R0=np.append(RF_SICO_UHO_BM08_R0[0],RF_SICO_UHO_BM08_R0)
RF_SICO_UHO_BM08_R1=np.append(RF_SICO_UHO_BM08_R1[0],RF_SICO_UHO_BM08_R1)
RF_SICO_UHO_BM08_R2=np.append(RF_SICO_UHO_BM08_R2[0],RF_SICO_UHO_BM08_R2)
RF_SICO_UHO_BM08_R3=np.append(RF_SICO_UHO_BM08_R3[0],RF_SICO_UHO_BM08_R3)
RF_SICO_UHO_BM08_R4=np.append(RF_SICO_UHO_BM08_R4[0],RF_SICO_UHO_BM08_R4)
RF_SICO_UHO_BM08_R5=np.append(RF_SICO_UHO_BM08_R5[0],RF_SICO_UHO_BM08_R5)
RF_SICO_UHO_BM08_SU=np.append(RF_SICO_UHO_BM08_SU[0],RF_SICO_UHO_BM08_SU)

print(len(RF_SICO_UHO_BM08_R0))
# Out:
# 200

# %%
# SICO_UHO = SICOPOLIS
# Experiment BM16

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_expggggg.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM16_R0 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM16_R0_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_expg0000.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM16_R1 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM16_R1_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp0g000.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM16_R2 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM16_R2_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00g00.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM16_R3 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM16_R3_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp000g0.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM16_R4 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM16_R4_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp0000g.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM16_R5 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM16_R5_time = ncf.variables["t"][::]

SICO_UHO_BM16_SU = SICO_UHO_BM16_R1+SICO_UHO_BM16_R2+SICO_UHO_BM16_R3+SICO_UHO_BM16_R4+SICO_UHO_BM16_R5


# create and write response function
RF_SICO_UHO_BM16_R0=np.diff(SICO_UHO_BM16_R0)/16
RF_SICO_UHO_BM16_R1=np.diff(SICO_UHO_BM16_R1)/16
RF_SICO_UHO_BM16_R2=np.diff(SICO_UHO_BM16_R2)/16
RF_SICO_UHO_BM16_R3=np.diff(SICO_UHO_BM16_R3)/16
RF_SICO_UHO_BM16_R4=np.diff(SICO_UHO_BM16_R4)/16
RF_SICO_UHO_BM16_R5=np.diff(SICO_UHO_BM16_R5)/16
RF_SICO_UHO_BM16_SU=np.diff(SICO_UHO_BM16_SU)/16


# plot
plt.plot(SICO_UHO_BM16_R0,label="SICO_UHO_BM16_R0")
plt.plot(SICO_UHO_BM16_R1,label="SICO_UHO_BM16_R1")
plt.plot(SICO_UHO_BM16_R2,label="SICO_UHO_BM16_R2")
plt.plot(SICO_UHO_BM16_R3,label="SICO_UHO_BM16_R3")
plt.plot(SICO_UHO_BM16_R4,label="SICO_UHO_BM16_R4")
plt.plot(SICO_UHO_BM16_R5,label="SICO_UHO_BM16_R5")
plt.plot(SICO_UHO_BM16_SU,label="SICO_UHO_BM16_SU")
plt.legend()

RF_SICO_UHO_BM16_R0=np.append(RF_SICO_UHO_BM16_R0[0],RF_SICO_UHO_BM16_R0)
RF_SICO_UHO_BM16_R1=np.append(RF_SICO_UHO_BM16_R1[0],RF_SICO_UHO_BM16_R1)
RF_SICO_UHO_BM16_R2=np.append(RF_SICO_UHO_BM16_R2[0],RF_SICO_UHO_BM16_R2)
RF_SICO_UHO_BM16_R3=np.append(RF_SICO_UHO_BM16_R3[0],RF_SICO_UHO_BM16_R3)
RF_SICO_UHO_BM16_R4=np.append(RF_SICO_UHO_BM16_R4[0],RF_SICO_UHO_BM16_R4)
RF_SICO_UHO_BM16_R5=np.append(RF_SICO_UHO_BM16_R5[0],RF_SICO_UHO_BM16_R5)
RF_SICO_UHO_BM16_SU=np.append(RF_SICO_UHO_BM16_SU[0],RF_SICO_UHO_BM16_SU)

print(len(RF_SICO_UHO_BM16_R0))
# Out:
# 200

# %%
# SICO_UHO = SICOPOLIS
# Experiment BM32

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_expwwwww.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM32_R0 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM32_R0_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_expw0000.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM32_R1 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM32_R1_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp0w000.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM32_R2 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM32_R2_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp00w00.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM32_R3 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM32_R3_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp000w0.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM32_R4 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM32_R4_time = ncf.variables["t"][::]

fname="larmip_data/SICOPOLIS/ILTS_PIK_SICOPOLIS1_exp0000w.nc"
ncf = nc.Dataset(fname, "r")
ncf.variables.keys()
SICO_UHO_BM32_R5 = -(ncf.variables["V_sle"][::]-SICO_UHO_Control)
SICO_UHO_BM32_R5_time = ncf.variables["t"][::]

SICO_UHO_BM32_SU = SICO_UHO_BM32_R1+SICO_UHO_BM32_R2+SICO_UHO_BM32_R3+SICO_UHO_BM32_R4+SICO_UHO_BM32_R5


# create and write response function
RF_SICO_UHO_BM32_R0=np.diff(SICO_UHO_BM32_R0)/32
RF_SICO_UHO_BM32_R1=np.diff(SICO_UHO_BM32_R1)/32
RF_SICO_UHO_BM32_R2=np.diff(SICO_UHO_BM32_R2)/32
RF_SICO_UHO_BM32_R3=np.diff(SICO_UHO_BM32_R3)/32
RF_SICO_UHO_BM32_R4=np.diff(SICO_UHO_BM32_R4)/32
RF_SICO_UHO_BM32_R5=np.diff(SICO_UHO_BM32_R5)/32
RF_SICO_UHO_BM32_SU=np.diff(SICO_UHO_BM32_SU)/32


# plot
plt.plot(SICO_UHO_BM32_R0,label="SICO_UHO_BM32_R0")
plt.plot(SICO_UHO_BM32_R1,label="SICO_UHO_BM32_R1")
plt.plot(SICO_UHO_BM32_R2,label="SICO_UHO_BM32_R2")
plt.plot(SICO_UHO_BM32_R3,label="SICO_UHO_BM32_R3")
plt.plot(SICO_UHO_BM32_R4,label="SICO_UHO_BM32_R4")
plt.plot(SICO_UHO_BM32_R5,label="SICO_UHO_BM32_R5")
plt.plot(SICO_UHO_BM32_SU,label="SICO_UHO_BM32_SU")
plt.legend()

RF_SICO_UHO_BM32_R0=np.append(RF_SICO_UHO_BM32_R0[0],RF_SICO_UHO_BM32_R0)
RF_SICO_UHO_BM32_R1=np.append(RF_SICO_UHO_BM32_R1[0],RF_SICO_UHO_BM32_R1)
RF_SICO_UHO_BM32_R2=np.append(RF_SICO_UHO_BM32_R2[0],RF_SICO_UHO_BM32_R2)
RF_SICO_UHO_BM32_R3=np.append(RF_SICO_UHO_BM32_R3[0],RF_SICO_UHO_BM32_R3)
RF_SICO_UHO_BM32_R4=np.append(RF_SICO_UHO_BM32_R4[0],RF_SICO_UHO_BM32_R4)
RF_SICO_UHO_BM32_R5=np.append(RF_SICO_UHO_BM32_R5[0],RF_SICO_UHO_BM32_R5)
RF_SICO_UHO_BM32_SU=np.append(RF_SICO_UHO_BM32_SU[0],RF_SICO_UHO_BM32_SU)

print(len(RF_SICO_UHO_BM32_R0))
# Out:
# 200

# %%
# Response functions
np.savetxt("RF_SICO_UHO_BM01_R0.dat", RF_SICO_UHO_BM01_R0, delimiter=",")
np.savetxt("RF_SICO_UHO_BM01_R1.dat", RF_SICO_UHO_BM01_R1, delimiter=",")
np.savetxt("RF_SICO_UHO_BM01_R2.dat", RF_SICO_UHO_BM01_R2, delimiter=",")
np.savetxt("RF_SICO_UHO_BM01_R3.dat", RF_SICO_UHO_BM01_R3, delimiter=",")
np.savetxt("RF_SICO_UHO_BM01_R4.dat", RF_SICO_UHO_BM01_R4, delimiter=",")
np.savetxt("RF_SICO_UHO_BM01_R5.dat", RF_SICO_UHO_BM01_R5, delimiter=",")
np.savetxt("RF_SICO_UHO_BM01_SU.dat", RF_SICO_UHO_BM01_SU, delimiter=",")

# %%
np.savetxt("RF_SICO_UHO_BM02_R0.dat", RF_SICO_UHO_BM02_R0, delimiter=",")
np.savetxt("RF_SICO_UHO_BM02_R1.dat", RF_SICO_UHO_BM02_R1, delimiter=",")
np.savetxt("RF_SICO_UHO_BM02_R2.dat", RF_SICO_UHO_BM02_R2, delimiter=",")
np.savetxt("RF_SICO_UHO_BM02_R3.dat", RF_SICO_UHO_BM02_R3, delimiter=",")
np.savetxt("RF_SICO_UHO_BM02_R4.dat", RF_SICO_UHO_BM02_R4, delimiter=",")
np.savetxt("RF_SICO_UHO_BM02_R5.dat", RF_SICO_UHO_BM02_R5, delimiter=",")
np.savetxt("RF_SICO_UHO_BM02_SU.dat", RF_SICO_UHO_BM02_SU, delimiter=",")

# %%
np.savetxt("RF_SICO_UHO_BM04_R0.dat", RF_SICO_UHO_BM04_R0, delimiter=",")
np.savetxt("RF_SICO_UHO_BM04_R1.dat", RF_SICO_UHO_BM04_R1, delimiter=",")
np.savetxt("RF_SICO_UHO_BM04_R2.dat", RF_SICO_UHO_BM04_R2, delimiter=",")
np.savetxt("RF_SICO_UHO_BM04_R3.dat", RF_SICO_UHO_BM04_R3, delimiter=",")
np.savetxt("RF_SICO_UHO_BM04_R4.dat", RF_SICO_UHO_BM04_R4, delimiter=",")
np.savetxt("RF_SICO_UHO_BM04_R5.dat", RF_SICO_UHO_BM04_R5, delimiter=",")
np.savetxt("RF_SICO_UHO_BM04_SU.dat", RF_SICO_UHO_BM04_SU, delimiter=",")

# %%
np.savetxt("RF_SICO_UHO_BM08_R0.dat", RF_SICO_UHO_BM08_R0, delimiter=",")
np.savetxt("RF_SICO_UHO_BM08_R1.dat", RF_SICO_UHO_BM08_R1, delimiter=",")
np.savetxt("RF_SICO_UHO_BM08_R2.dat", RF_SICO_UHO_BM08_R2, delimiter=",")
np.savetxt("RF_SICO_UHO_BM08_R3.dat", RF_SICO_UHO_BM08_R3, delimiter=",")
np.savetxt("RF_SICO_UHO_BM08_R4.dat", RF_SICO_UHO_BM08_R4, delimiter=",")
np.savetxt("RF_SICO_UHO_BM08_R5.dat", RF_SICO_UHO_BM08_R5, delimiter=",")
np.savetxt("RF_SICO_UHO_BM08_SU.dat", RF_SICO_UHO_BM08_SU, delimiter=",")

# %%
np.savetxt("RF_SICO_UHO_BM16_R0.dat", RF_SICO_UHO_BM16_R0, delimiter=",")
np.savetxt("RF_SICO_UHO_BM16_R1.dat", RF_SICO_UHO_BM16_R1, delimiter=",")
np.savetxt("RF_SICO_UHO_BM16_R2.dat", RF_SICO_UHO_BM16_R2, delimiter=",")
np.savetxt("RF_SICO_UHO_BM16_R3.dat", RF_SICO_UHO_BM16_R3, delimiter=",")
np.savetxt("RF_SICO_UHO_BM16_R4.dat", RF_SICO_UHO_BM16_R4, delimiter=",")
np.savetxt("RF_SICO_UHO_BM16_R5.dat", RF_SICO_UHO_BM16_R5, delimiter=",")
np.savetxt("RF_SICO_UHO_BM16_SU.dat", RF_SICO_UHO_BM16_SU, delimiter=",")

# %%
np.savetxt("RF_SICO_UHO_BM32_R0.dat", RF_SICO_UHO_BM32_R0, delimiter=",")
np.savetxt("RF_SICO_UHO_BM32_R1.dat", RF_SICO_UHO_BM32_R1, delimiter=",")
np.savetxt("RF_SICO_UHO_BM32_R2.dat", RF_SICO_UHO_BM32_R2, delimiter=",")
np.savetxt("RF_SICO_UHO_BM32_R3.dat", RF_SICO_UHO_BM32_R3, delimiter=",")
np.savetxt("RF_SICO_UHO_BM32_R4.dat", RF_SICO_UHO_BM32_R4, delimiter=",")
np.savetxt("RF_SICO_UHO_BM32_R5.dat", RF_SICO_UHO_BM32_R5, delimiter=",")
np.savetxt("RF_SICO_UHO_BM32_SU.dat", RF_SICO_UHO_BM32_SU, delimiter=",")

# %%
# Experiments
np.savetxt("SICO_UHO_BM01_R0.dat", SICO_UHO_BM01_R0, delimiter=",")
np.savetxt("SICO_UHO_BM01_R1.dat", SICO_UHO_BM01_R1, delimiter=",")
np.savetxt("SICO_UHO_BM01_R2.dat", SICO_UHO_BM01_R2, delimiter=",")
np.savetxt("SICO_UHO_BM01_R3.dat", SICO_UHO_BM01_R3, delimiter=",")
np.savetxt("SICO_UHO_BM01_R4.dat", SICO_UHO_BM01_R4, delimiter=",")
np.savetxt("SICO_UHO_BM01_R5.dat", SICO_UHO_BM01_R5, delimiter=",")
np.savetxt("SICO_UHO_BM01_SU.dat", SICO_UHO_BM01_SU, delimiter=",")

# %%
np.savetxt("SICO_UHO_BM02_R0.dat", SICO_UHO_BM02_R0, delimiter=",")
np.savetxt("SICO_UHO_BM02_R1.dat", SICO_UHO_BM02_R1, delimiter=",")
np.savetxt("SICO_UHO_BM02_R2.dat", SICO_UHO_BM02_R2, delimiter=",")
np.savetxt("SICO_UHO_BM02_R3.dat", SICO_UHO_BM02_R3, delimiter=",")
np.savetxt("SICO_UHO_BM02_R4.dat", SICO_UHO_BM02_R4, delimiter=",")
np.savetxt("SICO_UHO_BM02_R5.dat", SICO_UHO_BM02_R5, delimiter=",")
np.savetxt("SICO_UHO_BM02_SU.dat", SICO_UHO_BM02_SU, delimiter=",")

# %%
np.savetxt("SICO_UHO_BM04_R0.dat", SICO_UHO_BM04_R0, delimiter=",")
np.savetxt("SICO_UHO_BM04_R1.dat", SICO_UHO_BM04_R1, delimiter=",")
np.savetxt("SICO_UHO_BM04_R2.dat", SICO_UHO_BM04_R2, delimiter=",")
np.savetxt("SICO_UHO_BM04_R3.dat", SICO_UHO_BM04_R3, delimiter=",")
np.savetxt("SICO_UHO_BM04_R4.dat", SICO_UHO_BM04_R4, delimiter=",")
np.savetxt("SICO_UHO_BM04_R5.dat", SICO_UHO_BM04_R5, delimiter=",")
np.savetxt("SICO_UHO_BM04_SU.dat", SICO_UHO_BM04_SU, delimiter=",")

# %%
np.savetxt("SICO_UHO_BM08_R0.dat", SICO_UHO_BM08_R0, delimiter=",")
np.savetxt("SICO_UHO_BM08_R1.dat", SICO_UHO_BM08_R1, delimiter=",")
np.savetxt("SICO_UHO_BM08_R2.dat", SICO_UHO_BM08_R2, delimiter=",")
np.savetxt("SICO_UHO_BM08_R3.dat", SICO_UHO_BM08_R3, delimiter=",")
np.savetxt("SICO_UHO_BM08_R4.dat", SICO_UHO_BM08_R4, delimiter=",")
np.savetxt("SICO_UHO_BM08_R5.dat", SICO_UHO_BM08_R5, delimiter=",")
np.savetxt("SICO_UHO_BM08_SU.dat", SICO_UHO_BM08_SU, delimiter=",")

# %%
np.savetxt("SICO_UHO_BM16_R0.dat", SICO_UHO_BM16_R0, delimiter=",")
np.savetxt("SICO_UHO_BM16_R1.dat", SICO_UHO_BM16_R1, delimiter=",")
np.savetxt("SICO_UHO_BM16_R2.dat", SICO_UHO_BM16_R2, delimiter=",")
np.savetxt("SICO_UHO_BM16_R3.dat", SICO_UHO_BM16_R3, delimiter=",")
np.savetxt("SICO_UHO_BM16_R4.dat", SICO_UHO_BM16_R4, delimiter=",")
np.savetxt("SICO_UHO_BM16_R5.dat", SICO_UHO_BM16_R5, delimiter=",")
np.savetxt("SICO_UHO_BM16_SU.dat", SICO_UHO_BM16_SU, delimiter=",")

# %%
np.savetxt("SICO_UHO_BM32_R0.dat", SICO_UHO_BM32_R0, delimiter=",")
np.savetxt("SICO_UHO_BM32_R1.dat", SICO_UHO_BM32_R1, delimiter=",")
np.savetxt("SICO_UHO_BM32_R2.dat", SICO_UHO_BM32_R2, delimiter=",")
np.savetxt("SICO_UHO_BM32_R3.dat", SICO_UHO_BM32_R3, delimiter=",")
np.savetxt("SICO_UHO_BM32_R4.dat", SICO_UHO_BM32_R4, delimiter=",")
np.savetxt("SICO_UHO_BM32_R5.dat", SICO_UHO_BM32_R5, delimiter=",")
np.savetxt("SICO_UHO_BM32_SU.dat", SICO_UHO_BM32_SU, delimiter=",")
