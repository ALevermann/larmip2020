# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv
#import pandas

# %%
slfact = -1e15 / 3.61e14 * 910 / 1000 # m3 / m2
print(slfact)
# Out:
# -2.5207756232686984

# %%
# UA_UNN = UA UNN
# Experiment BM01

fname = "larmip_data/UA_UNN/M1R1.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM01_R1 = np.array([float(row) for row in f])
UA_UNN_BM01_R1=np.array([x*slfact for x in UA_UNN_BM01_R1[0:]])/-1000

fname = "larmip_data/UA_UNN/M1R2.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM01_R2 = np.array([float(row) for row in f])
UA_UNN_BM01_R2=np.array([x*slfact for x in UA_UNN_BM01_R2[0:]])/-1000

fname = "larmip_data/UA_UNN/M1R3.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM01_R3 = np.array([float(row) for row in f])
UA_UNN_BM01_R3=np.array([x*slfact for x in UA_UNN_BM01_R3[0:]])/-1000

fname = "larmip_data/UA_UNN/M1R4.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM01_R4 = np.array([float(row) for row in f])
UA_UNN_BM01_R4=np.array([x*slfact for x in UA_UNN_BM01_R4[0:]])/-1000

fname = "larmip_data/UA_UNN/M1R5.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM01_R5 = np.array([float(row) for row in f])
UA_UNN_BM01_R5=np.array([x*slfact for x in UA_UNN_BM01_R5[0:]])/-1000

UA_UNN_BM01_SU = UA_UNN_BM01_R1+UA_UNN_BM01_R2+UA_UNN_BM01_R3+UA_UNN_BM01_R4+UA_UNN_BM01_R5

# create and write response function
RF_UA_UNN_BM01_R1=np.diff(UA_UNN_BM01_R1)/1
RF_UA_UNN_BM01_R2=np.diff(UA_UNN_BM01_R2)/1
RF_UA_UNN_BM01_R3=np.diff(UA_UNN_BM01_R3)/1
RF_UA_UNN_BM01_R4=np.diff(UA_UNN_BM01_R4)/1
RF_UA_UNN_BM01_R5=np.diff(UA_UNN_BM01_R5)/1
RF_UA_UNN_BM01_SU=np.diff(UA_UNN_BM01_SU)/1

RF_UA_UNN_BM01_R1=np.append(RF_UA_UNN_BM01_R1[0],RF_UA_UNN_BM01_R1)
RF_UA_UNN_BM01_R2=np.append(RF_UA_UNN_BM01_R2[0],RF_UA_UNN_BM01_R2)
RF_UA_UNN_BM01_R3=np.append(RF_UA_UNN_BM01_R3[0],RF_UA_UNN_BM01_R3)
RF_UA_UNN_BM01_R4=np.append(RF_UA_UNN_BM01_R4[0],RF_UA_UNN_BM01_R4)
RF_UA_UNN_BM01_R5=np.append(RF_UA_UNN_BM01_R5[0],RF_UA_UNN_BM01_R5)
RF_UA_UNN_BM01_SU=np.append(RF_UA_UNN_BM01_SU[0],RF_UA_UNN_BM01_SU)

# plot
plt.plot(UA_UNN_BM01_R1,label="UA_UNN_BM01_R1")
plt.plot(UA_UNN_BM01_R2,label="UA_UNN_BM01_R2")
plt.plot(UA_UNN_BM01_R3,label="UA_UNN_BM01_R3")
plt.plot(UA_UNN_BM01_R4,label="UA_UNN_BM01_R4")
plt.plot(UA_UNN_BM01_R5,label="UA_UNN_BM01_R5")
plt.plot(UA_UNN_BM01_SU,label="UA_UNN_BM01_SU")
plt.legend()

print(len(RF_UA_UNN_BM01_R1))
# Out:
# 200

# %%
# UA_UNN = UA UNN
# Experiment BM02

fname = "larmip_data/UA_UNN/M2R1.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM02_R1 = np.array([float(row) for row in f])
UA_UNN_BM02_R1=np.array([x*slfact for x in UA_UNN_BM02_R1[0:]])/-1000

fname = "larmip_data/UA_UNN/M2R2.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM02_R2 = np.array([float(row) for row in f])
UA_UNN_BM02_R2=np.array([x*slfact for x in UA_UNN_BM02_R2[0:]])/-1000

fname = "larmip_data/UA_UNN/M2R3.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM02_R3 = np.array([float(row) for row in f])
UA_UNN_BM02_R3=np.array([x*slfact for x in UA_UNN_BM02_R3[0:]])/-1000

fname = "larmip_data/UA_UNN/M2R4.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM02_R4 = np.array([float(row) for row in f])
UA_UNN_BM02_R4=np.array([x*slfact for x in UA_UNN_BM02_R4[0:]])/-1000

fname = "larmip_data/UA_UNN/M2R5.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM02_R5 = np.array([float(row) for row in f])
UA_UNN_BM02_R5=np.array([x*slfact for x in UA_UNN_BM02_R5[0:]])/-1000

UA_UNN_BM02_SU = UA_UNN_BM02_R1+UA_UNN_BM02_R2+UA_UNN_BM02_R3+UA_UNN_BM02_R4+UA_UNN_BM02_R5

# create and write response function
RF_UA_UNN_BM02_R1=np.diff(UA_UNN_BM02_R1)/2
RF_UA_UNN_BM02_R2=np.diff(UA_UNN_BM02_R2)/2
RF_UA_UNN_BM02_R3=np.diff(UA_UNN_BM02_R3)/2
RF_UA_UNN_BM02_R4=np.diff(UA_UNN_BM02_R4)/2
RF_UA_UNN_BM02_R5=np.diff(UA_UNN_BM02_R5)/2
RF_UA_UNN_BM02_SU=np.diff(UA_UNN_BM02_SU)/2

RF_UA_UNN_BM02_R1=np.append(RF_UA_UNN_BM02_R1[0],RF_UA_UNN_BM02_R1)
RF_UA_UNN_BM02_R2=np.append(RF_UA_UNN_BM02_R2[0],RF_UA_UNN_BM02_R2)
RF_UA_UNN_BM02_R3=np.append(RF_UA_UNN_BM02_R3[0],RF_UA_UNN_BM02_R3)
RF_UA_UNN_BM02_R4=np.append(RF_UA_UNN_BM02_R4[0],RF_UA_UNN_BM02_R4)
RF_UA_UNN_BM02_R5=np.append(RF_UA_UNN_BM02_R5[0],RF_UA_UNN_BM02_R5)
RF_UA_UNN_BM02_SU=np.append(RF_UA_UNN_BM02_SU[0],RF_UA_UNN_BM02_SU)

# plot
plt.plot(UA_UNN_BM02_R1,label="UA_UNN_BM02_R1")
plt.plot(UA_UNN_BM02_R2,label="UA_UNN_BM02_R2")
plt.plot(UA_UNN_BM02_R3,label="UA_UNN_BM02_R3")
plt.plot(UA_UNN_BM02_R4,label="UA_UNN_BM02_R4")
plt.plot(UA_UNN_BM02_R5,label="UA_UNN_BM02_R5")
plt.plot(UA_UNN_BM02_SU,label="UA_UNN_BM02_SU")
plt.legend()

print(len(RF_UA_UNN_BM02_R1))
# Out:
# 200

# %%
# UA_UNN = UA UNN
# Experiment BM04

fname = "larmip_data/UA_UNN/M4R1.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM04_R1 = np.array([float(row) for row in f])
UA_UNN_BM04_R1=np.array([x*slfact for x in UA_UNN_BM04_R1[0:]])/-1000

fname = "larmip_data/UA_UNN/M4R2.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM04_R2 = np.array([float(row) for row in f])
UA_UNN_BM04_R2=np.array([x*slfact for x in UA_UNN_BM04_R2[0:]])/-1000

fname = "larmip_data/UA_UNN/M4R3.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM04_R3 = np.array([float(row) for row in f])
UA_UNN_BM04_R3=np.array([x*slfact for x in UA_UNN_BM04_R3[0:]])/-1000

fname = "larmip_data/UA_UNN/M4R4.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM04_R4 = np.array([float(row) for row in f])
UA_UNN_BM04_R4=np.array([x*slfact for x in UA_UNN_BM04_R4[0:]])/-1000

fname = "larmip_data/UA_UNN/M4R5.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM04_R5 = np.array([float(row) for row in f])
UA_UNN_BM04_R5=np.array([x*slfact for x in UA_UNN_BM04_R5[0:]])/-1000

UA_UNN_BM04_SU = UA_UNN_BM04_R1+UA_UNN_BM04_R2+UA_UNN_BM04_R3+UA_UNN_BM04_R4+UA_UNN_BM04_R5

# create and write response function
RF_UA_UNN_BM04_R1=np.diff(UA_UNN_BM04_R1)/4
RF_UA_UNN_BM04_R2=np.diff(UA_UNN_BM04_R2)/4
RF_UA_UNN_BM04_R3=np.diff(UA_UNN_BM04_R3)/4
RF_UA_UNN_BM04_R4=np.diff(UA_UNN_BM04_R4)/4
RF_UA_UNN_BM04_R5=np.diff(UA_UNN_BM04_R5)/4
RF_UA_UNN_BM04_SU=np.diff(UA_UNN_BM04_SU)/4

RF_UA_UNN_BM04_R1=np.append(RF_UA_UNN_BM04_R1[0],RF_UA_UNN_BM04_R1)
RF_UA_UNN_BM04_R2=np.append(RF_UA_UNN_BM04_R2[0],RF_UA_UNN_BM04_R2)
RF_UA_UNN_BM04_R3=np.append(RF_UA_UNN_BM04_R3[0],RF_UA_UNN_BM04_R3)
RF_UA_UNN_BM04_R4=np.append(RF_UA_UNN_BM04_R4[0],RF_UA_UNN_BM04_R4)
RF_UA_UNN_BM04_R5=np.append(RF_UA_UNN_BM04_R5[0],RF_UA_UNN_BM04_R5)
RF_UA_UNN_BM04_SU=np.append(RF_UA_UNN_BM04_SU[0],RF_UA_UNN_BM04_SU)


# plot
plt.plot(UA_UNN_BM04_R1,label="UA_UNN_BM04_R1")
plt.plot(UA_UNN_BM04_R2,label="UA_UNN_BM04_R2")
plt.plot(UA_UNN_BM04_R3,label="UA_UNN_BM04_R3")
plt.plot(UA_UNN_BM04_R4,label="UA_UNN_BM04_R4")
plt.plot(UA_UNN_BM04_R5,label="UA_UNN_BM04_R5")
plt.plot(UA_UNN_BM04_SU,label="UA_UNN_BM04_SU")
plt.legend()

print(len(RF_UA_UNN_BM04_R1))
# Out:
# 200

# %%
# UA_UNN = UA UNN
# Experiment BM08

fname = "larmip_data/UA_UNN/M8R1.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM08_R1 = np.array([float(row) for row in f])
UA_UNN_BM08_R1=np.array([x*slfact for x in UA_UNN_BM08_R1[0:]])/-1000

fname = "larmip_data/UA_UNN/M8R2.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM08_R2 = np.array([float(row) for row in f])
UA_UNN_BM08_R2=np.array([x*slfact for x in UA_UNN_BM08_R2[0:]])/-1000

fname = "larmip_data/UA_UNN/M8R3.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM08_R3 = np.array([float(row) for row in f])
UA_UNN_BM08_R3=np.array([x*slfact for x in UA_UNN_BM08_R3[0:]])/-1000

fname = "larmip_data/UA_UNN/M8R4.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM08_R4 = np.array([float(row) for row in f])
UA_UNN_BM08_R4=np.array([x*slfact for x in UA_UNN_BM08_R4[0:]])/-1000

fname = "larmip_data/UA_UNN/M8R5.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM08_R5 = np.array([float(row) for row in f])
UA_UNN_BM08_R5=np.array([x*slfact for x in UA_UNN_BM08_R5[0:]])/-1000

UA_UNN_BM08_SU = UA_UNN_BM08_R1+UA_UNN_BM08_R2+UA_UNN_BM08_R3+UA_UNN_BM08_R4+UA_UNN_BM08_R5

# create and write response function
RF_UA_UNN_BM08_R1=np.diff(UA_UNN_BM08_R1)/8
RF_UA_UNN_BM08_R2=np.diff(UA_UNN_BM08_R2)/8
RF_UA_UNN_BM08_R3=np.diff(UA_UNN_BM08_R3)/8
RF_UA_UNN_BM08_R4=np.diff(UA_UNN_BM08_R4)/8
RF_UA_UNN_BM08_R5=np.diff(UA_UNN_BM08_R5)/8
RF_UA_UNN_BM08_SU=np.diff(UA_UNN_BM08_SU)/8

RF_UA_UNN_BM08_R1=np.append(RF_UA_UNN_BM08_R1[0],RF_UA_UNN_BM08_R1)
RF_UA_UNN_BM08_R2=np.append(RF_UA_UNN_BM08_R2[0],RF_UA_UNN_BM08_R2)
RF_UA_UNN_BM08_R3=np.append(RF_UA_UNN_BM08_R3[0],RF_UA_UNN_BM08_R3)
RF_UA_UNN_BM08_R4=np.append(RF_UA_UNN_BM08_R4[0],RF_UA_UNN_BM08_R4)
RF_UA_UNN_BM08_R5=np.append(RF_UA_UNN_BM08_R5[0],RF_UA_UNN_BM08_R5)
RF_UA_UNN_BM08_SU=np.append(RF_UA_UNN_BM08_SU[0],RF_UA_UNN_BM08_SU)


# plot
plt.plot(UA_UNN_BM08_R1,label="UA_UNN_BM08_R1")
plt.plot(UA_UNN_BM08_R2,label="UA_UNN_BM08_R2")
plt.plot(UA_UNN_BM08_R3,label="UA_UNN_BM08_R3")
plt.plot(UA_UNN_BM08_R4,label="UA_UNN_BM08_R4")
plt.plot(UA_UNN_BM08_R5,label="UA_UNN_BM08_R5")
plt.plot(UA_UNN_BM08_SU,label="UA_UNN_BM08_SU")
plt.legend()

print(len(RF_UA_UNN_BM08_R1))
# Out:
# 200

# %%
# UA_UNN = UA UNN
# Experiment BM16

fname = "larmip_data/UA_UNN/M16R1.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM16_R1 = np.array([float(row) for row in f])
UA_UNN_BM16_R1=np.array([x*slfact for x in UA_UNN_BM16_R1[0:]])/-1000

fname = "larmip_data/UA_UNN/M16R2.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM16_R2 = np.array([float(row) for row in f])
UA_UNN_BM16_R2=np.array([x*slfact for x in UA_UNN_BM16_R2[0:]])/-1000

fname = "larmip_data/UA_UNN/M16R3.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM16_R3 = np.array([float(row) for row in f])
UA_UNN_BM16_R3=np.array([x*slfact for x in UA_UNN_BM16_R3[0:]])/-1000

fname = "larmip_data/UA_UNN/M16R4.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM16_R4 = np.array([float(row) for row in f])
UA_UNN_BM16_R4=np.array([x*slfact for x in UA_UNN_BM16_R4[0:]])/-1000

fname = "larmip_data/UA_UNN/M16R5.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM16_R5 = np.array([float(row) for row in f])
UA_UNN_BM16_R5=np.array([x*slfact for x in UA_UNN_BM16_R5[0:]])/-1000

UA_UNN_BM16_SU = UA_UNN_BM16_R1+UA_UNN_BM16_R2+UA_UNN_BM16_R3+UA_UNN_BM16_R4+UA_UNN_BM16_R5

# create and write response function
RF_UA_UNN_BM16_R1=np.diff(UA_UNN_BM16_R1)/16
RF_UA_UNN_BM16_R2=np.diff(UA_UNN_BM16_R2)/16
RF_UA_UNN_BM16_R3=np.diff(UA_UNN_BM16_R3)/16
RF_UA_UNN_BM16_R4=np.diff(UA_UNN_BM16_R4)/16
RF_UA_UNN_BM16_R5=np.diff(UA_UNN_BM16_R5)/16
RF_UA_UNN_BM16_SU=np.diff(UA_UNN_BM16_SU)/16

RF_UA_UNN_BM16_R1=np.append(RF_UA_UNN_BM16_R1[0],RF_UA_UNN_BM16_R1)
RF_UA_UNN_BM16_R2=np.append(RF_UA_UNN_BM16_R2[0],RF_UA_UNN_BM16_R2)
RF_UA_UNN_BM16_R3=np.append(RF_UA_UNN_BM16_R3[0],RF_UA_UNN_BM16_R3)
RF_UA_UNN_BM16_R4=np.append(RF_UA_UNN_BM16_R4[0],RF_UA_UNN_BM16_R4)
RF_UA_UNN_BM16_R5=np.append(RF_UA_UNN_BM16_R5[0],RF_UA_UNN_BM16_R5)
RF_UA_UNN_BM16_SU=np.append(RF_UA_UNN_BM16_SU[0],RF_UA_UNN_BM16_SU)


# plot
plt.plot(UA_UNN_BM16_R1,label="UA_UNN_BM16_R1")
plt.plot(UA_UNN_BM16_R2,label="UA_UNN_BM16_R2")
plt.plot(UA_UNN_BM16_R3,label="UA_UNN_BM16_R3")
plt.plot(UA_UNN_BM16_R4,label="UA_UNN_BM16_R4")
plt.plot(UA_UNN_BM16_R5,label="UA_UNN_BM16_R5")
plt.plot(UA_UNN_BM16_SU,label="UA_UNN_BM16_SU")
plt.legend()

print(len(RF_UA_UNN_BM16_R1))
# Out:
# 200

# %%
# UA_UNN = UA UNN
# Experiment BM32

fname = "larmip_data/UA_UNN/M32R1.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM32_R1 = np.array([float(row) for row in f])
UA_UNN_BM32_R1=np.array([x*slfact for x in UA_UNN_BM32_R1[0:]])/-1000

fname = "larmip_data/UA_UNN/M32R2.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM32_R2 = np.array([float(row) for row in f])
UA_UNN_BM32_R2=np.array([x*slfact for x in UA_UNN_BM32_R2[0:]])/-1000

fname = "larmip_data/UA_UNN/M32R3.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM32_R3 = np.array([float(row) for row in f])
UA_UNN_BM32_R3=np.array([x*slfact for x in UA_UNN_BM32_R3[0:]])/-1000

fname = "larmip_data/UA_UNN/M32R4.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM32_R4 = np.array([float(row) for row in f])
UA_UNN_BM32_R4=np.array([x*slfact for x in UA_UNN_BM32_R4[0:]])/-1000

fname = "larmip_data/UA_UNN/M32R5.txt" # File to read   
with open(fname) as f:
    UA_UNN_BM32_R5 = np.array([float(row) for row in f])
UA_UNN_BM32_R5=np.array([x*slfact for x in UA_UNN_BM32_R5[0:]])/-1000

UA_UNN_BM32_SU = UA_UNN_BM32_R1+UA_UNN_BM32_R2+UA_UNN_BM32_R3+UA_UNN_BM32_R4+UA_UNN_BM32_R5

# create and write response function
RF_UA_UNN_BM32_R1=np.diff(UA_UNN_BM32_R1)/32
RF_UA_UNN_BM32_R2=np.diff(UA_UNN_BM32_R2)/32
RF_UA_UNN_BM32_R3=np.diff(UA_UNN_BM32_R3)/32
RF_UA_UNN_BM32_R4=np.diff(UA_UNN_BM32_R4)/32
RF_UA_UNN_BM32_R5=np.diff(UA_UNN_BM32_R5)/32
RF_UA_UNN_BM32_SU=np.diff(UA_UNN_BM32_SU)/32

RF_UA_UNN_BM32_R1=np.append(RF_UA_UNN_BM32_R1[0],RF_UA_UNN_BM32_R1)
RF_UA_UNN_BM32_R2=np.append(RF_UA_UNN_BM32_R2[0],RF_UA_UNN_BM32_R2)
RF_UA_UNN_BM32_R3=np.append(RF_UA_UNN_BM32_R3[0],RF_UA_UNN_BM32_R3)
RF_UA_UNN_BM32_R4=np.append(RF_UA_UNN_BM32_R4[0],RF_UA_UNN_BM32_R4)
RF_UA_UNN_BM32_R5=np.append(RF_UA_UNN_BM32_R5[0],RF_UA_UNN_BM32_R5)
RF_UA_UNN_BM32_SU=np.append(RF_UA_UNN_BM32_SU[0],RF_UA_UNN_BM32_SU)


# plot
plt.plot(UA_UNN_BM32_R1,label="UA_UNN_BM32_R1")
plt.plot(UA_UNN_BM32_R2,label="UA_UNN_BM32_R2")
plt.plot(UA_UNN_BM32_R3,label="UA_UNN_BM32_R3")
plt.plot(UA_UNN_BM32_R4,label="UA_UNN_BM32_R4")
plt.plot(UA_UNN_BM32_R5,label="UA_UNN_BM32_R5")
plt.plot(UA_UNN_BM32_SU,label="UA_UNN_BM32_SU")
plt.legend()

print(len(RF_UA_UNN_BM32_R1))
# Out:
# 200

# %%
np.savetxt("RF_UA_UNN_BM01_R1.dat", RF_UA_UNN_BM01_R1, delimiter=",")
np.savetxt("RF_UA_UNN_BM01_R2.dat", RF_UA_UNN_BM01_R2, delimiter=",")
np.savetxt("RF_UA_UNN_BM01_R3.dat", RF_UA_UNN_BM01_R3, delimiter=",")
np.savetxt("RF_UA_UNN_BM01_R4.dat", RF_UA_UNN_BM01_R4, delimiter=",")
np.savetxt("RF_UA_UNN_BM01_R5.dat", RF_UA_UNN_BM01_R5, delimiter=",")
np.savetxt("RF_UA_UNN_BM01_SU.dat", RF_UA_UNN_BM01_SU, delimiter=",")

# %%
np.savetxt("RF_UA_UNN_BM02_R1.dat", RF_UA_UNN_BM02_R1, delimiter=",")
np.savetxt("RF_UA_UNN_BM02_R2.dat", RF_UA_UNN_BM02_R2, delimiter=",")
np.savetxt("RF_UA_UNN_BM02_R3.dat", RF_UA_UNN_BM02_R3, delimiter=",")
np.savetxt("RF_UA_UNN_BM02_R4.dat", RF_UA_UNN_BM02_R4, delimiter=",")
np.savetxt("RF_UA_UNN_BM02_R5.dat", RF_UA_UNN_BM02_R5, delimiter=",")
np.savetxt("RF_UA_UNN_BM02_SU.dat", RF_UA_UNN_BM02_SU, delimiter=",")

# %%
np.savetxt("RF_UA_UNN_BM04_R1.dat", RF_UA_UNN_BM04_R1, delimiter=",")
np.savetxt("RF_UA_UNN_BM04_R2.dat", RF_UA_UNN_BM04_R2, delimiter=",")
np.savetxt("RF_UA_UNN_BM04_R3.dat", RF_UA_UNN_BM04_R3, delimiter=",")
np.savetxt("RF_UA_UNN_BM04_R4.dat", RF_UA_UNN_BM04_R4, delimiter=",")
np.savetxt("RF_UA_UNN_BM04_R5.dat", RF_UA_UNN_BM04_R5, delimiter=",")
np.savetxt("RF_UA_UNN_BM04_SU.dat", RF_UA_UNN_BM04_SU, delimiter=",")

# %%
np.savetxt("RF_UA_UNN_BM08_R1.dat", RF_UA_UNN_BM08_R1, delimiter=",")
np.savetxt("RF_UA_UNN_BM08_R2.dat", RF_UA_UNN_BM08_R2, delimiter=",")
np.savetxt("RF_UA_UNN_BM08_R3.dat", RF_UA_UNN_BM08_R3, delimiter=",")
np.savetxt("RF_UA_UNN_BM08_R4.dat", RF_UA_UNN_BM08_R4, delimiter=",")
np.savetxt("RF_UA_UNN_BM08_R5.dat", RF_UA_UNN_BM08_R5, delimiter=",")
np.savetxt("RF_UA_UNN_BM08_SU.dat", RF_UA_UNN_BM08_SU, delimiter=",")

# %%
np.savetxt("RF_UA_UNN_BM16_R1.dat", RF_UA_UNN_BM16_R1, delimiter=",")
np.savetxt("RF_UA_UNN_BM16_R2.dat", RF_UA_UNN_BM16_R2, delimiter=",")
np.savetxt("RF_UA_UNN_BM16_R3.dat", RF_UA_UNN_BM16_R3, delimiter=",")
np.savetxt("RF_UA_UNN_BM16_R4.dat", RF_UA_UNN_BM16_R4, delimiter=",")
np.savetxt("RF_UA_UNN_BM16_R5.dat", RF_UA_UNN_BM16_R5, delimiter=",")
np.savetxt("RF_UA_UNN_BM16_SU.dat", RF_UA_UNN_BM16_SU, delimiter=",")

# %%
np.savetxt("RF_UA_UNN_BM32_R1.dat", RF_UA_UNN_BM32_R1, delimiter=",")
np.savetxt("RF_UA_UNN_BM32_R2.dat", RF_UA_UNN_BM32_R2, delimiter=",")
np.savetxt("RF_UA_UNN_BM32_R3.dat", RF_UA_UNN_BM32_R3, delimiter=",")
np.savetxt("RF_UA_UNN_BM32_R4.dat", RF_UA_UNN_BM32_R4, delimiter=",")
np.savetxt("RF_UA_UNN_BM32_R5.dat", RF_UA_UNN_BM32_R5, delimiter=",")
np.savetxt("RF_UA_UNN_BM32_SU.dat", RF_UA_UNN_BM32_SU, delimiter=",")

# %%
# Experiments
np.savetxt("UA_UNN_BM01_R1.dat", UA_UNN_BM01_R1, delimiter=",")
np.savetxt("UA_UNN_BM01_R2.dat", UA_UNN_BM01_R2, delimiter=",")
np.savetxt("UA_UNN_BM01_R3.dat", UA_UNN_BM01_R3, delimiter=",")
np.savetxt("UA_UNN_BM01_R4.dat", UA_UNN_BM01_R4, delimiter=",")
np.savetxt("UA_UNN_BM01_R5.dat", UA_UNN_BM01_R5, delimiter=",")
np.savetxt("UA_UNN_BM01_SU.dat", UA_UNN_BM01_SU, delimiter=",")

# %%
# Experiments
np.savetxt("UA_UNN_BM02_R1.dat", UA_UNN_BM02_R1, delimiter=",")
np.savetxt("UA_UNN_BM02_R2.dat", UA_UNN_BM02_R2, delimiter=",")
np.savetxt("UA_UNN_BM02_R3.dat", UA_UNN_BM02_R3, delimiter=",")
np.savetxt("UA_UNN_BM02_R4.dat", UA_UNN_BM02_R4, delimiter=",")
np.savetxt("UA_UNN_BM02_R5.dat", UA_UNN_BM02_R5, delimiter=",")
np.savetxt("UA_UNN_BM02_SU.dat", UA_UNN_BM02_SU, delimiter=",")

# %%
# Experiments
np.savetxt("UA_UNN_BM04_R1.dat", UA_UNN_BM04_R1, delimiter=",")
np.savetxt("UA_UNN_BM04_R2.dat", UA_UNN_BM04_R2, delimiter=",")
np.savetxt("UA_UNN_BM04_R3.dat", UA_UNN_BM04_R3, delimiter=",")
np.savetxt("UA_UNN_BM04_R4.dat", UA_UNN_BM04_R4, delimiter=",")
np.savetxt("UA_UNN_BM04_R5.dat", UA_UNN_BM04_R5, delimiter=",")
np.savetxt("UA_UNN_BM04_SU.dat", UA_UNN_BM04_SU, delimiter=",")

# %%
# Experiments
np.savetxt("UA_UNN_BM08_R1.dat", UA_UNN_BM08_R1, delimiter=",")
np.savetxt("UA_UNN_BM08_R2.dat", UA_UNN_BM08_R2, delimiter=",")
np.savetxt("UA_UNN_BM08_R3.dat", UA_UNN_BM08_R3, delimiter=",")
np.savetxt("UA_UNN_BM08_R4.dat", UA_UNN_BM08_R4, delimiter=",")
np.savetxt("UA_UNN_BM08_R5.dat", UA_UNN_BM08_R5, delimiter=",")
np.savetxt("UA_UNN_BM08_SU.dat", UA_UNN_BM08_SU, delimiter=",")

# %%
# Experiments
np.savetxt("UA_UNN_BM16_R1.dat", UA_UNN_BM16_R1, delimiter=",")
np.savetxt("UA_UNN_BM16_R2.dat", UA_UNN_BM16_R2, delimiter=",")
np.savetxt("UA_UNN_BM16_R3.dat", UA_UNN_BM16_R3, delimiter=",")
np.savetxt("UA_UNN_BM16_R4.dat", UA_UNN_BM16_R4, delimiter=",")
np.savetxt("UA_UNN_BM16_R5.dat", UA_UNN_BM16_R5, delimiter=",")
np.savetxt("UA_UNN_BM16_SU.dat", UA_UNN_BM16_SU, delimiter=",")

# %%
# Experiments
np.savetxt("UA_UNN_BM32_R1.dat", UA_UNN_BM32_R1, delimiter=",")
np.savetxt("UA_UNN_BM32_R2.dat", UA_UNN_BM32_R2, delimiter=",")
np.savetxt("UA_UNN_BM32_R3.dat", UA_UNN_BM32_R3, delimiter=",")
np.savetxt("UA_UNN_BM32_R4.dat", UA_UNN_BM32_R4, delimiter=",")
np.savetxt("UA_UNN_BM32_R5.dat", UA_UNN_BM32_R5, delimiter=",")
np.savetxt("UA_UNN_BM32_SU.dat", UA_UNN_BM32_SU, delimiter=",")

# %%
print(len(RF_UA_UNN_BM08_R1))
# Out:
# 200
