# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv
import pandas as pd
from io import StringIO

# %%
Time = np.arange(1900,2100)
print(len(Time))
# Out:
# 200

# %%
# Read data
# AISM_VUB

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_AISM_VUB_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]
#Time = ncf.variable["Time"][:]

SL_wTd_nos_base_AISM_VUB_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_AISM_VUB_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_AISM_VUB_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_AISM_VUB_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_AISM_VUB_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_AISM_VUB_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_AISM_VUB_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

ncf.close()
print(max(SL_wTd_nos_base_AISM_VUB_SU_RCP60_99pc))
# Out:
# 0.11827712

# %%
print(len(SL_wTd_nos_base_R0[:,1]))
plt.plot(SL_wTd_nos_base_R0[:,100])
plt.plot(SL_wTd_nos_base_R0[:,1000])
plt.plot(SL_wTd_nos_base_R0[:,500])
# Out:
# 201

# %%
# Read data
# BISI_LBL

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_BISI_LBL_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_BISI_LBL_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_BISI_LBL_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_BISI_LBL_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_BISI_LBL_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_BISI_LBL_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_BISI_LBL_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_BISI_LBL_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_BISI_LBL_SU_RCP60_99pc))
# Out:
# 0.5562201

# %%
# Read data
# CISM_NCA

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_CISM_NCA_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_CISM_NCA_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_CISM_NCA_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_CISM_NCA_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_CISM_NCA_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_CISM_NCA_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_CISM_NCA_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_CISM_NCA_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_CISM_NCA_SU_RCP60_99pc))
# Out:
# 0.2830358

# %%
# Read data
# FETI_VUB

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_FETI_VUB_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_FETI_VUB_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_FETI_VUB_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_FETI_VUB_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_FETI_VUB_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_FETI_VUB_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_FETI_VUB_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_FETI_VUB_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_FETI_VUB_SU_RCP60_99pc))
# Out:
# 0.42395875

# %%
# Read data
# GRIS_LSC

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_GRIS_LSC_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_GRIS_LSC_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_GRIS_LSC_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_GRIS_LSC_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_GRIS_LSC_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_GRIS_LSC_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_GRIS_LSC_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_GRIS_LSC_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_GRIS_LSC_SU_RCP60_99pc))
print(len(SL_wTd_nos_base_GRIS_LSC_SU_RCP60_01pc))
print(len(SL_wTd_nos_base_R0[1,:]))
print(len(SL_wTd_nos_base_R0[:,1]))
# Out:
# 0.20100091
# 200
# 1001
# 201

# %%
# Read data
# IMAU_VUB

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_IMAU_VUB_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_IMAU_VUB_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_IMAU_VUB_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_IMAU_VUB_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_IMAU_VUB_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_IMAU_VUB_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_IMAU_VUB_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_IMAU_VUB_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_IMAU_VUB_SU_RCP60_99pc))
# Out:
# 0.8065038

# %%
# Read data
# ISSM_JPL

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_ISSM_JPL_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_ISSM_JPL_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_ISSM_JPL_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_ISSM_JPL_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_ISSM_JPL_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_ISSM_JPL_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_ISSM_JPL_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_ISSM_JPL_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_ISSM_JPL_SU_RCP60_99pc))
# Out:
# 0.35765207

# %%
# Read data
# ISSM_UCI

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_ISSM_UCI_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_ISSM_UCI_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_ISSM_UCI_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_ISSM_UCI_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_ISSM_UCI_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_ISSM_UCI_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_ISSM_UCI_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_ISSM_UCI_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_ISSM_UCI_SU_RCP60_99pc))
# Out:
# 0.8043265

# %%
# Read data
# MALI_LAN
fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_MALI_LAN_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_MALI_LAN_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_MALI_LAN_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_MALI_LAN_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_MALI_LAN_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_MALI_LAN_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_MALI_LAN_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_MALI_LAN_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_MALI_LAN_SU_RCP60_99pc))
# Out:
# 0.45500895

# %%
# Read data
# PISM_AWI

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_PISM_AWI_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_PISM_AWI_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_PISM_AWI_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_PISM_AWI_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_PISM_AWI_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_PISM_AWI_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_PISM_AWI_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_PISM_AWI_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_PISM_AWI_SU_RCP60_99pc))
# Out:
# 0.32046247

# %%
# Read data
# PISM_DMI

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_PISM_DMI_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_PISM_DMI_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_PISM_DMI_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_PISM_DMI_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_PISM_DMI_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_PISM_DMI_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_PISM_DMI_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_PISM_DMI_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_PISM_DMI_SU_RCP60_99pc))
# Out:
# 0.9214785

# %%
# Read data
# PISM_PIK

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_PISM_PIK_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_PISM_PIK_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_PISM_PIK_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_PISM_PIK_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_PISM_PIK_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_PISM_PIK_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_PISM_PIK_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_PISM_PIK_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_PISM_PIK_SU_RCP60_99pc))
# Out:
# 0.48385173

# %%
# Read data
# PISM_VUW

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_PISM_VUW_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_PISM_VUW_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_PISM_VUW_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_PISM_VUW_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_PISM_VUW_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_PISM_VUW_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_PISM_VUW_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_PISM_VUW_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_PISM_VUW_SU_RCP60_99pc))
# Out:
# 1.1341876

# %%
# Read data
# PS3D_PSU

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_PS3D_PSU_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_PS3D_PSU_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_PS3D_PSU_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_PS3D_PSU_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_PS3D_PSU_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_PS3D_PSU_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_PS3D_PSU_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_PS3D_PSU_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_PS3D_PSU_SU_RCP60_99pc))
# Out:
# 0.52148867

# %%
# Read data
# SICO_UHO

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_SICO_UHO_RCP60_cdf.nc"
#fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_nos_base_SICO_UHO_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_SICO_UHO_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_SICO_UHO_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_SICO_UHO_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_SICO_UHO_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_SICO_UHO_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_SICO_UHO_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_SICO_UHO_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_SICO_UHO_SU_RCP60_99pc))
# Out:
# 0.5087668

# %%
# Read data
# UA_UNN

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_UA_UNN_RCP60_cdf.nc"
#fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_nos_base_UA_UNN_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_UA_UNN_SU_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_UA_UNN_SU_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_UA_UNN_SU_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_UA_UNN_SU_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_UA_UNN_SU_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_UA_UNN_SU_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_UA_UNN_SU_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_UA_UNN_SU_RCP60_99pc))
# Out:
# 1.3880466

# %%
# Read data
# All Models

fname="..\ComputeCdfsOfProjections\Cdfs/SL_wTd_weighted_base_RCP60_cdf.nc"
ncf = nc.Dataset(fname, "r")

Percentile = ncf.variables["Percentile"][:]
SL_wTd_nos_base_R0 = ncf.variables["Antarctica"][:]

SL_wTd_nos_base_RCP60_01pc = SL_wTd_nos_base_R0[0:-1,10]
SL_wTd_nos_base_RCP60_05pc = SL_wTd_nos_base_R0[0:-1,50]
SL_wTd_nos_base_RCP60_17pc = SL_wTd_nos_base_R0[0:-1,166]
SL_wTd_nos_base_RCP60_50pc = SL_wTd_nos_base_R0[0:-1,500]
SL_wTd_nos_base_RCP60_83pc = SL_wTd_nos_base_R0[0:-1,833]
SL_wTd_nos_base_RCP60_95pc = SL_wTd_nos_base_R0[0:-1,950]
SL_wTd_nos_base_RCP60_99pc = SL_wTd_nos_base_R0[0:-1,990]

print(max(SL_wTd_nos_base_RCP60_99pc))
# Out:
# 0.77874607

# %%
# Set plotting variables
SizeOfFont = 20

# For all panels but Whole Antarctica
xmin = 1900
xmax = 2100
ymin = -0.01
ymax = 1.05
xlimit = [xmin, xmax]
ylimit = [ymin, ymax]
AspectRatio = 1.0*((xmax-xmin)/(ymax-ymin))


figwidth = 20

ScalingTextXPos= xmin+10
ScalingTextYPos= ymax-0.1

# %%
fp, axes = plt.subplots(4, 4,figsize=(figwidth,figwidth))
#fp.subplots_adjust(hspace=0.2, wspace=0.01)
fp.subplots_adjust(hspace=0.15, wspace=0.01)

# AISM_VUB

ax = axes[0,0]
ax.fill_between(Time, SL_wTd_nos_base_AISM_VUB_SU_RCP60_01pc, SL_wTd_nos_base_AISM_VUB_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_AISM_VUB_SU_RCP60_05pc, SL_wTd_nos_base_AISM_VUB_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_AISM_VUB_SU_RCP60_17pc, SL_wTd_nos_base_AISM_VUB_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_AISM_VUB_SU_RCP60_50pc, '#ffffff')

ax.xaxis.set_visible(False)
#ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"AISM VUB",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R1,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# BISI_LBL

ax = axes[0,1]
ax.fill_between(Time, SL_wTd_nos_base_BISI_LBL_SU_RCP60_01pc, SL_wTd_nos_base_BISI_LBL_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_BISI_LBL_SU_RCP60_05pc, SL_wTd_nos_base_BISI_LBL_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_BISI_LBL_SU_RCP60_17pc, SL_wTd_nos_base_BISI_LBL_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_BISI_LBL_SU_RCP60_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"BISI LBL",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R1,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# CISM_NCA

ax = axes[0,2]
ax.fill_between(Time, SL_wTd_nos_base_CISM_NCA_SU_RCP60_01pc, SL_wTd_nos_base_CISM_NCA_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_CISM_NCA_SU_RCP60_05pc, SL_wTd_nos_base_CISM_NCA_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_CISM_NCA_SU_RCP60_17pc, SL_wTd_nos_base_CISM_NCA_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_CISM_NCA_SU_RCP60_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"CISM NCA",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R1,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# FETI_VUB
ax = axes[0,3]
ax.fill_between(Time, SL_wTd_nos_base_FETI_VUB_SU_RCP60_01pc, SL_wTd_nos_base_FETI_VUB_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_FETI_VUB_SU_RCP60_05pc, SL_wTd_nos_base_FETI_VUB_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_FETI_VUB_SU_RCP60_17pc, SL_wTd_nos_base_FETI_VUB_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_FETI_VUB_SU_RCP60_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"FETI ULB",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R2,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# GRIS_LSC
ax = axes[1,0]
#ax.plot(ISSM_UCI_BM02_R3[:endyear],'g')
ax.fill_between(Time, SL_wTd_nos_base_GRIS_LSC_SU_RCP60_01pc, SL_wTd_nos_base_GRIS_LSC_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_GRIS_LSC_SU_RCP60_05pc, SL_wTd_nos_base_GRIS_LSC_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_GRIS_LSC_SU_RCP60_17pc, SL_wTd_nos_base_GRIS_LSC_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_GRIS_LSC_SU_RCP60_50pc, '#ffffff')

ax.xaxis.set_visible(False)
#ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"GRIS LSC",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R3,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# IMAU_VUB
ax = axes[1,1]
#ax.plot(ISSM_UCI_BM02_R4[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_nos_base_IMAU_VUB_SU_RCP60_01pc, SL_wTd_nos_base_IMAU_VUB_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_IMAU_VUB_SU_RCP60_05pc, SL_wTd_nos_base_IMAU_VUB_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_IMAU_VUB_SU_RCP60_17pc, SL_wTd_nos_base_IMAU_VUB_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_IMAU_VUB_SU_RCP60_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"IMAU UU",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R4,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# ISSM_JPL
ax = axes[1,2]
#ax.plot(ISSM_UCI_BM04_R5[:endyear],'b')
ax.fill_between(Time, SL_wTd_nos_base_ISSM_JPL_SU_RCP60_01pc, SL_wTd_nos_base_ISSM_JPL_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_ISSM_JPL_SU_RCP60_05pc, SL_wTd_nos_base_ISSM_JPL_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_ISSM_JPL_SU_RCP60_17pc, SL_wTd_nos_base_ISSM_JPL_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_ISSM_JPL_SU_RCP60_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"ISSM JPL",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R5,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# ISSM_UCI
ax = axes[1,3]
#ax.plot(ISSM_UCI_BM02_R0[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_nos_base_ISSM_UCI_SU_RCP60_01pc, SL_wTd_nos_base_ISSM_UCI_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_ISSM_UCI_SU_RCP60_05pc, SL_wTd_nos_base_ISSM_UCI_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_ISSM_UCI_SU_RCP60_17pc, SL_wTd_nos_base_ISSM_UCI_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_ISSM_UCI_SU_RCP60_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
#ax.yaxis.set_label_position("right")
ax.yaxis.set_ticks_position("right")
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"ISSM UCI",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R0,2))
#ax.text(ScalingTextXPos2,ScalingTextYPos2,ScalingText,fontsize = SizeOfFont)


# MALI_LAN
ax = axes[2,0]
#ax.plot(MALI_LAN_BM02_R0[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_nos_base_MALI_LAN_SU_RCP60_01pc, SL_wTd_nos_base_MALI_LAN_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_MALI_LAN_SU_RCP60_05pc, SL_wTd_nos_base_MALI_LAN_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_MALI_LAN_SU_RCP60_17pc, SL_wTd_nos_base_MALI_LAN_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_MALI_LAN_SU_RCP60_50pc, '#ffffff')

ax.xaxis.set_visible(False)
#ax.yaxis.set_visible(False)
#ax.yaxis.set_label_position("right")
#ax.yaxis.set_ticks_position("right")
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"MALI DOE",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R0,2))
#ax.text(ScalingTextXPos2,ScalingTextYPos2,ScalingText,fontsize = SizeOfFont)


# PISM_AWI
ax = axes[2,1]
#ax.plot(ISSM_UCI_BM02_R4[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_nos_base_PISM_AWI_SU_RCP60_01pc, SL_wTd_nos_base_PISM_AWI_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_PISM_AWI_SU_RCP60_05pc, SL_wTd_nos_base_PISM_AWI_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_PISM_AWI_SU_RCP60_17pc, SL_wTd_nos_base_PISM_AWI_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_PISM_AWI_SU_RCP60_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"PISM AWI",fontsize = SizeOfFont)
ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R4,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# PISM_DMI
ax = axes[2,2]
#ax.plot(PISM_DMI_BM02_R4[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_nos_base_PISM_DMI_SU_RCP60_01pc, SL_wTd_nos_base_PISM_DMI_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_PISM_DMI_SU_RCP60_05pc, SL_wTd_nos_base_PISM_DMI_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_PISM_DMI_SU_RCP60_17pc, SL_wTd_nos_base_PISM_DMI_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_PISM_DMI_SU_RCP60_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"PISM DMI",fontsize = SizeOfFont)
ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R4,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# PISM_PIK
ax = axes[2,3]
#ax.plot(PISM_PIK_BM04_R5[:endyear],'b')
ax.fill_between(Time, SL_wTd_nos_base_PISM_PIK_SU_RCP60_01pc, SL_wTd_nos_base_PISM_PIK_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_PISM_PIK_SU_RCP60_05pc, SL_wTd_nos_base_PISM_PIK_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_PISM_PIK_SU_RCP60_17pc, SL_wTd_nos_base_PISM_PIK_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_PISM_PIK_SU_RCP60_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"PISM PIK",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R5,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# PISM_VUW
ax = axes[3,0]
#ax.plot(ISSM_UCI_BM02_R0[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_nos_base_PISM_VUW_SU_RCP60_01pc, SL_wTd_nos_base_PISM_VUW_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_PISM_VUW_SU_RCP60_05pc, SL_wTd_nos_base_PISM_VUW_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_PISM_VUW_SU_RCP60_17pc, SL_wTd_nos_base_PISM_VUW_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_PISM_VUW_SU_RCP60_50pc, '#ffffff')

#ax.xaxis.set_visible(False)
#ax.yaxis.set_visible(False)
#ax.yaxis.set_label_position("right")
#ax.yaxis.set_ticks_position("right")
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"PISM VUW",fontsize = SizeOfFont)
ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R0,2))
#ax.text(ScalingTextXPos2,ScalingTextYPos2,ScalingText,fontsize = SizeOfFont)

# PS3D_PSU
ax = axes[3,1]
#ax.plot(ISSM_UCI_BM02_R4[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_nos_base_PS3D_PSU_SU_RCP60_01pc, SL_wTd_nos_base_PS3D_PSU_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_PS3D_PSU_SU_RCP60_05pc, SL_wTd_nos_base_PS3D_PSU_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_PS3D_PSU_SU_RCP60_17pc, SL_wTd_nos_base_PS3D_PSU_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_PS3D_PSU_SU_RCP60_50pc, '#ffffff')

#ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"PS3D PSU",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R4,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)
ax.xaxis.set_ticks(np.arange(1950, 2150, 50))


# SICO_UHO
ax = axes[3,2]
#ax.plot(ISSM_UCI_BM04_R5[:endyear],'b')
ax.fill_between(Time, SL_wTd_nos_base_SICO_UHO_SU_RCP60_01pc, SL_wTd_nos_base_SICO_UHO_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_SICO_UHO_SU_RCP60_05pc, SL_wTd_nos_base_SICO_UHO_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_SICO_UHO_SU_RCP60_17pc, SL_wTd_nos_base_SICO_UHO_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_SICO_UHO_SU_RCP60_50pc, '#ffffff')

#ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"SICO ILTS",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
ax.xaxis.set_ticks(np.arange(1950, 2150, 50))
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R5,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# UA UNN
ax = axes[3,3]
ax.fill_between(Time, SL_wTd_nos_base_UA_UNN_SU_RCP60_01pc, SL_wTd_nos_base_UA_UNN_SU_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_UA_UNN_SU_RCP60_05pc, SL_wTd_nos_base_UA_UNN_SU_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_UA_UNN_SU_RCP60_17pc, SL_wTd_nos_base_UA_UNN_SU_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_UA_UNN_SU_RCP60_50pc, '#ffffff')

#ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.yaxis.set_label_position("right")
ax.yaxis.set_ticks_position("right")
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"ÚA UNN",fontsize = SizeOfFont)
ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
ax.xaxis.set_ticks(np.arange(1950, 2150, 50))
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R0,2))
#ax.text(ScalingTextXPos2,ScalingTextYPos2,ScalingText,fontsize = SizeOfFont)



fp.savefig("Figures/RCP60_weighted.pdf", bbox_inches='tight')

# %%
fp = plt.figure()

# Set plotting variables
SizeOfFont = 20
#Scalefactor = 1000 # 1 = m and 1000 = mm

# For all panels but Whole Antarctica
#xmin = 1992
#xmax = 2017
#ymin = 0.0*Scalefactor
#ymax = 0.016*Scalefactor
#xlimit = [xmin, xmax]
#ylimit = [ymin, ymax]
#AspectRatio = 1.0*((xmax-xmin)/(ymax-ymin))


#figwidth = 15

#ScalingTextXPos= xmin+10
#ScalingTextYPos= ymax-0.08

fp, axes = plt.subplots(1, 1,figsize=(figwidth,figwidth/3*2))
fp.subplots_adjust(hspace=0.2, wspace=0.05)

ax = axes

#plt.fill_between(Time, SL_wTd_nos_base_RCP60_01pc*Scalefactor, SL_wTd_nos_base_RCP60_99pc*Scalefactor,facecolor='+f8900b',alpha=0.25)
#plt.fill_between(Time, SL_wTd_nos_base_RCP60_05pc*Scalefactor, SL_wTd_nos_base_RCP60_95pc*Scalefactor,facecolor='+f8900b',alpha=0.5)
#plt.fill_between(Time, SL_wTd_nos_base_RCP60_17pc*Scalefactor, SL_wTd_nos_base_RCP60_83pc*Scalefactor,facecolor='+f8900b')
#plt.plot(Time, SL_wTd_nos_base_RCP60_50pc*Scalefactor, '#ffffff')

ax.fill_between(Time, SL_wTd_nos_base_RCP60_01pc, SL_wTd_nos_base_RCP60_99pc,facecolor='#f8900b',alpha=0.25)
ax.fill_between(Time, SL_wTd_nos_base_RCP60_05pc, SL_wTd_nos_base_RCP60_95pc,facecolor='#f8900b',alpha=0.5)
ax.fill_between(Time, SL_wTd_nos_base_RCP60_17pc, SL_wTd_nos_base_RCP60_83pc,facecolor='#f8900b')
ax.plot(Time, SL_wTd_nos_base_RCP60_50pc, '#ffffff')

#ax.plot(ObsTime,ObsSL,'k')
#ax.plot(ObsTime,ObsSL-ObsUncertainty,':k')
#ax.plot(ObsTime,ObsSL+ObsUncertainty,':k')

#ax.xaxis.set_visible(False)
#ax.yaxis.set_visible(False)
#ax.yaxis.set_label_position("right")
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
#ax.set_title("Historic",fontsize = SizeOfFont)
ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)

plt.show()
fp.savefig("Figures/RCP60_weighted_combined.pdf", bbox_inches='tight')
