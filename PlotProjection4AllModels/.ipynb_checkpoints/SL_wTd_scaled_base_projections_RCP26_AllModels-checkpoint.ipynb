# %%
# %matplotlib inline

# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pylab as plt
import imp
import csv
import pandas as pd
from io import StringIO

# %%
# Read data
# AISM_VUB

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_AISM_VUB_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_AISM_VUB_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_AISM_VUB_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_AISM_VUB_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_AISM_VUB_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_AISM_VUB_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_AISM_VUB_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_AISM_VUB_SU_RCP26 = SL_wTd_scaled_base_AISM_VUB_R1_RCP26+SL_wTd_scaled_base_AISM_VUB_R2_RCP26+SL_wTd_scaled_base_AISM_VUB_R3_RCP26+SL_wTd_scaled_base_AISM_VUB_R4_RCP26+SL_wTd_scaled_base_AISM_VUB_R5_RCP26

SL_wTd_scaled_base_AISM_VUB_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_AISM_VUB_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_AISM_VUB_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_AISM_VUB_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_AISM_VUB_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_AISM_VUB_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_AISM_VUB_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_AISM_VUB_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_AISM_VUB_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_AISM_VUB_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_AISM_VUB_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_AISM_VUB_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_AISM_VUB_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_AISM_VUB_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_AISM_VUB_SU_RCP26_99pc))
# Out:
# 0.31663936376571655

# %%
# Read data
# BISI_LBL

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_BISI_LBL_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_BISI_LBL_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_BISI_LBL_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_BISI_LBL_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_BISI_LBL_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_BISI_LBL_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_BISI_LBL_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_BISI_LBL_SU_RCP26 = SL_wTd_scaled_base_BISI_LBL_R1_RCP26+SL_wTd_scaled_base_BISI_LBL_R2_RCP26+SL_wTd_scaled_base_BISI_LBL_R3_RCP26+SL_wTd_scaled_base_BISI_LBL_R4_RCP26+SL_wTd_scaled_base_BISI_LBL_R5_RCP26

SL_wTd_scaled_base_BISI_LBL_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_BISI_LBL_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_BISI_LBL_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_BISI_LBL_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_BISI_LBL_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_BISI_LBL_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_BISI_LBL_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_BISI_LBL_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_BISI_LBL_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_BISI_LBL_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_BISI_LBL_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_BISI_LBL_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_BISI_LBL_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_BISI_LBL_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_BISI_LBL_SU_RCP26_99pc))
# Out:
# 0.4165657162666321

# %%
# Read data
# CISM_NCA

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_CISM_NCA_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_CISM_NCA_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_CISM_NCA_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_CISM_NCA_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_CISM_NCA_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_CISM_NCA_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_CISM_NCA_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_CISM_NCA_SU_RCP26 = SL_wTd_scaled_base_CISM_NCA_R1_RCP26+SL_wTd_scaled_base_CISM_NCA_R2_RCP26+SL_wTd_scaled_base_CISM_NCA_R3_RCP26+SL_wTd_scaled_base_CISM_NCA_R4_RCP26+SL_wTd_scaled_base_CISM_NCA_R5_RCP26

SL_wTd_scaled_base_CISM_NCA_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_CISM_NCA_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_CISM_NCA_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_CISM_NCA_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_CISM_NCA_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_CISM_NCA_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_CISM_NCA_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_CISM_NCA_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_CISM_NCA_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_CISM_NCA_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_CISM_NCA_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_CISM_NCA_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_CISM_NCA_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_CISM_NCA_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_CISM_NCA_SU_RCP26_99pc))
# Out:
# 0.21897973120212555

# %%
# Read data
# FETI_VUB

fname="..\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_FETI_VUB_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_FETI_VUB_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_FETI_VUB_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_FETI_VUB_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_FETI_VUB_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_FETI_VUB_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_FETI_VUB_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_FETI_VUB_SU_RCP26 = SL_wTd_scaled_base_FETI_VUB_R1_RCP26+SL_wTd_scaled_base_FETI_VUB_R2_RCP26+SL_wTd_scaled_base_FETI_VUB_R3_RCP26+SL_wTd_scaled_base_FETI_VUB_R4_RCP26+SL_wTd_scaled_base_FETI_VUB_R5_RCP26

SL_wTd_scaled_base_FETI_VUB_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_FETI_VUB_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_FETI_VUB_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_FETI_VUB_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_FETI_VUB_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_FETI_VUB_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_FETI_VUB_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_FETI_VUB_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_FETI_VUB_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_FETI_VUB_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_FETI_VUB_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_FETI_VUB_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_FETI_VUB_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_FETI_VUB_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_FETI_VUB_SU_RCP26_99pc))
# Out:
# 0.3692225217819214

# %%
# Read data
# GRIS_LSC

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_GRIS_LSC_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_GRIS_LSC_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_GRIS_LSC_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_GRIS_LSC_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_GRIS_LSC_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_GRIS_LSC_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_GRIS_LSC_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_GRIS_LSC_SU_RCP26 = SL_wTd_scaled_base_GRIS_LSC_R1_RCP26+SL_wTd_scaled_base_GRIS_LSC_R2_RCP26+SL_wTd_scaled_base_GRIS_LSC_R3_RCP26+SL_wTd_scaled_base_GRIS_LSC_R4_RCP26+SL_wTd_scaled_base_GRIS_LSC_R5_RCP26

SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_GRIS_LSC_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_GRIS_LSC_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_GRIS_LSC_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_GRIS_LSC_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_GRIS_LSC_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_GRIS_LSC_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_GRIS_LSC_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_99pc))
# Out:
# 0.07598420977592468

# %%
# Read data
# IMAU_VUB

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_IMAU_VUB_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_IMAU_VUB_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_IMAU_VUB_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_IMAU_VUB_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_IMAU_VUB_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_IMAU_VUB_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_IMAU_VUB_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_IMAU_VUB_SU_RCP26 = SL_wTd_scaled_base_IMAU_VUB_R1_RCP26+SL_wTd_scaled_base_IMAU_VUB_R2_RCP26+SL_wTd_scaled_base_IMAU_VUB_R3_RCP26+SL_wTd_scaled_base_IMAU_VUB_R4_RCP26+SL_wTd_scaled_base_IMAU_VUB_R5_RCP26

SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_IMAU_VUB_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_IMAU_VUB_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_IMAU_VUB_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_IMAU_VUB_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_IMAU_VUB_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_IMAU_VUB_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_IMAU_VUB_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_99pc))
# Out:
# 0.5999286770820618

# %%
# Read data
# ISSM_JPL

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_ISSM_JPL_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_ISSM_JPL_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_ISSM_JPL_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_ISSM_JPL_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_ISSM_JPL_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_ISSM_JPL_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_ISSM_JPL_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_ISSM_JPL_SU_RCP26 = SL_wTd_scaled_base_ISSM_JPL_R1_RCP26+SL_wTd_scaled_base_ISSM_JPL_R2_RCP26+SL_wTd_scaled_base_ISSM_JPL_R3_RCP26+SL_wTd_scaled_base_ISSM_JPL_R4_RCP26+SL_wTd_scaled_base_ISSM_JPL_R5_RCP26

SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_ISSM_JPL_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_ISSM_JPL_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_ISSM_JPL_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_ISSM_JPL_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_ISSM_JPL_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_ISSM_JPL_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_ISSM_JPL_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_99pc))
# Out:
# 0.5908983945846558

# %%
# Read data
# ISSM_UCI

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_ISSM_UCI_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_ISSM_UCI_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_ISSM_UCI_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_ISSM_UCI_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_ISSM_UCI_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_ISSM_UCI_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_ISSM_UCI_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_ISSM_UCI_SU_RCP26 = SL_wTd_scaled_base_ISSM_UCI_R1_RCP26+SL_wTd_scaled_base_ISSM_UCI_R2_RCP26+SL_wTd_scaled_base_ISSM_UCI_R3_RCP26+SL_wTd_scaled_base_ISSM_UCI_R4_RCP26+SL_wTd_scaled_base_ISSM_UCI_R5_RCP26

SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_ISSM_UCI_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_ISSM_UCI_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_ISSM_UCI_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_ISSM_UCI_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_ISSM_UCI_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_ISSM_UCI_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_ISSM_UCI_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_99pc))
# Out:
# 0.6456414461135864

# %%
# Read data
# PISM_AWI

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_PISM_AWI_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_PISM_AWI_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_PISM_AWI_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_PISM_AWI_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_PISM_AWI_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_PISM_AWI_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_PISM_AWI_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_PISM_AWI_SU_RCP26 = SL_wTd_scaled_base_PISM_AWI_R1_RCP26+SL_wTd_scaled_base_PISM_AWI_R2_RCP26+SL_wTd_scaled_base_PISM_AWI_R3_RCP26+SL_wTd_scaled_base_PISM_AWI_R4_RCP26+SL_wTd_scaled_base_PISM_AWI_R5_RCP26

SL_wTd_scaled_base_PISM_AWI_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_PISM_AWI_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_AWI_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_PISM_AWI_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_AWI_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_PISM_AWI_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_AWI_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_PISM_AWI_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_AWI_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_PISM_AWI_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_AWI_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_PISM_AWI_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_AWI_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_PISM_AWI_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_PISM_AWI_SU_RCP26_99pc))
# Out:
# 0.30161237716674805

# %%
# Read data
# PISM_DMI

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_PISM_DMI_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_PISM_DMI_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_PISM_DMI_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_PISM_DMI_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_PISM_DMI_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_PISM_DMI_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_PISM_DMI_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_PISM_DMI_SU_RCP26 = SL_wTd_scaled_base_PISM_DMI_R1_RCP26+SL_wTd_scaled_base_PISM_DMI_R2_RCP26+SL_wTd_scaled_base_PISM_DMI_R3_RCP26+SL_wTd_scaled_base_PISM_DMI_R4_RCP26+SL_wTd_scaled_base_PISM_DMI_R5_RCP26

SL_wTd_scaled_base_PISM_DMI_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_PISM_DMI_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_DMI_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_PISM_DMI_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_DMI_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_PISM_DMI_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_DMI_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_PISM_DMI_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_DMI_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_PISM_DMI_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_DMI_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_PISM_DMI_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_DMI_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_PISM_DMI_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_PISM_DMI_SU_RCP26_99pc))
# Out:
# 0.7913298606872559

# %%
# Read data
# PISM_PIK

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_PISM_PIK_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_PISM_PIK_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_PISM_PIK_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_PISM_PIK_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_PISM_PIK_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_PISM_PIK_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_PISM_PIK_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_PISM_PIK_SU_RCP26 = SL_wTd_scaled_base_PISM_PIK_R1_RCP26+SL_wTd_scaled_base_PISM_PIK_R2_RCP26+SL_wTd_scaled_base_PISM_PIK_R3_RCP26+SL_wTd_scaled_base_PISM_PIK_R4_RCP26+SL_wTd_scaled_base_PISM_PIK_R5_RCP26

SL_wTd_scaled_base_PISM_PIK_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_PISM_PIK_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_PIK_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_PISM_PIK_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_PIK_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_PISM_PIK_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_PIK_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_PISM_PIK_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_PIK_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_PISM_PIK_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_PIK_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_PISM_PIK_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_PIK_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_PISM_PIK_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_PISM_PIK_SU_RCP26_99pc))
# Out:
# 0.27062955498695374

# %%
# Read data
# PISM_VUW

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_PISM_VUW_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_PISM_VUW_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_PISM_VUW_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_PISM_VUW_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_PISM_VUW_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_PISM_VUW_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_PISM_VUW_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_PISM_VUW_SU_RCP26 = SL_wTd_scaled_base_PISM_VUW_R1_RCP26+SL_wTd_scaled_base_PISM_VUW_R2_RCP26+SL_wTd_scaled_base_PISM_VUW_R3_RCP26+SL_wTd_scaled_base_PISM_VUW_R4_RCP26+SL_wTd_scaled_base_PISM_VUW_R5_RCP26

SL_wTd_scaled_base_PISM_VUW_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_PISM_VUW_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_VUW_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_PISM_VUW_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_VUW_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_PISM_VUW_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_VUW_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_PISM_VUW_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_VUW_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_PISM_VUW_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_VUW_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_PISM_VUW_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PISM_VUW_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_PISM_VUW_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_PISM_VUW_SU_RCP26_99pc))
# Out:
# 0.8460054993629456

# %%
# Read data
# PS3D_PSU

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_PS3D_PSU_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_PS3D_PSU_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_PS3D_PSU_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_PS3D_PSU_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_PS3D_PSU_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_PS3D_PSU_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_PS3D_PSU_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_PS3D_PSU_SU_RCP26 = SL_wTd_scaled_base_PS3D_PSU_R1_RCP26+SL_wTd_scaled_base_PS3D_PSU_R2_RCP26+SL_wTd_scaled_base_PS3D_PSU_R3_RCP26+SL_wTd_scaled_base_PS3D_PSU_R4_RCP26+SL_wTd_scaled_base_PS3D_PSU_R5_RCP26

SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_PS3D_PSU_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_PS3D_PSU_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_PS3D_PSU_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_PS3D_PSU_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_PS3D_PSU_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_PS3D_PSU_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_PS3D_PSU_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_99pc))
# Out:
# 0.41722631454467773

# %%
# Read data
# SICO_UHO

fname="../\ComputeProjection4OneIceModel\EnsembleSingleModelProjections/SL_wTd_scaled_base_SICO_UHO_RCP26.nc"
ncf = nc.Dataset(fname, "r")

Time = ncf.variables["Time"][:]
SL_wTd_scaled_base_SICO_UHO_R0_RCP26 = ncf.variables["Antarctica"][:]
SL_wTd_scaled_base_SICO_UHO_R1_RCP26 = ncf.variables["EAIS"][:]
SL_wTd_scaled_base_SICO_UHO_R2_RCP26 = ncf.variables["Ross"][:]
SL_wTd_scaled_base_SICO_UHO_R3_RCP26 = ncf.variables["Amundsen"][:]
SL_wTd_scaled_base_SICO_UHO_R4_RCP26 = ncf.variables["Weddell"][:]
SL_wTd_scaled_base_SICO_UHO_R5_RCP26 = ncf.variables["Peninsula"][:]
SL_wTd_scaled_base_SICO_UHO_SU_RCP26 = SL_wTd_scaled_base_SICO_UHO_R1_RCP26+SL_wTd_scaled_base_SICO_UHO_R2_RCP26+SL_wTd_scaled_base_SICO_UHO_R3_RCP26+SL_wTd_scaled_base_SICO_UHO_R4_RCP26+SL_wTd_scaled_base_SICO_UHO_R5_RCP26

SL_wTd_scaled_base_SICO_UHO_SU_RCP26_50pc = np.percentile(SL_wTd_scaled_base_SICO_UHO_SU_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_SICO_UHO_SU_RCP26_83pc = np.percentile(SL_wTd_scaled_base_SICO_UHO_SU_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_SICO_UHO_SU_RCP26_17pc = np.percentile(SL_wTd_scaled_base_SICO_UHO_SU_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_SICO_UHO_SU_RCP26_95pc = np.percentile(SL_wTd_scaled_base_SICO_UHO_SU_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_SICO_UHO_SU_RCP26_05pc = np.percentile(SL_wTd_scaled_base_SICO_UHO_SU_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_SICO_UHO_SU_RCP26_99pc = np.percentile(SL_wTd_scaled_base_SICO_UHO_SU_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_SICO_UHO_SU_RCP26_01pc = np.percentile(SL_wTd_scaled_base_SICO_UHO_SU_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

print(max(SL_wTd_scaled_base_SICO_UHO_SU_RCP26_99pc))
# Out:
# 0.35498228669166565

# %%
SL_wTd_scaled_base_RCP26 =np.vstack([SL_wTd_scaled_base_AISM_VUB_SU_RCP26,SL_wTd_scaled_base_BISI_LBL_SU_RCP26,SL_wTd_scaled_base_CISM_NCA_SU_RCP26,SL_wTd_scaled_base_FETI_VUB_SU_RCP26,SL_wTd_scaled_base_GRIS_LSC_SU_RCP26,SL_wTd_scaled_base_IMAU_VUB_SU_RCP26,SL_wTd_scaled_base_ISSM_JPL_SU_RCP26,SL_wTd_scaled_base_ISSM_UCI_SU_RCP26,SL_wTd_scaled_base_PISM_AWI_SU_RCP26,SL_wTd_scaled_base_PISM_DMI_SU_RCP26,SL_wTd_scaled_base_PISM_PIK_SU_RCP26,SL_wTd_scaled_base_PISM_VUW_SU_RCP26,SL_wTd_scaled_base_PS3D_PSU_SU_RCP26, SL_wTd_scaled_base_SICO_UHO_SU_RCP26])
print(len(SL_wTd_scaled_base_RCP26[0,:]))
print(len(SL_wTd_scaled_base_RCP26[:,0]))
# Out:
# 200
# 280014

# %%
SL_wTd_scaled_base_RCP26_50pc = np.percentile(SL_wTd_scaled_base_RCP26, 50, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_RCP26_83pc = np.percentile(SL_wTd_scaled_base_RCP26, 83.33, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_RCP26_17pc = np.percentile(SL_wTd_scaled_base_RCP26, 16.66, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_RCP26_95pc = np.percentile(SL_wTd_scaled_base_RCP26, 5, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_RCP26_05pc = np.percentile(SL_wTd_scaled_base_RCP26, 95, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_RCP26_99pc = np.percentile(SL_wTd_scaled_base_RCP26, 99, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)
SL_wTd_scaled_base_RCP26_01pc = np.percentile(SL_wTd_scaled_base_RCP26, 1, axis=0, out=None, overwrite_input=False, interpolation='linear', keepdims=False)

np.savetxt("Percentiles/SL_wTd_scaled_base_RCP26_50pc.dat", SL_wTd_scaled_base_RCP26_50pc, delimiter=",")
np.savetxt("Percentiles/SL_wTd_scaled_base_RCP26_83pc.dat", SL_wTd_scaled_base_RCP26_83pc, delimiter=",")
np.savetxt("Percentiles/SL_wTd_scaled_base_RCP26_17pc.dat", SL_wTd_scaled_base_RCP26_17pc, delimiter=",")
np.savetxt("Percentiles/SL_wTd_scaled_base_RCP26_05pc.dat", SL_wTd_scaled_base_RCP26_05pc, delimiter=",")
np.savetxt("Percentiles/SL_wTd_scaled_base_RCP26_95pc.dat", SL_wTd_scaled_base_RCP26_95pc, delimiter=",")
np.savetxt("Percentiles/SL_wTd_scaled_base_RCP26_01pc.dat", SL_wTd_scaled_base_RCP26_01pc, delimiter=",")
np.savetxt("Percentiles/SL_wTd_scaled_base_RCP26_99pc.dat", SL_wTd_scaled_base_RCP26_99pc, delimiter=",")

# %%
fp = plt.figure()

# Set plotting variables
SizeOfFont = 20

# For all panels but Whole Antarctica
xmin = 1900
xmax = 2100
ymin = -0.01
ymax = 1.05
xlimit = [xmin, xmax]
ylimit = [ymin, ymax]
AspectRatio = 1.0*((xmax-xmin)/(ymax-ymin))

# For Whole Antarctica panel
xmin2 = 0
xmax2 = 100
ymin2 = 0
ymax2 = 0.75
xlimit2 = [xmin2, xmax2]
ylimit2 = [ymin2, ymax2]
AspectRatio2 = 1.0*((xmax2-xmin2)/(ymax2-ymin2))


figwidth = 15

ScalingTextXPos= xmin+10
ScalingTextYPos= ymax-0.08
ScalingTextXPos2= xmin2+10
ScalingTextYPos2= ymax2-0.25

fp, axes = plt.subplots(1, 1,figsize=(figwidth,figwidth/3*2))
fp.subplots_adjust(hspace=0.2, wspace=0.05)

ax = axes

plt.fill_between(Time, SL_wTd_scaled_base_RCP26_01pc, SL_wTd_scaled_base_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
plt.fill_between(Time, SL_wTd_scaled_base_RCP26_05pc, SL_wTd_scaled_base_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
plt.fill_between(Time, SL_wTd_scaled_base_RCP26_17pc, SL_wTd_scaled_base_RCP26_83pc,facecolor='#0000ff')
plt.plot(Time, SL_wTd_scaled_base_RCP26_50pc, '#ffffff')

#ax.xaxis.set_visible(False)
#ax.yaxis.set_visible(False)
#ax.yaxis.set_label_position("right")
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio2)
ax.set_title("Projections RCP-2.6",fontsize = SizeOfFont)
ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_CISM_NCA_BM08_R0,2))
#ax.text(ScalingTextXPos2,ScalingTextYPos2,ScalingText,fontsize = SizeOfFont)


plt.show()
fp.savefig("Figures/SL_wTd_scaled_base_projections_RCP26_ModelsCombined.pdf", bbox_inches='tight')

# %%
# Set plotting variables
SizeOfFont = 20

# For all panels but Whole Antarctica
xmin = 1900
xmax = 2100
ymin = -0.01
ymax = 1.05
xlimit = [xmin, xmax]
ylimit = [ymin, ymax]
AspectRatio = 1.0*((xmax-xmin)/(ymax-ymin))


figwidth = 20

ScalingTextXPos= xmin+10
ScalingTextYPos= ymax-0.1
ScalingTextXPos2= xmin2+10
ScalingTextYPos2= ymax2-0.25

# %%
fp, axes = plt.subplots(4, 4,figsize=(figwidth,figwidth))
#fp.subplots_adjust(hspace=0.2, wspace=0.01)
fp.subplots_adjust(hspace=0.15, wspace=0.01)

# AISM_VUB

ax = axes[0,0]
ax.fill_between(Time, SL_wTd_scaled_base_AISM_VUB_SU_RCP26_01pc, SL_wTd_scaled_base_AISM_VUB_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_AISM_VUB_SU_RCP26_05pc, SL_wTd_scaled_base_AISM_VUB_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_AISM_VUB_SU_RCP26_17pc, SL_wTd_scaled_base_AISM_VUB_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_AISM_VUB_SU_RCP26_50pc, '#ffffff')

ax.xaxis.set_visible(False)
#ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"AISM VUB",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R1,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# BISI_LBL

ax = axes[0,1]
ax.fill_between(Time, SL_wTd_scaled_base_BISI_LBL_SU_RCP26_01pc, SL_wTd_scaled_base_BISI_LBL_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_BISI_LBL_SU_RCP26_05pc, SL_wTd_scaled_base_BISI_LBL_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_BISI_LBL_SU_RCP26_17pc, SL_wTd_scaled_base_BISI_LBL_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_BISI_LBL_SU_RCP26_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"BISI LBL",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R1,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# CISM_NCA

ax = axes[0,2]
ax.fill_between(Time, SL_wTd_scaled_base_CISM_NCA_SU_RCP26_01pc, SL_wTd_scaled_base_CISM_NCA_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_CISM_NCA_SU_RCP26_05pc, SL_wTd_scaled_base_CISM_NCA_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_CISM_NCA_SU_RCP26_17pc, SL_wTd_scaled_base_CISM_NCA_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_CISM_NCA_SU_RCP26_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"CISM NCA",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R1,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# FETI_VUB
ax = axes[0,3]
ax.fill_between(Time, SL_wTd_scaled_base_FETI_VUB_SU_RCP26_01pc, SL_wTd_scaled_base_FETI_VUB_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_FETI_VUB_SU_RCP26_05pc, SL_wTd_scaled_base_FETI_VUB_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_FETI_VUB_SU_RCP26_17pc, SL_wTd_scaled_base_FETI_VUB_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_FETI_VUB_SU_RCP26_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"FETI ULB",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R2,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# GRIS_LSC
ax = axes[1,0]
#ax.plot(ISSM_UCI_BM02_R3[:endyear],'g')
ax.fill_between(Time, SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_01pc, SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_05pc, SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_17pc, SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_50pc, '#ffffff')

ax.xaxis.set_visible(False)
#ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"GRIS LSC",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R3,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# IMAU_VUB
ax = axes[1,1]
#ax.plot(ISSM_UCI_BM02_R4[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_01pc, SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_05pc, SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_17pc, SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"IMAU UU",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R4,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# ISSM_JPL
ax = axes[1,2]
#ax.plot(ISSM_UCI_BM04_R5[:endyear],'b')
ax.fill_between(Time, SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_01pc, SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_05pc, SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_17pc, SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"ISSM JPL",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R5,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# ISSM_UCI
ax = axes[1,3]
#ax.plot(ISSM_UCI_BM02_R0[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_01pc, SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_05pc, SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_17pc, SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
#ax.yaxis.set_label_position("right")
ax.yaxis.set_ticks_position("right")
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"ISSM UCI",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R0,2))
#ax.text(ScalingTextXPos2,ScalingTextYPos2,ScalingText,fontsize = SizeOfFont)


# MALI_LAN
ax = axes[2,0]
#ax.plot(MALI_LAN_BM02_R0[:endyear],'g',label="ISSM_UCI_BM02_R0")
#ax.fill_between(Time, SL_wTd_scaled_base_MALI_LAN_SU_RCP26_01pc, SL_wTd_scaled_base_MALI_LAN_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
#ax.fill_between(Time, SL_wTd_scaled_base_MALI_LAN_SU_RCP26_05pc, SL_wTd_scaled_base_MALI_LAN_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
#ax.fill_between(Time, SL_wTd_scaled_base_MALI_LAN_SU_RCP26_17pc, SL_wTd_scaled_base_MALI_LAN_SU_RCP26_83pc,facecolor='#0000ff')
#ax.plot(Time, SL_wTd_scaled_base_MALI_LAN_SU_RCP26_50pc, '#ffffff')

ax.xaxis.set_visible(False)
#ax.yaxis.set_visible(False)
#ax.yaxis.set_label_position("right")
#ax.yaxis.set_ticks_position("right")
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"MALI LAN",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R0,2))
#ax.text(ScalingTextXPos2,ScalingTextYPos2,ScalingText,fontsize = SizeOfFont)


# PISM_AWI
ax = axes[2,1]
#ax.plot(ISSM_UCI_BM02_R4[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_scaled_base_PISM_AWI_SU_RCP26_01pc, SL_wTd_scaled_base_PISM_AWI_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_PISM_AWI_SU_RCP26_05pc, SL_wTd_scaled_base_PISM_AWI_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_PISM_AWI_SU_RCP26_17pc, SL_wTd_scaled_base_PISM_AWI_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_PISM_AWI_SU_RCP26_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"PISM AWI",fontsize = SizeOfFont)
ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R4,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# PISM_DMI
ax = axes[2,2]
#ax.plot(PISM_DMI_BM02_R4[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_scaled_base_PISM_DMI_SU_RCP26_01pc, SL_wTd_scaled_base_PISM_DMI_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_PISM_DMI_SU_RCP26_05pc, SL_wTd_scaled_base_PISM_DMI_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_PISM_DMI_SU_RCP26_17pc, SL_wTd_scaled_base_PISM_DMI_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_PISM_DMI_SU_RCP26_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"PISM DMI",fontsize = SizeOfFont)
ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R4,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# PISM_PIK
ax = axes[2,3]
#ax.plot(PISM_PIK_BM04_R5[:endyear],'b')
ax.fill_between(Time, SL_wTd_scaled_base_PISM_PIK_SU_RCP26_01pc, SL_wTd_scaled_base_PISM_PIK_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_PISM_PIK_SU_RCP26_05pc, SL_wTd_scaled_base_PISM_PIK_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_PISM_PIK_SU_RCP26_17pc, SL_wTd_scaled_base_PISM_PIK_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_PISM_PIK_SU_RCP26_50pc, '#ffffff')

ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"PISM PIK",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
#ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R5,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# PISM_VUW
ax = axes[3,0]
#ax.plot(ISSM_UCI_BM02_R0[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_scaled_base_PISM_VUW_SU_RCP26_01pc, SL_wTd_scaled_base_PISM_VUW_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_PISM_VUW_SU_RCP26_05pc, SL_wTd_scaled_base_PISM_VUW_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_PISM_VUW_SU_RCP26_17pc, SL_wTd_scaled_base_PISM_VUW_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_PISM_VUW_SU_RCP26_50pc, '#ffffff')

#ax.xaxis.set_visible(False)
#ax.yaxis.set_visible(False)
#ax.yaxis.set_label_position("right")
#ax.yaxis.set_ticks_position("right")
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"PISM VUW",fontsize = SizeOfFont)
ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R0,2))
#ax.text(ScalingTextXPos2,ScalingTextYPos2,ScalingText,fontsize = SizeOfFont)

# PS3D_PSU
ax = axes[3,1]
#ax.plot(ISSM_UCI_BM02_R4[:endyear],'g',label="ISSM_UCI_BM02_R0")
ax.fill_between(Time, SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_01pc, SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_05pc, SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_17pc, SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_50pc, '#ffffff')

#ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"PS3D PSU",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R4,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)
ax.xaxis.set_ticks(np.arange(1950, 2150, 50))


# SICO_UHO
ax = axes[3,2]
#ax.plot(ISSM_UCI_BM04_R5[:endyear],'b')
ax.fill_between(Time, SL_wTd_scaled_base_SICO_UHO_SU_RCP26_01pc, SL_wTd_scaled_base_SICO_UHO_SU_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_SICO_UHO_SU_RCP26_05pc, SL_wTd_scaled_base_SICO_UHO_SU_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_SICO_UHO_SU_RCP26_17pc, SL_wTd_scaled_base_SICO_UHO_SU_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_SICO_UHO_SU_RCP26_50pc, '#ffffff')

#ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"SICO ILTS",fontsize = SizeOfFont)
#ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
ax.xaxis.set_ticks(np.arange(1950, 2150, 50))
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R5,2))
#ax.text(ScalingTextXPos,ScalingTextYPos,ScalingText,fontsize = SizeOfFont)


# Whole Antarctica
ax = axes[3,3]
ax.fill_between(Time, SL_wTd_scaled_base_RCP26_01pc, SL_wTd_scaled_base_RCP26_99pc,facecolor='#0000ff',alpha=0.25)
ax.fill_between(Time, SL_wTd_scaled_base_RCP26_05pc, SL_wTd_scaled_base_RCP26_95pc,facecolor='#0000ff',alpha=0.5)
ax.fill_between(Time, SL_wTd_scaled_base_RCP26_17pc, SL_wTd_scaled_base_RCP26_83pc,facecolor='#0000ff')
ax.plot(Time, SL_wTd_scaled_base_RCP26_50pc, '#ffffff')

#ax.xaxis.set_visible(False)
ax.yaxis.set_visible(False)
ax.yaxis.set_label_position("right")
ax.yaxis.set_ticks_position("right")
ax.set_xlim(xlimit)
ax.set_ylim(ylimit)
ax.xaxis.set_tick_params(labelsize=SizeOfFont)
ax.yaxis.set_tick_params(labelsize=SizeOfFont)
ax.set(adjustable='box',aspect=AspectRatio)
ax.text(ScalingTextXPos,ScalingTextYPos,"MODE ALL",fontsize = SizeOfFont)
ax.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax.set_xlabel("Time (years)",fontsize = SizeOfFont)
ax.xaxis.set_ticks(np.arange(1950, 2150, 50))
#ScalingText = "r = " + str(np.round(SF_ISSM_UCI_BM08_R0,2))
#ax.text(ScalingTextXPos2,ScalingTextYPos2,ScalingText,fontsize = SizeOfFont)



fp.savefig("Figures/SL_wTd_scaled_base_projections_RCP26_AllModels.pdf", bbox_inches='tight')

# %%
yearval = 199
modelnum = 13
ensemnum = 10001

SL_wTd_scaled_base_BISI_LBL_SU_RCP26_2100 = SL_wTd_scaled_base_BISI_LBL_SU_RCP26[:,yearval]
SL_wTd_scaled_base_CISM_NCA_SU_RCP26_2100 = SL_wTd_scaled_base_CISM_NCA_SU_RCP26[:,yearval]
SL_wTd_scaled_base_FETI_VUB_SU_RCP26_2100 = SL_wTd_scaled_base_FETI_VUB_SU_RCP26[:,yearval]
SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_2100 = SL_wTd_scaled_base_GRIS_LSC_SU_RCP26[:,yearval]
SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_2100 = SL_wTd_scaled_base_IMAU_VUB_SU_RCP26[:,yearval]
SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_2100 = SL_wTd_scaled_base_ISSM_JPL_SU_RCP26[:,yearval]
SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_2100 = SL_wTd_scaled_base_ISSM_UCI_SU_RCP26[:,yearval]
SL_wTd_scaled_base_PISM_AWI_SU_RCP26_2100 = SL_wTd_scaled_base_PISM_AWI_SU_RCP26[:,yearval]
SL_wTd_scaled_base_PISM_DMI_SU_RCP26_2100 = SL_wTd_scaled_base_PISM_DMI_SU_RCP26[:,yearval]
SL_wTd_scaled_base_PISM_PIK_SU_RCP26_2100 = SL_wTd_scaled_base_PISM_PIK_SU_RCP26[:,yearval]
SL_wTd_scaled_base_PISM_VUW_SU_RCP26_2100 = SL_wTd_scaled_base_PISM_VUW_SU_RCP26[:,yearval]
SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_2100 = SL_wTd_scaled_base_PS3D_PSU_SU_RCP26[:,yearval]
SL_wTd_scaled_base_SICO_UHO_SU_RCP26_2100 = SL_wTd_scaled_base_SICO_UHO_SU_RCP26[:,yearval]
SL_wTd_scaled_base_RCP26_2100 = SL_wTd_scaled_base_RCP26[:,yearval]

# %%
#binnum=2000
#binrange=np.arange(0.0005,2,0.001)
#binnum=200
#binrange=np.arange(0.005,2,0.01)
#binnum=300
#binrange=np.arange(-0.995,2,0.01)
#binnum=30
#binrange=np.arange(-0.95,2,0.1)
binnum=300
binrange=np.arange(-0.995,2,0.01)
#binnum=100
#binrange=np.arange(0.01,2,0.02)
SL_wTd_scaled_base_BISI_LBL_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_BISI_LBL_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_CISM_NCA_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_CISM_NCA_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_FETI_VUB_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_FETI_VUB_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_PISM_AWI_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_PISM_AWI_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_PISM_DMI_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_PISM_DMI_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_PISM_PIK_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_PISM_PIK_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_PISM_VUW_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_PISM_VUW_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_SICO_UHO_SU_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_SICO_UHO_SU_RCP26_2100,bins=binnum,range=(-1,2))
SL_wTd_scaled_base_RCP26_2100_hist, bins = np.histogram(SL_wTd_scaled_base_RCP26_2100,bins=binnum,range=(-1,2))
print(len(SL_wTd_scaled_base_BISI_LBL_SU_RCP26_2100_hist))
print(len(bins))
print(len(binrange))
# Out:
# 300
# 301
# 300

# %%
SizeOfFont = 20
figwidth = 20

# For all panels but Whole Antarctica
xmin1 = -0.0
xmax1 = 0.35
ymin1 = 0.0
ymax1 = 0.5
xlimit1 = [xmin1, xmax1]
ylimit1 = [ymin1, ymax1]
AspectRatio1 = 1.0*((xmax1-xmin1)/(ymax1-ymin1))

xmin2 = -0.0
xmax2 = 0.7
ymin2 = 0.0
ymax2 = 0.24
xlimit2 = [xmin2, xmax2]
ylimit2 = [ymin2, ymax2]
AspectRatio2 = 1.0*((xmax2-xmin2)/(ymax2-ymin2))

xmin3 = -0.0
xmax3 = 1.2
ymin3 = 0.0
ymax3 = 0.11
xlimit3 = [xmin3, xmax3]
ylimit3 = [ymin3, ymax3]
AspectRatio3 = 1.0*((xmax3-xmin3)/(ymax3-ymin3))

xmin4 = -0.0
xmax4 = 1.2
ymin4 = 0.0
ymax4 = 0.1
xlimit4 = [xmin4, xmax4]
ylimit4 = [ymin4, ymax4]
AspectRatio4 = 1.0*((xmax4-xmin4)/(ymax4-ymin4))

#fp, axes = plt.subplots(4)
fp, axes = plt.subplots(2, 2,figsize=(figwidth,figwidth))
fp.subplots_adjust(hspace=0.2,wspace=0.2)

ax1 = axes[0,0]
ax2 = axes[0,1]
ax3 = axes[1,0]
ax4 = axes[1,1]

#ax1 = axes[0,0]
#ax2 = axes[1,0]
#ax3 = axes[2,0]
#ax4 = axes[3,0]

ax1.plot(binrange,SL_wTd_scaled_base_BISI_LBL_SU_RCP26_2100_hist/ensemnum,label="BISI LBL")
ax2.plot(binrange,SL_wTd_scaled_base_CISM_NCA_SU_RCP26_2100_hist/ensemnum,label="CISM NCA")
ax2.plot(binrange,SL_wTd_scaled_base_FETI_VUB_SU_RCP26_2100_hist/ensemnum,label="FETI ULB")
ax1.plot(binrange,SL_wTd_scaled_base_GRIS_LSC_SU_RCP26_2100_hist/ensemnum,label="GRIS LSC")
ax3.plot(binrange,SL_wTd_scaled_base_IMAU_VUB_SU_RCP26_2100_hist/ensemnum,label="IMAU UU")
ax3.plot(binrange,SL_wTd_scaled_base_ISSM_JPL_SU_RCP26_2100_hist/ensemnum,label="ISSM JPL")
ax3.plot(binrange,SL_wTd_scaled_base_ISSM_UCI_SU_RCP26_2100_hist/ensemnum,label="ISSM UCI")
ax2.plot(binrange,SL_wTd_scaled_base_PISM_AWI_SU_RCP26_2100_hist/ensemnum,label="PISM AWI")
ax3.plot(binrange,SL_wTd_scaled_base_PISM_DMI_SU_RCP26_2100_hist/ensemnum,label="PISM DMI")
ax1.plot(binrange,SL_wTd_scaled_base_PISM_PIK_SU_RCP26_2100_hist/ensemnum,label="PISM PIK")
ax3.plot(binrange,SL_wTd_scaled_base_PISM_VUW_SU_RCP26_2100_hist/ensemnum,label="PISM VUW")
ax2.plot(binrange,SL_wTd_scaled_base_PS3D_PSU_SU_RCP26_2100_hist/ensemnum,label="PS3D PSU")
ax2.plot(binrange,SL_wTd_scaled_base_SICO_UHO_SU_RCP26_2100_hist/ensemnum,label="SICO UHO")
#ax4.plot(binrange,SL_wTd_scaled_base_RCP26_2100_hist/ensemnum/modelnum,".",label="MODE ALL")
ax4.hist(SL_wTd_scaled_base_RCP26_2100,bins='auto',label="MODE ALL")

ax1.set_xlim(xlimit1)
ax1.set_ylim(ylimit1)
ax1.xaxis.set_tick_params(labelsize=SizeOfFont)
ax1.yaxis.set_tick_params(labelsize=SizeOfFont)
ax1.set(adjustable='box',aspect=AspectRatio1)
ax1.set_title("Projections RCP-8.5",fontsize = SizeOfFont)
ax1.set_ylabel("Histogram",fontsize = SizeOfFont)
ax1.set_xlabel("Sea Level (m)",fontsize = SizeOfFont)
ax1.legend(fontsize = SizeOfFont)

ax2.set_xlim(xlimit2)
ax2.set_ylim(ylimit2)
#ax2.yaxis.set_visible(False)
ax2.xaxis.set_tick_params(labelsize=SizeOfFont)
ax2.yaxis.set_tick_params(labelsize=SizeOfFont)
ax2.set(adjustable='box',aspect=AspectRatio2)
ax2.set_title("Projections RCP-8.5",fontsize = SizeOfFont)
#ax2.set_ylabel("Sea level response (m)",fontsize = SizeOfFont)
ax2.set_xlabel("Sea Level (m)",fontsize = SizeOfFont)
ax2.legend(fontsize = SizeOfFont)

ax3.set_xlim(xlimit3)
ax3.set_ylim(ylimit3)
#ax3.yaxis.set_visible(False)
ax3.xaxis.set_tick_params(labelsize=SizeOfFont)
ax3.yaxis.set_tick_params(labelsize=SizeOfFont)
ax3.set(adjustable='box',aspect=AspectRatio3)
ax3.set_title("Projections RCP-8.5",fontsize = SizeOfFont)
#ax3.set_ylabel("Count",fontsize = SizeOfFont)
ax3.set_xlabel("Sea Level (m)",fontsize = SizeOfFont)
ax3.legend(fontsize = SizeOfFont)

#ax4.set_xlim(xlimit4)
#ax4.set_ylim(ylimit4)
#ax4.yaxis.set_visible(False)
#ax4.xaxis.set_tick_params(labelsize=SizeOfFont)
#ax4.yaxis.set_tick_params(labelsize=SizeOfFont)
#ax4.set(adjustable='box',aspect=AspectRatio4)
ax4.set_title("Projections RCP-8.5",fontsize = SizeOfFont)
#ax4.set_ylabel("Count",fontsize = SizeOfFont)
ax4.set_xlabel("Sea Level (m)",fontsize = SizeOfFont)
#ax4.legend(fontsize = SizeOfFont)
# Out:
# Text(0.5,0,'Sea Level (m)')
